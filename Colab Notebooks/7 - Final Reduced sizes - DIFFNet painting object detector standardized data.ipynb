# %% [markdown]
# ## Preparation
#
# ### Install the required packages
# Start by installing the required packages, including the Model Maker package from the [GitHub repo](https://github.com/tensorflow/examples/tree/master/tensorflow_examples/lite/model_maker) and the pycocotools library you'll use for evaluation.

# %%
# !pip install -q tflite-model-maker
# !pip install -q tflite-support
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.3/577.3 KB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 KB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 42.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 KB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.6/128.6 KB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 MB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 43.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 KB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 29.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.0/498.0 MB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 KB 36.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 106.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 84.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 KB 46.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 KB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.4/222.4 KB 28.2 MB/s eta 0:00:00
#   Building wheel for fire (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 2022.12.0 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.

# %% [markdown]
# Import the required packages.

# %%
import numpy as np
import os

from tflite_model_maker.config import ExportFormat, QuantizationConfig
from tflite_model_maker import model_spec
from tflite_model_maker import object_detector

from tflite_support import metadata

import tensorflow as tf
assert tf.__version__.startswith('2')

tf.get_logger().setLevel('ERROR')
from absl import logging
logging.set_verbosity(logging.ERROR)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.4 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %% [markdown]
# ### Prepare the dataset

# %%
#!wget https://storage.googleapis.com/download.tensorflow.org/data/android_figurine.zip
#!unzip -q android_figurine.zip
from google.colab import drive
drive.mount('/content/drive/', force_remount=True) #, force_remount=True
# Out:
# Mounted at /content/drive/

# %%
# Run this if need to force remount
import os
path = "/content" # /content is pretty much the root. you can choose other path in your colab workspace
os.chdir(path)

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/My Drive/
# Out:
# /content/drive/My Drive

# %%
# !unzip -q Colab_1024.zip # This should be on when running first time

# %% [markdown]
# ## Train the object detection model
#
# ### Step 1: Load the dataset
#
# * Images in `train_data` is used to train the custom object detection model.
# * Images in `val_data` is used to check if the model can generalize well to new images that it hasn't seen before.

# %%
# !pwd
# Out:
# /content/drive/My Drive

# %%
train_data = object_detector.DataLoader.from_pascal_voc(
    'Thesis/All_Photos/Original_Size_Reduction/Original_TRAIN',
    'Thesis/All_Photos/Original_Size_Reduction/Original_TRAIN',
    ['painting','Real_Tunnel']
)

val_data = object_detector.DataLoader.from_pascal_voc(
    'Thesis/All_Photos/Original_Size_Reduction/Original_TEST',
    'Thesis/All_Photos/Original_Size_Reduction/Original_TEST',
    ['painting','Real_Tunnel']
)

# %%
print(train_data.size)
# Out:
# 25

# %%
print(val_data.size)
# Out:
# 7

# %% [markdown]
# ### Step 2: Select a model architecture
#
# EfficientDet-Lite[0-4] are a family of mobile/IoT-friendly object detection models derived from the [EfficientDet](https://arxiv.org/abs/1911.09070) architecture.
#
# Here is the performance of each EfficientDet-Lite models compared to each others.
#
# | Model architecture | Size(MB)* | Latency(ms)** | Average Precision*** |
# |--------------------|-----------|---------------|----------------------|
# | EfficientDet-Lite0 | 4.4       | 146           | 25.69%               |
# | EfficientDet-Lite1 | 5.8       | 259           | 30.55%               |
# | EfficientDet-Lite2 | 7.2       | 396           | 33.97%               |
# | EfficientDet-Lite3 | 11.4      | 716           | 37.70%               |
# | EfficientDet-Lite4 | 19.9      | 1886          | 41.96%               |
#
# <i> * Size of the integer quantized models. <br/>
# ** Latency measured on Raspberry Pi 4 using 4 threads on CPU. <br/>
# *** Average Precision is the mAP (mean Average Precision) on the COCO 2017 validation dataset.
# </i>
#
# In this notebook, we use EfficientDet-Lite0 to train our model. You can choose other model architectures depending on whether speed or accuracy is more important to you.

# %%
spec = model_spec.get('efficientdet_lite4')

# %% [markdown]
# ### Step 3: Train the TensorFlow model with the training data.
#
# * Set `epochs = 20`, which means it will go through the training dataset 20 times. You can look at the validation accuracy during training and stop when you see validation loss (`val_loss`) stop decreasing to avoid overfitting.
# * Set `batch_size = 4` here so you will see that it takes 15 steps to go through the 62 images in the training dataset.
# * Set `train_whole_model=True` to fine-tune the whole model instead of just training the head layer to improve accuracy. The trade-off is that it may take longer to train the model.

# %%
import time
t1 = time.perf_counter()

# %%
model = object_detector.create(train_data, model_spec=spec, batch_size=4, train_whole_model=True, epochs=100, validation_data=val_data)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 86s 2s/step - det_loss: 1.7465 - cls_loss: 1.1640 - box_loss: 0.0116 - reg_l2_loss: 0.1078 - loss: 1.8542 - learning_rate: 0.0066 - gradient_norm: 1.2817 - val_det_loss: 1.6900 - val_cls_loss: 1.1646 - val_box_loss: 0.0105 - val_reg_l2_loss: 0.1078 - val_loss: 1.7978
# Epoch 2/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.7165 - cls_loss: 1.1539 - box_loss: 0.0113 - reg_l2_loss: 0.1078 - loss: 1.8242 - learning_rate: 0.0050 - gradient_norm: 1.4503 - val_det_loss: 1.6196 - val_cls_loss: 1.1568 - val_box_loss: 0.0093 - val_reg_l2_loss: 0.1078 - val_loss: 1.7273
# Epoch 3/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 1.6605 - cls_loss: 1.1442 - box_loss: 0.0103 - reg_l2_loss: 0.1078 - loss: 1.7683 - learning_rate: 0.0050 - gradient_norm: 1.5788 - val_det_loss: 1.5526 - val_cls_loss: 1.1461 - val_box_loss: 0.0081 - val_reg_l2_loss: 0.1078 - val_loss: 1.6604
# Epoch 4/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 1.6137 - cls_loss: 1.1363 - box_loss: 0.0095 - reg_l2_loss: 0.1078 - loss: 1.7215 - learning_rate: 0.0050 - gradient_norm: 2.1978 - val_det_loss: 1.4867 - val_cls_loss: 1.1321 - val_box_loss: 0.0071 - val_reg_l2_loss: 0.1078 - val_loss: 1.5945
# Epoch 5/100
# 6/6 [==============================] - 20s 4s/step - det_loss: 1.5567 - cls_loss: 1.1183 - box_loss: 0.0088 - reg_l2_loss: 0.1078 - loss: 1.6645 - learning_rate: 0.0050 - gradient_norm: 2.4435 - val_det_loss: 1.4298 - val_cls_loss: 1.1102 - val_box_loss: 0.0064 - val_reg_l2_loss: 0.1078 - val_loss: 1.5376
# Epoch 6/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 1.4537 - cls_loss: 1.0855 - box_loss: 0.0074 - reg_l2_loss: 0.1078 - loss: 1.5615 - learning_rate: 0.0050 - gradient_norm: 2.3621 - val_det_loss: 1.3599 - val_cls_loss: 1.0750 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.1078 - val_loss: 1.4676
# Epoch 7/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.4343 - cls_loss: 1.0596 - box_loss: 0.0075 - reg_l2_loss: 0.1078 - loss: 1.5421 - learning_rate: 0.0049 - gradient_norm: 2.2972 - val_det_loss: 1.2543 - val_cls_loss: 1.0022 - val_box_loss: 0.0050 - val_reg_l2_loss: 0.1078 - val_loss: 1.3621
# Epoch 8/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 1.3925 - cls_loss: 1.0013 - box_loss: 0.0078 - reg_l2_loss: 0.1078 - loss: 1.5003 - learning_rate: 0.0049 - gradient_norm: 3.9861 - val_det_loss: 1.1159 - val_cls_loss: 0.9057 - val_box_loss: 0.0042 - val_reg_l2_loss: 0.1078 - val_loss: 1.2237
# Epoch 9/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.2286 - cls_loss: 0.9322 - box_loss: 0.0059 - reg_l2_loss: 0.1078 - loss: 1.3364 - learning_rate: 0.0049 - gradient_norm: 3.8049 - val_det_loss: 0.9870 - val_cls_loss: 0.7554 - val_box_loss: 0.0046 - val_reg_l2_loss: 0.1078 - val_loss: 1.0948
# Epoch 10/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 1.1069 - cls_loss: 0.8088 - box_loss: 0.0060 - reg_l2_loss: 0.1078 - loss: 1.2147 - learning_rate: 0.0049 - gradient_norm: 3.6448 - val_det_loss: 0.8660 - val_cls_loss: 0.6839 - val_box_loss: 0.0036 - val_reg_l2_loss: 0.1078 - val_loss: 0.9738
# Epoch 11/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.9678 - cls_loss: 0.7071 - box_loss: 0.0052 - reg_l2_loss: 0.1078 - loss: 1.0756 - learning_rate: 0.0049 - gradient_norm: 3.5691 - val_det_loss: 1.1184 - val_cls_loss: 0.9637 - val_box_loss: 0.0031 - val_reg_l2_loss: 0.1078 - val_loss: 1.2262
# Epoch 12/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.9001 - cls_loss: 0.6642 - box_loss: 0.0047 - reg_l2_loss: 0.1078 - loss: 1.0079 - learning_rate: 0.0048 - gradient_norm: 4.1333 - val_det_loss: 0.8970 - val_cls_loss: 0.7464 - val_box_loss: 0.0030 - val_reg_l2_loss: 0.1078 - val_loss: 1.0048
# Epoch 13/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.8343 - cls_loss: 0.6195 - box_loss: 0.0043 - reg_l2_loss: 0.1078 - loss: 0.9421 - learning_rate: 0.0048 - gradient_norm: 3.6667 - val_det_loss: 0.6815 - val_cls_loss: 0.5427 - val_box_loss: 0.0028 - val_reg_l2_loss: 0.1078 - val_loss: 0.7893
# Epoch 14/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.7874 - cls_loss: 0.6090 - box_loss: 0.0036 - reg_l2_loss: 0.1078 - loss: 0.8952 - learning_rate: 0.0048 - gradient_norm: 3.6120 - val_det_loss: 0.6694 - val_cls_loss: 0.5395 - val_box_loss: 0.0026 - val_reg_l2_loss: 0.1078 - val_loss: 0.7773
# Epoch 15/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 0.7966 - cls_loss: 0.5499 - box_loss: 0.0049 - reg_l2_loss: 0.1078 - loss: 0.9045 - learning_rate: 0.0047 - gradient_norm: 3.3363 - val_det_loss: 0.6395 - val_cls_loss: 0.5067 - val_box_loss: 0.0027 - val_reg_l2_loss: 0.1078 - val_loss: 0.7473
# Epoch 16/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.6812 - cls_loss: 0.5167 - box_loss: 0.0033 - reg_l2_loss: 0.1078 - loss: 0.7890 - learning_rate: 0.0047 - gradient_norm: 3.8749 - val_det_loss: 0.6070 - val_cls_loss: 0.4724 - val_box_loss: 0.0027 - val_reg_l2_loss: 0.1078 - val_loss: 0.7149
# Epoch 17/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.6796 - cls_loss: 0.4994 - box_loss: 0.0036 - reg_l2_loss: 0.1078 - loss: 0.7875 - learning_rate: 0.0047 - gradient_norm: 6.6633 - val_det_loss: 0.5694 - val_cls_loss: 0.4391 - val_box_loss: 0.0026 - val_reg_l2_loss: 0.1078 - val_loss: 0.6773
# Epoch 18/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.5789 - cls_loss: 0.4407 - box_loss: 0.0028 - reg_l2_loss: 0.1078 - loss: 0.6867 - learning_rate: 0.0046 - gradient_norm: 3.4997 - val_det_loss: 0.5234 - val_cls_loss: 0.4027 - val_box_loss: 0.0024 - val_reg_l2_loss: 0.1078 - val_loss: 0.6312
# Epoch 19/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.6132 - cls_loss: 0.4542 - box_loss: 0.0032 - reg_l2_loss: 0.1078 - loss: 0.7211 - learning_rate: 0.0046 - gradient_norm: 3.8814 - val_det_loss: 0.5237 - val_cls_loss: 0.3893 - val_box_loss: 0.0027 - val_reg_l2_loss: 0.1078 - val_loss: 0.6316
# Epoch 20/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.6184 - cls_loss: 0.4571 - box_loss: 0.0032 - reg_l2_loss: 0.1078 - loss: 0.7263 - learning_rate: 0.0045 - gradient_norm: 4.2758 - val_det_loss: 0.5049 - val_cls_loss: 0.3828 - val_box_loss: 0.0024 - val_reg_l2_loss: 0.1079 - val_loss: 0.6127
# Epoch 21/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.5374 - cls_loss: 0.4078 - box_loss: 0.0026 - reg_l2_loss: 0.1079 - loss: 0.6452 - learning_rate: 0.0045 - gradient_norm: 4.0013 - val_det_loss: 0.5577 - val_cls_loss: 0.4324 - val_box_loss: 0.0025 - val_reg_l2_loss: 0.1079 - val_loss: 0.6656
# Epoch 22/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.5245 - cls_loss: 0.3856 - box_loss: 0.0028 - reg_l2_loss: 0.1079 - loss: 0.6323 - learning_rate: 0.0044 - gradient_norm: 4.1890 - val_det_loss: 0.5940 - val_cls_loss: 0.4578 - val_box_loss: 0.0027 - val_reg_l2_loss: 0.1079 - val_loss: 0.7019
# Epoch 23/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.5536 - cls_loss: 0.4314 - box_loss: 0.0024 - reg_l2_loss: 0.1079 - loss: 0.6614 - learning_rate: 0.0044 - gradient_norm: 3.1290 - val_det_loss: 0.6454 - val_cls_loss: 0.4920 - val_box_loss: 0.0031 - val_reg_l2_loss: 0.1079 - val_loss: 0.7532
# Epoch 24/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.4615 - cls_loss: 0.3411 - box_loss: 0.0024 - reg_l2_loss: 0.1079 - loss: 0.5694 - learning_rate: 0.0043 - gradient_norm: 2.8601 - val_det_loss: 0.6381 - val_cls_loss: 0.4977 - val_box_loss: 0.0028 - val_reg_l2_loss: 0.1079 - val_loss: 0.7460
# Epoch 25/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.4507 - cls_loss: 0.3261 - box_loss: 0.0025 - reg_l2_loss: 0.1079 - loss: 0.5585 - learning_rate: 0.0043 - gradient_norm: 2.7795 - val_det_loss: 0.6372 - val_cls_loss: 0.4949 - val_box_loss: 0.0028 - val_reg_l2_loss: 0.1079 - val_loss: 0.7450
# Epoch 26/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4754 - cls_loss: 0.3585 - box_loss: 0.0023 - reg_l2_loss: 0.1079 - loss: 0.5833 - learning_rate: 0.0042 - gradient_norm: 4.1591 - val_det_loss: 0.6988 - val_cls_loss: 0.5005 - val_box_loss: 0.0040 - val_reg_l2_loss: 0.1079 - val_loss: 0.8067
# Epoch 27/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.5347 - cls_loss: 0.4044 - box_loss: 0.0026 - reg_l2_loss: 0.1079 - loss: 0.6426 - learning_rate: 0.0042 - gradient_norm: 5.3097 - val_det_loss: 0.6519 - val_cls_loss: 0.5011 - val_box_loss: 0.0030 - val_reg_l2_loss: 0.1079 - val_loss: 0.7598
# Epoch 28/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3956 - cls_loss: 0.2910 - box_loss: 0.0021 - reg_l2_loss: 0.1079 - loss: 0.5035 - learning_rate: 0.0041 - gradient_norm: 2.7829 - val_det_loss: 0.6485 - val_cls_loss: 0.5196 - val_box_loss: 0.0026 - val_reg_l2_loss: 0.1079 - val_loss: 0.7564
# Epoch 29/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.4748 - cls_loss: 0.3387 - box_loss: 0.0027 - reg_l2_loss: 0.1079 - loss: 0.5827 - learning_rate: 0.0040 - gradient_norm: 5.0618 - val_det_loss: 0.6280 - val_cls_loss: 0.5123 - val_box_loss: 0.0023 - val_reg_l2_loss: 0.1079 - val_loss: 0.7359
# Epoch 30/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.4103 - cls_loss: 0.3196 - box_loss: 0.0018 - reg_l2_loss: 0.1079 - loss: 0.5182 - learning_rate: 0.0040 - gradient_norm: 3.3899 - val_det_loss: 0.6195 - val_cls_loss: 0.5084 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1079 - val_loss: 0.7274
# Epoch 31/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.4098 - cls_loss: 0.3089 - box_loss: 0.0020 - reg_l2_loss: 0.1079 - loss: 0.5177 - learning_rate: 0.0039 - gradient_norm: 3.9164 - val_det_loss: 0.6282 - val_cls_loss: 0.4967 - val_box_loss: 0.0026 - val_reg_l2_loss: 0.1079 - val_loss: 0.7361
# Epoch 32/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3761 - cls_loss: 0.2796 - box_loss: 0.0019 - reg_l2_loss: 0.1079 - loss: 0.4840 - learning_rate: 0.0039 - gradient_norm: 3.0116 - val_det_loss: 0.5789 - val_cls_loss: 0.4789 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1079 - val_loss: 0.6868
# Epoch 33/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3550 - cls_loss: 0.2757 - box_loss: 0.0016 - reg_l2_loss: 0.1079 - loss: 0.4629 - learning_rate: 0.0038 - gradient_norm: 3.2930 - val_det_loss: 0.5725 - val_cls_loss: 0.4729 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1079 - val_loss: 0.6804
# Epoch 34/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.4216 - cls_loss: 0.3132 - box_loss: 0.0022 - reg_l2_loss: 0.1079 - loss: 0.5295 - learning_rate: 0.0037 - gradient_norm: 4.1348 - val_det_loss: 0.5517 - val_cls_loss: 0.4580 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1079 - val_loss: 0.6596
# Epoch 35/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.4256 - cls_loss: 0.3038 - box_loss: 0.0024 - reg_l2_loss: 0.1079 - loss: 0.5336 - learning_rate: 0.0036 - gradient_norm: 3.4534 - val_det_loss: 0.5339 - val_cls_loss: 0.4337 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1079 - val_loss: 0.6418
# Epoch 36/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3544 - cls_loss: 0.2729 - box_loss: 0.0016 - reg_l2_loss: 0.1079 - loss: 0.4623 - learning_rate: 0.0036 - gradient_norm: 3.8637 - val_det_loss: 0.5404 - val_cls_loss: 0.4130 - val_box_loss: 0.0025 - val_reg_l2_loss: 0.1079 - val_loss: 0.6483
# Epoch 37/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3527 - cls_loss: 0.2639 - box_loss: 0.0018 - reg_l2_loss: 0.1079 - loss: 0.4606 - learning_rate: 0.0035 - gradient_norm: 3.2148 - val_det_loss: 0.5273 - val_cls_loss: 0.4103 - val_box_loss: 0.0023 - val_reg_l2_loss: 0.1079 - val_loss: 0.6353
# Epoch 38/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3266 - cls_loss: 0.2526 - box_loss: 0.0015 - reg_l2_loss: 0.1079 - loss: 0.4345 - learning_rate: 0.0034 - gradient_norm: 3.7101 - val_det_loss: 0.4883 - val_cls_loss: 0.3890 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1079 - val_loss: 0.5962
# Epoch 39/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3585 - cls_loss: 0.2698 - box_loss: 0.0018 - reg_l2_loss: 0.1079 - loss: 0.4664 - learning_rate: 0.0034 - gradient_norm: 3.4416 - val_det_loss: 0.4052 - val_cls_loss: 0.3315 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1079 - val_loss: 0.5131
# Epoch 40/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.3985 - cls_loss: 0.2913 - box_loss: 0.0021 - reg_l2_loss: 0.1079 - loss: 0.5064 - learning_rate: 0.0033 - gradient_norm: 3.8421 - val_det_loss: 0.4362 - val_cls_loss: 0.3451 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.5441
# Epoch 41/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.3407 - cls_loss: 0.2599 - box_loss: 0.0016 - reg_l2_loss: 0.1079 - loss: 0.4487 - learning_rate: 0.0032 - gradient_norm: 3.2364 - val_det_loss: 0.5197 - val_cls_loss: 0.4120 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1079 - val_loss: 0.6276
# Epoch 42/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2890 - cls_loss: 0.2215 - box_loss: 0.0014 - reg_l2_loss: 0.1079 - loss: 0.3970 - learning_rate: 0.0031 - gradient_norm: 3.8348 - val_det_loss: 0.4820 - val_cls_loss: 0.3763 - val_box_loss: 0.0021 - val_reg_l2_loss: 0.1079 - val_loss: 0.5899
# Epoch 43/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3330 - cls_loss: 0.2537 - box_loss: 0.0016 - reg_l2_loss: 0.1079 - loss: 0.4409 - learning_rate: 0.0031 - gradient_norm: 3.8201 - val_det_loss: 0.4124 - val_cls_loss: 0.3091 - val_box_loss: 0.0021 - val_reg_l2_loss: 0.1079 - val_loss: 0.5203
# Epoch 44/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4623 - cls_loss: 0.3664 - box_loss: 0.0019 - reg_l2_loss: 0.1079 - loss: 0.5703 - learning_rate: 0.0030 - gradient_norm: 5.1968 - val_det_loss: 0.4044 - val_cls_loss: 0.3098 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1079 - val_loss: 0.5123
# Epoch 45/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2977 - cls_loss: 0.2212 - box_loss: 0.0015 - reg_l2_loss: 0.1079 - loss: 0.4056 - learning_rate: 0.0029 - gradient_norm: 3.4651 - val_det_loss: 0.4249 - val_cls_loss: 0.3290 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1079 - val_loss: 0.5328
# Epoch 46/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3393 - cls_loss: 0.2499 - box_loss: 0.0018 - reg_l2_loss: 0.1079 - loss: 0.4473 - learning_rate: 0.0028 - gradient_norm: 4.4673 - val_det_loss: 0.3722 - val_cls_loss: 0.2710 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1079 - val_loss: 0.4802
# Epoch 47/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2580 - cls_loss: 0.1929 - box_loss: 0.0013 - reg_l2_loss: 0.1079 - loss: 0.3660 - learning_rate: 0.0027 - gradient_norm: 3.4117 - val_det_loss: 0.3520 - val_cls_loss: 0.2434 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1079 - val_loss: 0.4600
# Epoch 48/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.2827 - cls_loss: 0.2270 - box_loss: 0.0011 - reg_l2_loss: 0.1079 - loss: 0.3906 - learning_rate: 0.0027 - gradient_norm: 2.8199 - val_det_loss: 0.3400 - val_cls_loss: 0.2321 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1079 - val_loss: 0.4480
# Epoch 49/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 0.2534 - cls_loss: 0.1851 - box_loss: 0.0014 - reg_l2_loss: 0.1079 - loss: 0.3613 - learning_rate: 0.0026 - gradient_norm: 2.8901 - val_det_loss: 0.3203 - val_cls_loss: 0.2432 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1079 - val_loss: 0.4283
# Epoch 50/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 0.2683 - cls_loss: 0.2184 - box_loss: 9.9735e-04 - reg_l2_loss: 0.1079 - loss: 0.3763 - learning_rate: 0.0025 - gradient_norm: 3.5135 - val_det_loss: 0.3155 - val_cls_loss: 0.2377 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.1079 - val_loss: 0.4234
# Epoch 51/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2982 - cls_loss: 0.2252 - box_loss: 0.0015 - reg_l2_loss: 0.1079 - loss: 0.4062 - learning_rate: 0.0024 - gradient_norm: 3.3194 - val_det_loss: 0.3601 - val_cls_loss: 0.2537 - val_box_loss: 0.0021 - val_reg_l2_loss: 0.1079 - val_loss: 0.4680
# Epoch 52/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3309 - cls_loss: 0.2554 - box_loss: 0.0015 - reg_l2_loss: 0.1079 - loss: 0.4389 - learning_rate: 0.0023 - gradient_norm: 2.4713 - val_det_loss: 0.3643 - val_cls_loss: 0.2643 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1079 - val_loss: 0.4723
# Epoch 53/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3206 - cls_loss: 0.2575 - box_loss: 0.0013 - reg_l2_loss: 0.1079 - loss: 0.4286 - learning_rate: 0.0023 - gradient_norm: 4.6912 - val_det_loss: 0.3397 - val_cls_loss: 0.2385 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1079 - val_loss: 0.4476
# Epoch 54/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2746 - cls_loss: 0.2247 - box_loss: 9.9875e-04 - reg_l2_loss: 0.1079 - loss: 0.3825 - learning_rate: 0.0022 - gradient_norm: 3.1469 - val_det_loss: 0.3152 - val_cls_loss: 0.2300 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.4231
# Epoch 55/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2448 - cls_loss: 0.1905 - box_loss: 0.0011 - reg_l2_loss: 0.1079 - loss: 0.3527 - learning_rate: 0.0021 - gradient_norm: 2.6507 - val_det_loss: 0.2980 - val_cls_loss: 0.2182 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.1079 - val_loss: 0.4059
# Epoch 56/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.3191 - cls_loss: 0.2329 - box_loss: 0.0017 - reg_l2_loss: 0.1079 - loss: 0.4270 - learning_rate: 0.0020 - gradient_norm: 5.1465 - val_det_loss: 0.2986 - val_cls_loss: 0.2150 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.4065
# Epoch 57/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2486 - cls_loss: 0.1859 - box_loss: 0.0013 - reg_l2_loss: 0.1079 - loss: 0.3565 - learning_rate: 0.0020 - gradient_norm: 2.5833 - val_det_loss: 0.2898 - val_cls_loss: 0.2175 - val_box_loss: 0.0014 - val_reg_l2_loss: 0.1079 - val_loss: 0.3978
# Epoch 58/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2354 - cls_loss: 0.1853 - box_loss: 0.0010 - reg_l2_loss: 0.1079 - loss: 0.3434 - learning_rate: 0.0019 - gradient_norm: 3.0474 - val_det_loss: 0.2784 - val_cls_loss: 0.2107 - val_box_loss: 0.0014 - val_reg_l2_loss: 0.1079 - val_loss: 0.3863
# Epoch 59/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3043 - cls_loss: 0.2053 - box_loss: 0.0020 - reg_l2_loss: 0.1079 - loss: 0.4122 - learning_rate: 0.0018 - gradient_norm: 3.3405 - val_det_loss: 0.2677 - val_cls_loss: 0.1998 - val_box_loss: 0.0014 - val_reg_l2_loss: 0.1079 - val_loss: 0.3757
# Epoch 60/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 0.2514 - cls_loss: 0.1909 - box_loss: 0.0012 - reg_l2_loss: 0.1079 - loss: 0.3593 - learning_rate: 0.0017 - gradient_norm: 2.4030 - val_det_loss: 0.2687 - val_cls_loss: 0.1932 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1079 - val_loss: 0.3767
# Epoch 61/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.2757 - cls_loss: 0.2139 - box_loss: 0.0012 - reg_l2_loss: 0.1079 - loss: 0.3836 - learning_rate: 0.0016 - gradient_norm: 2.6887 - val_det_loss: 0.2640 - val_cls_loss: 0.1920 - val_box_loss: 0.0014 - val_reg_l2_loss: 0.1079 - val_loss: 0.3719
# Epoch 62/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2436 - cls_loss: 0.1978 - box_loss: 9.1535e-04 - reg_l2_loss: 0.1079 - loss: 0.3516 - learning_rate: 0.0016 - gradient_norm: 4.0680 - val_det_loss: 0.2692 - val_cls_loss: 0.1937 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1079 - val_loss: 0.3771
# Epoch 63/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2551 - cls_loss: 0.2049 - box_loss: 0.0010 - reg_l2_loss: 0.1079 - loss: 0.3630 - learning_rate: 0.0015 - gradient_norm: 4.1943 - val_det_loss: 0.2660 - val_cls_loss: 0.1920 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1079 - val_loss: 0.3739
# Epoch 64/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2571 - cls_loss: 0.2036 - box_loss: 0.0011 - reg_l2_loss: 0.1079 - loss: 0.3651 - learning_rate: 0.0014 - gradient_norm: 2.5357 - val_det_loss: 0.2820 - val_cls_loss: 0.1927 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.3900
# Epoch 65/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2908 - cls_loss: 0.2340 - box_loss: 0.0011 - reg_l2_loss: 0.1079 - loss: 0.3987 - learning_rate: 0.0014 - gradient_norm: 5.2489 - val_det_loss: 0.2994 - val_cls_loss: 0.1976 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1079 - val_loss: 0.4073
# Epoch 66/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2440 - cls_loss: 0.1927 - box_loss: 0.0010 - reg_l2_loss: 0.1079 - loss: 0.3519 - learning_rate: 0.0013 - gradient_norm: 2.2835 - val_det_loss: 0.3005 - val_cls_loss: 0.2007 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1079 - val_loss: 0.4085
# Epoch 67/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2839 - cls_loss: 0.2137 - box_loss: 0.0014 - reg_l2_loss: 0.1079 - loss: 0.3919 - learning_rate: 0.0012 - gradient_norm: 2.8551 - val_det_loss: 0.2973 - val_cls_loss: 0.2056 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.4052
# Epoch 68/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1937 - cls_loss: 0.1578 - box_loss: 7.1816e-04 - reg_l2_loss: 0.1079 - loss: 0.3017 - learning_rate: 0.0012 - gradient_norm: 2.0381 - val_det_loss: 0.2886 - val_cls_loss: 0.2045 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.3965
# Epoch 69/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 0.2334 - cls_loss: 0.1728 - box_loss: 0.0012 - reg_l2_loss: 0.1079 - loss: 0.3413 - learning_rate: 0.0011 - gradient_norm: 3.7124 - val_det_loss: 0.3220 - val_cls_loss: 0.2315 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.4299
# Epoch 70/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2535 - cls_loss: 0.1956 - box_loss: 0.0012 - reg_l2_loss: 0.1079 - loss: 0.3615 - learning_rate: 0.0010 - gradient_norm: 3.2302 - val_det_loss: 0.3429 - val_cls_loss: 0.2485 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1079 - val_loss: 0.4508
# Epoch 71/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2527 - cls_loss: 0.2029 - box_loss: 9.9717e-04 - reg_l2_loss: 0.1079 - loss: 0.3607 - learning_rate: 9.5616e-04 - gradient_norm: 2.7249 - val_det_loss: 0.3269 - val_cls_loss: 0.2344 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1079 - val_loss: 0.4349
# Epoch 72/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2172 - cls_loss: 0.1718 - box_loss: 9.0882e-04 - reg_l2_loss: 0.1079 - loss: 0.3252 - learning_rate: 8.9455e-04 - gradient_norm: 3.3404 - val_det_loss: 0.3426 - val_cls_loss: 0.2502 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.4506
# Epoch 73/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 0.2045 - cls_loss: 0.1619 - box_loss: 8.5170e-04 - reg_l2_loss: 0.1079 - loss: 0.3124 - learning_rate: 8.3456e-04 - gradient_norm: 2.7046 - val_det_loss: 0.3470 - val_cls_loss: 0.2554 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.4550
# Epoch 74/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2274 - cls_loss: 0.1842 - box_loss: 8.6406e-04 - reg_l2_loss: 0.1079 - loss: 0.3353 - learning_rate: 7.7625e-04 - gradient_norm: 2.4080 - val_det_loss: 0.3421 - val_cls_loss: 0.2496 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.4500
# Epoch 75/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2288 - cls_loss: 0.1833 - box_loss: 9.0967e-04 - reg_l2_loss: 0.1079 - loss: 0.3367 - learning_rate: 7.1967e-04 - gradient_norm: 2.2242 - val_det_loss: 0.3355 - val_cls_loss: 0.2408 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1079 - val_loss: 0.4434
# Epoch 76/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.1999 - cls_loss: 0.1545 - box_loss: 9.0806e-04 - reg_l2_loss: 0.1079 - loss: 0.3078 - learning_rate: 6.6489e-04 - gradient_norm: 2.1562 - val_det_loss: 0.3290 - val_cls_loss: 0.2360 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1079 - val_loss: 0.4370
# Epoch 77/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3061 - cls_loss: 0.2370 - box_loss: 0.0014 - reg_l2_loss: 0.1079 - loss: 0.4141 - learning_rate: 6.1195e-04 - gradient_norm: 4.4649 - val_det_loss: 0.3191 - val_cls_loss: 0.2266 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.4271
# Epoch 78/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2125 - cls_loss: 0.1613 - box_loss: 0.0010 - reg_l2_loss: 0.1079 - loss: 0.3204 - learning_rate: 5.6091e-04 - gradient_norm: 2.6644 - val_det_loss: 0.3077 - val_cls_loss: 0.2181 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.4157
# Epoch 79/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.1958 - cls_loss: 0.1523 - box_loss: 8.6982e-04 - reg_l2_loss: 0.1079 - loss: 0.3038 - learning_rate: 5.1183e-04 - gradient_norm: 2.3248 - val_det_loss: 0.3006 - val_cls_loss: 0.2138 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.4085
# Epoch 80/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 0.3235 - cls_loss: 0.2398 - box_loss: 0.0017 - reg_l2_loss: 0.1079 - loss: 0.4314 - learning_rate: 4.6475e-04 - gradient_norm: 4.1793 - val_det_loss: 0.2952 - val_cls_loss: 0.2093 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.4031
# Epoch 81/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1917 - cls_loss: 0.1527 - box_loss: 7.7987e-04 - reg_l2_loss: 0.1079 - loss: 0.2996 - learning_rate: 4.1972e-04 - gradient_norm: 2.2703 - val_det_loss: 0.2996 - val_cls_loss: 0.2117 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.4075
# Epoch 82/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2736 - cls_loss: 0.2089 - box_loss: 0.0013 - reg_l2_loss: 0.1079 - loss: 0.3816 - learning_rate: 3.7678e-04 - gradient_norm: 3.6803 - val_det_loss: 0.2988 - val_cls_loss: 0.2108 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.4067
# Epoch 83/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2272 - cls_loss: 0.1888 - box_loss: 7.6740e-04 - reg_l2_loss: 0.1079 - loss: 0.3351 - learning_rate: 3.3598e-04 - gradient_norm: 2.0915 - val_det_loss: 0.3010 - val_cls_loss: 0.2125 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.4090
# Epoch 84/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2610 - cls_loss: 0.2072 - box_loss: 0.0011 - reg_l2_loss: 0.1079 - loss: 0.3690 - learning_rate: 2.9736e-04 - gradient_norm: 2.9977 - val_det_loss: 0.2985 - val_cls_loss: 0.2095 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.4065
# Epoch 85/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 0.1992 - cls_loss: 0.1656 - box_loss: 6.7254e-04 - reg_l2_loss: 0.1079 - loss: 0.3071 - learning_rate: 2.6096e-04 - gradient_norm: 2.1541 - val_det_loss: 0.2980 - val_cls_loss: 0.2109 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.4059
# Epoch 86/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2143 - cls_loss: 0.1688 - box_loss: 9.1045e-04 - reg_l2_loss: 0.1079 - loss: 0.3223 - learning_rate: 2.2681e-04 - gradient_norm: 3.3168 - val_det_loss: 0.2956 - val_cls_loss: 0.2090 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.4036
# Epoch 87/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2595 - cls_loss: 0.2053 - box_loss: 0.0011 - reg_l2_loss: 0.1079 - loss: 0.3675 - learning_rate: 1.9495e-04 - gradient_norm: 2.7514 - val_det_loss: 0.2923 - val_cls_loss: 0.2069 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.4002
# Epoch 88/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2528 - cls_loss: 0.1980 - box_loss: 0.0011 - reg_l2_loss: 0.1079 - loss: 0.3607 - learning_rate: 1.6541e-04 - gradient_norm: 2.9486 - val_det_loss: 0.2908 - val_cls_loss: 0.2054 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.3988
# Epoch 89/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2126 - cls_loss: 0.1649 - box_loss: 9.5272e-04 - reg_l2_loss: 0.1079 - loss: 0.3205 - learning_rate: 1.3822e-04 - gradient_norm: 3.8924 - val_det_loss: 0.2836 - val_cls_loss: 0.1994 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.3915
# Epoch 90/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2468 - cls_loss: 0.1932 - box_loss: 0.0011 - reg_l2_loss: 0.1079 - loss: 0.3548 - learning_rate: 1.1341e-04 - gradient_norm: 2.8063 - val_det_loss: 0.2843 - val_cls_loss: 0.2004 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.3922
# Epoch 91/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.2881 - cls_loss: 0.2357 - box_loss: 0.0010 - reg_l2_loss: 0.1079 - loss: 0.3960 - learning_rate: 9.1009e-05 - gradient_norm: 3.7075 - val_det_loss: 0.2882 - val_cls_loss: 0.2042 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.3962
# Epoch 92/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2340 - cls_loss: 0.1872 - box_loss: 9.3604e-04 - reg_l2_loss: 0.1079 - loss: 0.3419 - learning_rate: 7.1028e-05 - gradient_norm: 2.4891 - val_det_loss: 0.2900 - val_cls_loss: 0.2061 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.3979
# Epoch 93/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1799 - cls_loss: 0.1409 - box_loss: 7.8051e-04 - reg_l2_loss: 0.1079 - loss: 0.2879 - learning_rate: 5.3493e-05 - gradient_norm: 1.3035 - val_det_loss: 0.2938 - val_cls_loss: 0.2099 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.4018
# Epoch 94/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2086 - cls_loss: 0.1597 - box_loss: 9.7809e-04 - reg_l2_loss: 0.1079 - loss: 0.3166 - learning_rate: 3.8422e-05 - gradient_norm: 2.8535 - val_det_loss: 0.2929 - val_cls_loss: 0.2091 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.4008
# Epoch 95/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2329 - cls_loss: 0.1839 - box_loss: 9.8061e-04 - reg_l2_loss: 0.1079 - loss: 0.3409 - learning_rate: 2.5829e-05 - gradient_norm: 2.6521 - val_det_loss: 0.2905 - val_cls_loss: 0.2072 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.3985
# Epoch 96/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2493 - cls_loss: 0.1909 - box_loss: 0.0012 - reg_l2_loss: 0.1079 - loss: 0.3573 - learning_rate: 1.5727e-05 - gradient_norm: 2.8454 - val_det_loss: 0.2943 - val_cls_loss: 0.2109 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.4023
# Epoch 97/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2053 - cls_loss: 0.1700 - box_loss: 7.0648e-04 - reg_l2_loss: 0.1079 - loss: 0.3133 - learning_rate: 8.1273e-06 - gradient_norm: 2.5476 - val_det_loss: 0.2961 - val_cls_loss: 0.2118 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.4040
# Epoch 98/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2107 - cls_loss: 0.1764 - box_loss: 6.8501e-04 - reg_l2_loss: 0.1079 - loss: 0.3186 - learning_rate: 3.0362e-06 - gradient_norm: 2.9930 - val_det_loss: 0.2993 - val_cls_loss: 0.2140 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.4073
# Epoch 99/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1954 - cls_loss: 0.1595 - box_loss: 7.1738e-04 - reg_l2_loss: 0.1079 - loss: 0.3034 - learning_rate: 4.5955e-07 - gradient_norm: 2.7213 - val_det_loss: 0.2973 - val_cls_loss: 0.2120 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.4052
# Epoch 100/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 0.2335 - cls_loss: 0.1848 - box_loss: 9.7500e-04 - reg_l2_loss: 0.1079 - loss: 0.3415 - learning_rate: 3.9961e-07 - gradient_norm: 2.9979 - val_det_loss: 0.2993 - val_cls_loss: 0.2140 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.4072

# %% [markdown]
# ### Step 4. Evaluate the model with the validation data.
#
# After training the object detection model using the images in the training dataset, use the 10 images in the validation dataset to evaluate how the model performs against new data it has never seen before.
#
# As the default batch size is 64, it will take 1 step to go through the 10 images in the validation dataset.
#
# The evaluation metrics are same as [COCO](https://cocodataset.org/#detection-eval).

# %%
model.evaluate(val_data)
# Out:
# 1/1 [==============================] - 7s 7s/step
# {'AP': 0.344117,
#  'AP50': 0.7159812,
#  'AP75': 0.37458745,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.34441447,
#  'ARmax1': 0.39166668,
#  'ARmax10': 0.44166666,
#  'ARmax100': 0.45416668,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.45416668,
#  'AP_/painting': 0.55130833,
#  'AP_/Real_Tunnel': 0.13692562}

# %%
# import matplotlib.pyplot as plt
# print(model.history.keys())
# # summarize history for loss
# plt.plot(model.history['loss'])
# plt.plot(model.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %% [markdown]
# ### Step 5: Export as a TensorFlow Lite model.
#
# Export the trained object detection model to the TensorFlow Lite format by specifying which folder you want to export the quantized model to. The default post-training quantization technique is [full integer quantization](https://www.tensorflow.org/lite/performance/post_training_integer_quant). This allows the TensorFlow Lite model to be smaller, run faster on Raspberry Pi CPU and also compatible with the Google Coral EdgeTPU.

# %%
model.export(export_dir='Thesis/Final-2023/Archive/', tflite_filename='android.tfliteSeven')

# %% [markdown]
# ### Step 6:  Evaluate the TensorFlow Lite model.
#
# Several factors can affect the model accuracy when exporting to TFLite:
# * [Quantization](https://www.tensorflow.org/lite/performance/model_optimization) helps shrinking the model size by 4 times at the expense of some accuracy drop.
# * The original TensorFlow model uses per-class [non-max supression (NMS)](https://www.coursera.org/lecture/convolutional-neural-networks/non-max-suppression-dvrjH) for post-processing, while the TFLite model uses global NMS that's much faster but less accurate.
# Keras outputs maximum 100 detections while tflite outputs maximum 25 detections.
#
# Therefore you'll have to evaluate the exported TFLite model and compare its accuracy with the original TensorFlow model.

# %%
model.evaluate_tflite('Thesis/Final-2023/Archive/android.tfliteSeven', val_data)
# Out:
# 7/7 [==============================] - 445s 64s/step
# {'AP': 0.3671411,
#  'AP50': 0.7627888,
#  'AP75': 0.37458745,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.37001413,
#  'ARmax1': 0.40833333,
#  'ARmax10': 0.49583334,
#  'ARmax100': 0.49583334,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.49583334,
#  'AP_/painting': 0.56633663,
#  'AP_/Real_Tunnel': 0.16794555}

# %%
# Download the TFLite model to your local computer.
# from google.colab import files
# files.download('android.tfliteSeven')

# %% [markdown]
# ## Test the Android figurine detection model
#
# After training the model, let's test it with an image that the model hasn't seen before to get a sense of how good the model is.

# %%
#@title Load the trained TFLite model and define some visualization functions

#@markdown This code comes from the TFLite Object Detection [Raspberry Pi sample](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/raspberry_pi).

import platform
from typing import List, NamedTuple
import json

import cv2

Interpreter = tf.lite.Interpreter
load_delegate = tf.lite.experimental.load_delegate

# pylint: enable=g-import-not-at-top


class ObjectDetectorOptions(NamedTuple):
  """A config to initialize an object detector."""

  enable_edgetpu: bool = False
  """Enable the model to run on EdgeTPU."""

  label_allow_list: List[str] = None
  """The optional allow list of labels."""

  label_deny_list: List[str] = None
  """The optional deny list of labels."""

  max_results: int = -1
  """The maximum number of top-scored detection results to return."""

  num_threads: int = 1
  """The number of CPU threads to be used."""

  score_threshold: float = 0.0
  """The score threshold of detection results to return."""


class Rect(NamedTuple):
  """A rectangle in 2D space."""
  left: float
  top: float
  right: float
  bottom: float


class Category(NamedTuple):
  """A result of a classification task."""
  label: str
  score: float
  index: int


class Detection(NamedTuple):
  """A detected object as the result of an ObjectDetector."""
  bounding_box: Rect
  categories: List[Category]


def edgetpu_lib_name():
  """Returns the library name of EdgeTPU in the current platform."""
  return {
      'Darwin': 'libedgetpu.1.dylib',
      'Linux': 'libedgetpu.so.1',
      'Windows': 'edgetpu.dll',
  }.get(platform.system(), None)


class ObjectDetector:
  """A wrapper class for a TFLite object detection model."""

  _OUTPUT_LOCATION_NAME = 'location'
  _OUTPUT_CATEGORY_NAME = 'category'
  _OUTPUT_SCORE_NAME = 'score'
  _OUTPUT_NUMBER_NAME = 'number of detections'

  def __init__(
      self,
      model_path: str,
      options: ObjectDetectorOptions = ObjectDetectorOptions()
  ) -> None:
    """Initialize a TFLite object detection model.
    Args:
        model_path: Path to the TFLite model.
        options: The config to initialize an object detector. (Optional)
    Raises:
        ValueError: If the TFLite model is invalid.
        OSError: If the current OS isn't supported by EdgeTPU.
    """

    # Load metadata from model.
    displayer = metadata.MetadataDisplayer.with_model_file(model_path)

    # Save model metadata for preprocessing later.
    model_metadata = json.loads(displayer.get_metadata_json())
    process_units = model_metadata['subgraph_metadata'][0]['input_tensor_metadata'][0]['process_units']
    mean = 0.0
    std = 1.0
    for option in process_units:
      if option['options_type'] == 'NormalizationOptions':
        mean = option['options']['mean'][0]
        std = option['options']['std'][0]
    self._mean = mean
    self._std = std

    # Load label list from metadata.
    file_name = displayer.get_packed_associated_file_list()[0]
    label_map_file = displayer.get_associated_file_buffer(file_name).decode()
    label_list = list(filter(lambda x: len(x) > 0, label_map_file.splitlines()))
    self._label_list = label_list

    # Initialize TFLite model.
    if options.enable_edgetpu:
      if edgetpu_lib_name() is None:
        raise OSError("The current OS isn't supported by Coral EdgeTPU.")
      interpreter = Interpreter(
          model_path=model_path,
          experimental_delegates=[load_delegate(edgetpu_lib_name())],
          num_threads=options.num_threads)
    else:
      interpreter = Interpreter(
          model_path=model_path, num_threads=options.num_threads)

    interpreter.allocate_tensors()
    input_detail = interpreter.get_input_details()[0]

    # From TensorFlow 2.6, the order of the outputs become undefined.
    # Therefore we need to sort the tensor indices of TFLite outputs and to know
    # exactly the meaning of each output tensor. For example, if
    # output indices are [601, 599, 598, 600], tensor names and indices aligned
    # are:
    #   - location: 598
    #   - category: 599
    #   - score: 600
    #   - detection_count: 601
    # because of the op's ports of TFLITE_DETECTION_POST_PROCESS
    # (https://github.com/tensorflow/tensorflow/blob/a4fe268ea084e7d323133ed7b986e0ae259a2bc7/tensorflow/lite/kernels/detection_postprocess.cc#L47-L50).
    sorted_output_indices = sorted(
        [output['index'] for output in interpreter.get_output_details()])
    self._output_indices = {
        self._OUTPUT_LOCATION_NAME: sorted_output_indices[0],
        self._OUTPUT_CATEGORY_NAME: sorted_output_indices[1],
        self._OUTPUT_SCORE_NAME: sorted_output_indices[2],
        self._OUTPUT_NUMBER_NAME: sorted_output_indices[3],
    }

    self._input_size = input_detail['shape'][2], input_detail['shape'][1]
    self._is_quantized_input = input_detail['dtype'] == np.uint8
    self._interpreter = interpreter
    self._options = options

  def detect(self, input_image: np.ndarray) -> List[Detection]:
    """Run detection on an input image.
    Args:
        input_image: A [height, width, 3] RGB image. Note that height and width
          can be anything since the image will be immediately resized according
          to the needs of the model within this function.
    Returns:
        A Person instance.
    """
    image_height, image_width, _ = input_image.shape

    input_tensor = self._preprocess(input_image)

    self._set_input_tensor(input_tensor)
    self._interpreter.invoke()

    # Get all output details
    boxes = self._get_output_tensor(self._OUTPUT_LOCATION_NAME)
    classes = self._get_output_tensor(self._OUTPUT_CATEGORY_NAME)
    scores = self._get_output_tensor(self._OUTPUT_SCORE_NAME)
    count = int(self._get_output_tensor(self._OUTPUT_NUMBER_NAME))

    return self._postprocess(boxes, classes, scores, count, image_width,
                             image_height)

  def _preprocess(self, input_image: np.ndarray) -> np.ndarray:
    """Preprocess the input image as required by the TFLite model."""

    # Resize the input
    input_tensor = cv2.resize(input_image, self._input_size)

    # Normalize the input if it's a float model (aka. not quantized)
    if not self._is_quantized_input:
      input_tensor = (np.float32(input_tensor) - self._mean) / self._std

    # Add batch dimension
    input_tensor = np.expand_dims(input_tensor, axis=0)

    return input_tensor

  def _set_input_tensor(self, image):
    """Sets the input tensor."""
    tensor_index = self._interpreter.get_input_details()[0]['index']
    input_tensor = self._interpreter.tensor(tensor_index)()[0]
    input_tensor[:, :] = image

  def _get_output_tensor(self, name):
    """Returns the output tensor at the given index."""
    output_index = self._output_indices[name]
    tensor = np.squeeze(self._interpreter.get_tensor(output_index))
    return tensor

  def _postprocess(self, boxes: np.ndarray, classes: np.ndarray,
                   scores: np.ndarray, count: int, image_width: int,
                   image_height: int) -> List[Detection]:
    """Post-process the output of TFLite model into a list of Detection objects.
    Args:
        boxes: Bounding boxes of detected objects from the TFLite model.
        classes: Class index of the detected objects from the TFLite model.
        scores: Confidence scores of the detected objects from the TFLite model.
        count: Number of detected objects from the TFLite model.
        image_width: Width of the input image.
        image_height: Height of the input image.
    Returns:
        A list of Detection objects detected by the TFLite model.
    """
    results = []

    # Parse the model output into a list of Detection entities.
    for i in range(count):
      if scores[i] >= self._options.score_threshold:
        y_min, x_min, y_max, x_max = boxes[i]
        bounding_box = Rect(
            top=int(y_min * image_height),
            left=int(x_min * image_width),
            bottom=int(y_max * image_height),
            right=int(x_max * image_width))
        class_id = int(classes[i])
        category = Category(
            score=scores[i],
            label=self._label_list[class_id],  # 0 is reserved for background
            index=class_id)
        result = Detection(bounding_box=bounding_box, categories=[category])
        results.append(result)

    # Sort detection results by score ascending
    sorted_results = sorted(
        results,
        key=lambda detection: detection.categories[0].score,
        reverse=True)

    # Filter out detections in deny list
    filtered_results = sorted_results
    if self._options.label_deny_list is not None:
      filtered_results = list(
          filter(
              lambda detection: detection.categories[0].label not in self.
              _options.label_deny_list, filtered_results))

    # Keep only detections in allow list
    if self._options.label_allow_list is not None:
      filtered_results = list(
          filter(
              lambda detection: detection.categories[0].label in self._options.
              label_allow_list, filtered_results))

    # Only return maximum of max_results detection.
    if self._options.max_results > 0:
      result_count = min(len(filtered_results), self._options.max_results)
      filtered_results = filtered_results[:result_count]

    return filtered_results


_MARGIN = 10  # pixels
_ROW_SIZE = 10  # pixels
_FONT_SIZE = 1
_FONT_THICKNESS = 1
_TEXT_COLOR = (0, 0, 255)  # red


def visualize(
    image: np.ndarray,
    detections: List[Detection],
) -> np.ndarray:
  """Draws bounding boxes on the input image and return it.
  Args:
    image: The input RGB image.
    detections: The list of all "Detection" entities to be visualize.
  Returns:
    Image with bounding boxes.
  """
  for detection in detections:
    # Draw bounding_box
    start_point = detection.bounding_box.left, detection.bounding_box.top
    end_point = detection.bounding_box.right, detection.bounding_box.bottom
    cv2.rectangle(image, start_point, end_point, _TEXT_COLOR, 3)

    # Draw label and score
    category = detection.categories[0]
    class_name = category.label
    probability = round(category.score, 2)
    result_text = class_name + ' (' + str(probability) + ')'
    text_location = (_MARGIN + detection.bounding_box.left,
                     _MARGIN + _ROW_SIZE + detection.bounding_box.top)
    cv2.putText(image, result_text, text_location, cv2.FONT_HERSHEY_PLAIN,
                _FONT_SIZE, _TEXT_COLOR, _FONT_THICKNESS)

  return image

# %%
from PIL import Image
INPUT_IMAGE_ONE = 'Thesis/All_Photos/6_channels/6_TEST/0_disp.jpg' #@param {type:"string"}
DETECTION_THRESHOLD = 0.5 #@param {type:"number"}
TFLITE_MODEL_PATH = "Thesis/Final-2023/Archive/android.tfliteSeven" #@param {type:"string"}

TEMP_FILE = '/tmp/image.png'

# !wget -q -O $TEMP_FILE $INPUT_IMAGE_ONE

#image = Image.open(TEMP_FILE).convert('RGB')
image_one = Image.open(INPUT_IMAGE_ONE).convert('RGB')
image_one.thumbnail((512, 512), Image.ANTIALIAS)
image_np_one = np.asarray(image_one)

# Load the TFLite model
options = ObjectDetectorOptions(
      num_threads=4,
      score_threshold=DETECTION_THRESHOLD,
)
detector = ObjectDetector(model_path=TFLITE_MODEL_PATH, options=options)

# Run object detection estimation using the model.
detections = detector.detect(image_np_one)

# Draw keypoints and edges on input image
image_np_one = visualize(image_np_one, detections)

# Show the detection result
Image.fromarray(image_np_one)
# Out:
# <PIL.Image.Image image mode=RGB size=512x341 at 0x7F3CDB0BC2E0>

# %%
#INPUT_IMAGE_URL = 'JPEG/Validate/2_33226e67-1692-4472-88be-acdbace303f5_1024x1024.jpg'
INPUT_IMAGE_URL = 'Thesis/All_Photos/6_channels/6_TEST/6_disp.jpg'
DISP_IMAGE_OVERLAY = 'Thesis/All_Photos/6_channels/6_TEST/6_disp.jpg'

# %%
#@title Run object detection and show the detection results

# from PIL import Image

# INPUT_IMAGE_URL = 'Depth_Map_Image/2_disp.jpeg'
# INPUT_IMAGE_URL = "http://download.tensorflow.org/example_images/android_figurine.jpg" #@param {type:"string"}
INPUT_IMAGE_URL = INPUT_IMAGE_URL #@param {type:"string"}
DETECTION_THRESHOLD = 0.5 #@param {type:"number"}
TFLITE_MODEL_PATH = "Thesis/Final-2023/Archive/android.tfliteSeven" #@param {type:"string"}

TEMP_FILE = '/tmp/image.png'

# !wget -q -O $TEMP_FILE $INPUT_IMAGE_URL

#image = Image.open(TEMP_FILE).convert('RGB')
image = Image.open(INPUT_IMAGE_URL).convert('RGB')
image.thumbnail((512, 512), Image.ANTIALIAS)
image_np = np.asarray(image)

# Load the TFLite model
options = ObjectDetectorOptions(
      num_threads=4,
      score_threshold=DETECTION_THRESHOLD,
)
detector = ObjectDetector(model_path=TFLITE_MODEL_PATH, options=options)

# Run object detection estimation using the model.
detections = detector.detect(image_np)

# Draw keypoints and edges on input image
image_np = visualize(image_np, detections)

# Show the detection result
Image.fromarray(image_np)



# #image = Image.open(TEMP_FILE).convert('RGB')
# image_two = Image.open(DISP_IMAGE_OVERLAY).convert('RGB')
# image_two.thumbnail((512, 512), Image.ANTIALIAS)
# image_np_two = np.asarray(image_two)

# image_np_two = visualize(image_np_two, detections)
# Image.fromarray(image_np_two)
# Out:
# <PIL.Image.Image image mode=RGB size=512x288 at 0x7F3CDC78A8E0>

# %%
# image_two = Image.open(DISP_IMAGE_OVERLAY).convert('RGB')
# image_two.thumbnail((512, 512), Image.ANTIALIAS)
# image_np_two = np.asarray(image_two)

# image_np_two = visualize(image_np_two, detections)
# Image.fromarray(image_np_two)

# %%
t2 = time.perf_counter()
print('time taken to run:',t2-t1)
# Out:
# time taken to run: 1924.161222092

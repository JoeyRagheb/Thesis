# %% [markdown]
# ## Preparation
#
# ### Install the required packages
# Start by installing the required packages, including the Model Maker package from the [GitHub repo](https://github.com/tensorflow/examples/tree/master/tensorflow_examples/lite/model_maker) and the pycocotools library you'll use for evaluation.

# %%
# !pip install -q tflite-model-maker
# !pip install -q tflite-support
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.3/577.3 KB 22.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 KB 52.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 87.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 MB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 KB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.6/128.6 KB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 KB 22.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 45.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 39.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 67.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.0/498.0 MB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 KB 37.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 84.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 63.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 KB 46.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 KB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.4/222.4 KB 22.9 MB/s eta 0:00:00
#   Building wheel for fire (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 2022.12.0 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.

# %% [markdown]
# Import the required packages.

# %%
import numpy as np
import os

from tflite_model_maker.config import ExportFormat, QuantizationConfig
from tflite_model_maker import model_spec
from tflite_model_maker import object_detector

from tflite_support import metadata

import tensorflow as tf
assert tf.__version__.startswith('2')

tf.get_logger().setLevel('ERROR')
from absl import logging
logging.set_verbosity(logging.ERROR)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.4 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %% [markdown]
# ### Prepare the dataset

# %%
#!wget https://storage.googleapis.com/download.tensorflow.org/data/android_figurine.zip
#!unzip -q android_figurine.zip
from google.colab import drive
drive.mount('/content/drive/', force_remount=True) #, force_remount=True
# Out:
# Mounted at /content/drive/

# %%
# Run this if need to force remount
import os
path = "/content" # /content is pretty much the root. you can choose other path in your colab workspace
os.chdir(path)

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/My Drive/
# Out:
# /content/drive/My Drive

# %%
# !unzip -q Colab_1024.zip # This should be on when running first time

# %% [markdown]
# ## Train the object detection model
#
# ### Step 1: Load the dataset
#
# * Images in `train_data` is used to train the custom object detection model.
# * Images in `val_data` is used to check if the model can generalize well to new images that it hasn't seen before.

# %%
# !pwd
# Out:
# /content/drive/My Drive

# %%
train_data = object_detector.DataLoader.from_pascal_voc(
    'Thesis/All_Photos/1024_DIFFNet/TRAIN_1024',
    'Thesis/All_Photos/1024_DIFFNet/TRAIN_1024',
    ['painting','Real_Tunnel']
)

val_data = object_detector.DataLoader.from_pascal_voc(
    'Thesis/All_Photos/1024_DIFFNet/TEST_1024',
    'Thesis/All_Photos/1024_DIFFNet/TEST_1024',
    ['painting','Real_Tunnel']
)

# %%
print(train_data.size)
# Out:
# 25

# %% [markdown]
# ### Step 2: Select a model architecture
#
# EfficientDet-Lite[0-4] are a family of mobile/IoT-friendly object detection models derived from the [EfficientDet](https://arxiv.org/abs/1911.09070) architecture.
#
# Here is the performance of each EfficientDet-Lite models compared to each others.
#
# | Model architecture | Size(MB)* | Latency(ms)** | Average Precision*** |
# |--------------------|-----------|---------------|----------------------|
# | EfficientDet-Lite0 | 4.4       | 146           | 25.69%               |
# | EfficientDet-Lite1 | 5.8       | 259           | 30.55%               |
# | EfficientDet-Lite2 | 7.2       | 396           | 33.97%               |
# | EfficientDet-Lite3 | 11.4      | 716           | 37.70%               |
# | EfficientDet-Lite4 | 19.9      | 1886          | 41.96%               |
#
# <i> * Size of the integer quantized models. <br/>
# ** Latency measured on Raspberry Pi 4 using 4 threads on CPU. <br/>
# *** Average Precision is the mAP (mean Average Precision) on the COCO 2017 validation dataset.
# </i>
#
# In this notebook, we use EfficientDet-Lite0 to train our model. You can choose other model architectures depending on whether speed or accuracy is more important to you.

# %%
spec = model_spec.get('efficientdet_lite4')

# %% [markdown]
# ### Step 3: Train the TensorFlow model with the training data.
#
# * Set `epochs = 20`, which means it will go through the training dataset 20 times. You can look at the validation accuracy during training and stop when you see validation loss (`val_loss`) stop decreasing to avoid overfitting.
# * Set `batch_size = 4` here so you will see that it takes 15 steps to go through the 62 images in the training dataset.
# * Set `train_whole_model=True` to fine-tune the whole model instead of just training the head layer to improve accuracy. The trade-off is that it may take longer to train the model.

# %%
import time
t1 = time.perf_counter()

# %%
model = object_detector.create(train_data, model_spec=spec, batch_size=4, train_whole_model=True, epochs=100, validation_data=val_data)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 75s 2s/step - det_loss: 1.7601 - cls_loss: 1.1668 - box_loss: 0.0119 - reg_l2_loss: 0.1078 - loss: 1.8679 - learning_rate: 0.0066 - gradient_norm: 1.8797 - val_det_loss: 1.6674 - val_cls_loss: 1.1635 - val_box_loss: 0.0101 - val_reg_l2_loss: 0.1078 - val_loss: 1.7752
# Epoch 2/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.7153 - cls_loss: 1.1589 - box_loss: 0.0111 - reg_l2_loss: 0.1078 - loss: 1.8231 - learning_rate: 0.0050 - gradient_norm: 2.3458 - val_det_loss: 1.5856 - val_cls_loss: 1.1531 - val_box_loss: 0.0087 - val_reg_l2_loss: 0.1078 - val_loss: 1.6934
# Epoch 3/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 1.6745 - cls_loss: 1.1538 - box_loss: 0.0104 - reg_l2_loss: 0.1078 - loss: 1.7822 - learning_rate: 0.0050 - gradient_norm: 2.8980 - val_det_loss: 1.5235 - val_cls_loss: 1.1445 - val_box_loss: 0.0076 - val_reg_l2_loss: 0.1078 - val_loss: 1.6313
# Epoch 4/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 1.6057 - cls_loss: 1.1369 - box_loss: 0.0094 - reg_l2_loss: 0.1078 - loss: 1.7135 - learning_rate: 0.0050 - gradient_norm: 2.5815 - val_det_loss: 1.4786 - val_cls_loss: 1.1312 - val_box_loss: 0.0069 - val_reg_l2_loss: 0.1078 - val_loss: 1.5864
# Epoch 5/100
# 6/6 [==============================] - 15s 3s/step - det_loss: 1.5750 - cls_loss: 1.1201 - box_loss: 0.0091 - reg_l2_loss: 0.1078 - loss: 1.6828 - learning_rate: 0.0050 - gradient_norm: 2.9899 - val_det_loss: 1.4407 - val_cls_loss: 1.1135 - val_box_loss: 0.0065 - val_reg_l2_loss: 0.1078 - val_loss: 1.5485
# Epoch 6/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 1.5417 - cls_loss: 1.1089 - box_loss: 0.0087 - reg_l2_loss: 0.1078 - loss: 1.6495 - learning_rate: 0.0050 - gradient_norm: 3.6123 - val_det_loss: 1.4167 - val_cls_loss: 1.0925 - val_box_loss: 0.0065 - val_reg_l2_loss: 0.1078 - val_loss: 1.5245
# Epoch 7/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.4877 - cls_loss: 1.0792 - box_loss: 0.0082 - reg_l2_loss: 0.1078 - loss: 1.5955 - learning_rate: 0.0049 - gradient_norm: 3.7644 - val_det_loss: 1.4067 - val_cls_loss: 1.0721 - val_box_loss: 0.0067 - val_reg_l2_loss: 0.1078 - val_loss: 1.5145
# Epoch 8/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 1.4109 - cls_loss: 1.0456 - box_loss: 0.0073 - reg_l2_loss: 0.1078 - loss: 1.5188 - learning_rate: 0.0049 - gradient_norm: 4.6296 - val_det_loss: 1.3516 - val_cls_loss: 1.0325 - val_box_loss: 0.0064 - val_reg_l2_loss: 0.1078 - val_loss: 1.4594
# Epoch 9/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.3012 - cls_loss: 0.9766 - box_loss: 0.0065 - reg_l2_loss: 0.1078 - loss: 1.4090 - learning_rate: 0.0049 - gradient_norm: 4.3009 - val_det_loss: 1.2813 - val_cls_loss: 0.9566 - val_box_loss: 0.0065 - val_reg_l2_loss: 0.1078 - val_loss: 1.3892
# Epoch 10/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.1922 - cls_loss: 0.8966 - box_loss: 0.0059 - reg_l2_loss: 0.1078 - loss: 1.3000 - learning_rate: 0.0049 - gradient_norm: 4.7321 - val_det_loss: 1.1235 - val_cls_loss: 0.8263 - val_box_loss: 0.0059 - val_reg_l2_loss: 0.1078 - val_loss: 1.2314
# Epoch 11/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.0603 - cls_loss: 0.7823 - box_loss: 0.0056 - reg_l2_loss: 0.1078 - loss: 1.1682 - learning_rate: 0.0049 - gradient_norm: 7.6357 - val_det_loss: 1.0136 - val_cls_loss: 0.7133 - val_box_loss: 0.0060 - val_reg_l2_loss: 0.1078 - val_loss: 1.1215
# Epoch 12/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 1.0074 - cls_loss: 0.7543 - box_loss: 0.0051 - reg_l2_loss: 0.1078 - loss: 1.1153 - learning_rate: 0.0048 - gradient_norm: 8.2337 - val_det_loss: 1.2249 - val_cls_loss: 0.8839 - val_box_loss: 0.0068 - val_reg_l2_loss: 0.1079 - val_loss: 1.3328
# Epoch 13/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.9725 - cls_loss: 0.6944 - box_loss: 0.0056 - reg_l2_loss: 0.1079 - loss: 1.0804 - learning_rate: 0.0048 - gradient_norm: 7.3724 - val_det_loss: 1.2244 - val_cls_loss: 0.8117 - val_box_loss: 0.0083 - val_reg_l2_loss: 0.1079 - val_loss: 1.3323
# Epoch 14/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.9360 - cls_loss: 0.6559 - box_loss: 0.0056 - reg_l2_loss: 0.1079 - loss: 1.0439 - learning_rate: 0.0048 - gradient_norm: 7.2944 - val_det_loss: 1.0189 - val_cls_loss: 0.7207 - val_box_loss: 0.0060 - val_reg_l2_loss: 0.1079 - val_loss: 1.1268
# Epoch 15/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.7851 - cls_loss: 0.5724 - box_loss: 0.0043 - reg_l2_loss: 0.1079 - loss: 0.8930 - learning_rate: 0.0047 - gradient_norm: 7.3015 - val_det_loss: 1.0665 - val_cls_loss: 0.7370 - val_box_loss: 0.0066 - val_reg_l2_loss: 0.1079 - val_loss: 1.1744
# Epoch 16/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.8061 - cls_loss: 0.5838 - box_loss: 0.0044 - reg_l2_loss: 0.1079 - loss: 0.9140 - learning_rate: 0.0047 - gradient_norm: 5.2337 - val_det_loss: 1.1084 - val_cls_loss: 0.7701 - val_box_loss: 0.0068 - val_reg_l2_loss: 0.1079 - val_loss: 1.2163
# Epoch 17/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.8868 - cls_loss: 0.6355 - box_loss: 0.0050 - reg_l2_loss: 0.1079 - loss: 0.9947 - learning_rate: 0.0047 - gradient_norm: 7.7851 - val_det_loss: 1.1910 - val_cls_loss: 0.8530 - val_box_loss: 0.0068 - val_reg_l2_loss: 0.1079 - val_loss: 1.2989
# Epoch 18/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.7273 - cls_loss: 0.4972 - box_loss: 0.0046 - reg_l2_loss: 0.1079 - loss: 0.8353 - learning_rate: 0.0046 - gradient_norm: 7.2146 - val_det_loss: 1.2530 - val_cls_loss: 0.8613 - val_box_loss: 0.0078 - val_reg_l2_loss: 0.1079 - val_loss: 1.3610
# Epoch 19/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.6589 - cls_loss: 0.4682 - box_loss: 0.0038 - reg_l2_loss: 0.1079 - loss: 0.7669 - learning_rate: 0.0046 - gradient_norm: 5.9059 - val_det_loss: 1.2420 - val_cls_loss: 0.8679 - val_box_loss: 0.0075 - val_reg_l2_loss: 0.1080 - val_loss: 1.3500
# Epoch 20/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.5823 - cls_loss: 0.3984 - box_loss: 0.0037 - reg_l2_loss: 0.1080 - loss: 0.6902 - learning_rate: 0.0045 - gradient_norm: 5.9018 - val_det_loss: 1.2546 - val_cls_loss: 0.8531 - val_box_loss: 0.0080 - val_reg_l2_loss: 0.1080 - val_loss: 1.3626
# Epoch 21/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.6420 - cls_loss: 0.4631 - box_loss: 0.0036 - reg_l2_loss: 0.1080 - loss: 0.7499 - learning_rate: 0.0045 - gradient_norm: 5.1290 - val_det_loss: 1.2325 - val_cls_loss: 0.8258 - val_box_loss: 0.0081 - val_reg_l2_loss: 0.1080 - val_loss: 1.3405
# Epoch 22/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.6196 - cls_loss: 0.4309 - box_loss: 0.0038 - reg_l2_loss: 0.1080 - loss: 0.7276 - learning_rate: 0.0044 - gradient_norm: 6.4132 - val_det_loss: 1.1003 - val_cls_loss: 0.7587 - val_box_loss: 0.0068 - val_reg_l2_loss: 0.1080 - val_loss: 1.2082
# Epoch 23/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.5713 - cls_loss: 0.3880 - box_loss: 0.0037 - reg_l2_loss: 0.1080 - loss: 0.6793 - learning_rate: 0.0044 - gradient_norm: 5.2244 - val_det_loss: 1.1113 - val_cls_loss: 0.7699 - val_box_loss: 0.0068 - val_reg_l2_loss: 0.1080 - val_loss: 1.2193
# Epoch 24/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.6276 - cls_loss: 0.4558 - box_loss: 0.0034 - reg_l2_loss: 0.1080 - loss: 0.7356 - learning_rate: 0.0043 - gradient_norm: 7.5182 - val_det_loss: 1.1724 - val_cls_loss: 0.7578 - val_box_loss: 0.0083 - val_reg_l2_loss: 0.1080 - val_loss: 1.2804
# Epoch 25/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.5793 - cls_loss: 0.3992 - box_loss: 0.0036 - reg_l2_loss: 0.1080 - loss: 0.6873 - learning_rate: 0.0043 - gradient_norm: 7.5356 - val_det_loss: 1.0419 - val_cls_loss: 0.7317 - val_box_loss: 0.0062 - val_reg_l2_loss: 0.1080 - val_loss: 1.1499
# Epoch 26/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.5309 - cls_loss: 0.3918 - box_loss: 0.0028 - reg_l2_loss: 0.1080 - loss: 0.6389 - learning_rate: 0.0042 - gradient_norm: 6.6131 - val_det_loss: 1.0137 - val_cls_loss: 0.7337 - val_box_loss: 0.0056 - val_reg_l2_loss: 0.1080 - val_loss: 1.1217
# Epoch 27/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.5035 - cls_loss: 0.3602 - box_loss: 0.0029 - reg_l2_loss: 0.1080 - loss: 0.6115 - learning_rate: 0.0042 - gradient_norm: 5.1834 - val_det_loss: 1.0917 - val_cls_loss: 0.7592 - val_box_loss: 0.0066 - val_reg_l2_loss: 0.1080 - val_loss: 1.1997
# Epoch 28/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.5648 - cls_loss: 0.3992 - box_loss: 0.0033 - reg_l2_loss: 0.1080 - loss: 0.6728 - learning_rate: 0.0041 - gradient_norm: 5.9483 - val_det_loss: 1.1497 - val_cls_loss: 0.7604 - val_box_loss: 0.0078 - val_reg_l2_loss: 0.1080 - val_loss: 1.2578
# Epoch 29/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.5320 - cls_loss: 0.3734 - box_loss: 0.0032 - reg_l2_loss: 0.1080 - loss: 0.6400 - learning_rate: 0.0040 - gradient_norm: 5.0011 - val_det_loss: 0.9861 - val_cls_loss: 0.6957 - val_box_loss: 0.0058 - val_reg_l2_loss: 0.1080 - val_loss: 1.0941
# Epoch 30/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.6318 - cls_loss: 0.4565 - box_loss: 0.0035 - reg_l2_loss: 0.1080 - loss: 0.7399 - learning_rate: 0.0040 - gradient_norm: 5.2360 - val_det_loss: 1.0506 - val_cls_loss: 0.7251 - val_box_loss: 0.0065 - val_reg_l2_loss: 0.1080 - val_loss: 1.1587
# Epoch 31/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.6235 - cls_loss: 0.4171 - box_loss: 0.0041 - reg_l2_loss: 0.1081 - loss: 0.7315 - learning_rate: 0.0039 - gradient_norm: 6.2272 - val_det_loss: 1.1937 - val_cls_loss: 0.7736 - val_box_loss: 0.0084 - val_reg_l2_loss: 0.1081 - val_loss: 1.3017
# Epoch 32/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4994 - cls_loss: 0.3507 - box_loss: 0.0030 - reg_l2_loss: 0.1081 - loss: 0.6075 - learning_rate: 0.0039 - gradient_norm: 5.3004 - val_det_loss: 1.1350 - val_cls_loss: 0.7066 - val_box_loss: 0.0086 - val_reg_l2_loss: 0.1081 - val_loss: 1.2431
# Epoch 33/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.5104 - cls_loss: 0.3736 - box_loss: 0.0027 - reg_l2_loss: 0.1081 - loss: 0.6185 - learning_rate: 0.0038 - gradient_norm: 4.7301 - val_det_loss: 1.1711 - val_cls_loss: 0.7648 - val_box_loss: 0.0081 - val_reg_l2_loss: 0.1081 - val_loss: 1.2792
# Epoch 34/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.5063 - cls_loss: 0.3500 - box_loss: 0.0031 - reg_l2_loss: 0.1081 - loss: 0.6144 - learning_rate: 0.0037 - gradient_norm: 5.3080 - val_det_loss: 1.3865 - val_cls_loss: 0.9193 - val_box_loss: 0.0093 - val_reg_l2_loss: 0.1081 - val_loss: 1.4946
# Epoch 35/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.4848 - cls_loss: 0.3170 - box_loss: 0.0034 - reg_l2_loss: 0.1081 - loss: 0.5929 - learning_rate: 0.0036 - gradient_norm: 7.7802 - val_det_loss: 1.1096 - val_cls_loss: 0.7659 - val_box_loss: 0.0069 - val_reg_l2_loss: 0.1081 - val_loss: 1.2177
# Epoch 36/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.4998 - cls_loss: 0.3620 - box_loss: 0.0028 - reg_l2_loss: 0.1081 - loss: 0.6079 - learning_rate: 0.0036 - gradient_norm: 4.1212 - val_det_loss: 1.0533 - val_cls_loss: 0.6954 - val_box_loss: 0.0072 - val_reg_l2_loss: 0.1081 - val_loss: 1.1613
# Epoch 37/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.5073 - cls_loss: 0.3533 - box_loss: 0.0031 - reg_l2_loss: 0.1081 - loss: 0.6154 - learning_rate: 0.0035 - gradient_norm: 4.7367 - val_det_loss: 1.0451 - val_cls_loss: 0.6791 - val_box_loss: 0.0073 - val_reg_l2_loss: 0.1081 - val_loss: 1.1531
# Epoch 38/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.4039 - cls_loss: 0.2750 - box_loss: 0.0026 - reg_l2_loss: 0.1081 - loss: 0.5120 - learning_rate: 0.0034 - gradient_norm: 7.3326 - val_det_loss: 1.0792 - val_cls_loss: 0.7002 - val_box_loss: 0.0076 - val_reg_l2_loss: 0.1081 - val_loss: 1.1873
# Epoch 39/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.4758 - cls_loss: 0.3424 - box_loss: 0.0027 - reg_l2_loss: 0.1081 - loss: 0.5839 - learning_rate: 0.0034 - gradient_norm: 5.0387 - val_det_loss: 1.0242 - val_cls_loss: 0.6690 - val_box_loss: 0.0071 - val_reg_l2_loss: 0.1081 - val_loss: 1.1323
# Epoch 40/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.4511 - cls_loss: 0.3051 - box_loss: 0.0029 - reg_l2_loss: 0.1081 - loss: 0.5592 - learning_rate: 0.0033 - gradient_norm: 3.9511 - val_det_loss: 1.0677 - val_cls_loss: 0.7045 - val_box_loss: 0.0073 - val_reg_l2_loss: 0.1081 - val_loss: 1.1758
# Epoch 41/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4183 - cls_loss: 0.3049 - box_loss: 0.0023 - reg_l2_loss: 0.1081 - loss: 0.5264 - learning_rate: 0.0032 - gradient_norm: 4.1879 - val_det_loss: 0.9048 - val_cls_loss: 0.6222 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.1081 - val_loss: 1.0129
# Epoch 42/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.5244 - cls_loss: 0.3922 - box_loss: 0.0026 - reg_l2_loss: 0.1081 - loss: 0.6325 - learning_rate: 0.0031 - gradient_norm: 4.7640 - val_det_loss: 0.7956 - val_cls_loss: 0.5302 - val_box_loss: 0.0053 - val_reg_l2_loss: 0.1081 - val_loss: 0.9037
# Epoch 43/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4224 - cls_loss: 0.3103 - box_loss: 0.0022 - reg_l2_loss: 0.1081 - loss: 0.5305 - learning_rate: 0.0031 - gradient_norm: 5.7680 - val_det_loss: 0.8043 - val_cls_loss: 0.5566 - val_box_loss: 0.0050 - val_reg_l2_loss: 0.1081 - val_loss: 0.9124
# Epoch 44/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.4017 - cls_loss: 0.2950 - box_loss: 0.0021 - reg_l2_loss: 0.1081 - loss: 0.5098 - learning_rate: 0.0030 - gradient_norm: 5.2253 - val_det_loss: 0.7657 - val_cls_loss: 0.5546 - val_box_loss: 0.0042 - val_reg_l2_loss: 0.1081 - val_loss: 0.8738
# Epoch 45/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.4178 - cls_loss: 0.2982 - box_loss: 0.0024 - reg_l2_loss: 0.1081 - loss: 0.5260 - learning_rate: 0.0029 - gradient_norm: 4.4191 - val_det_loss: 0.7240 - val_cls_loss: 0.5395 - val_box_loss: 0.0037 - val_reg_l2_loss: 0.1081 - val_loss: 0.8321
# Epoch 46/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4002 - cls_loss: 0.2916 - box_loss: 0.0022 - reg_l2_loss: 0.1081 - loss: 0.5083 - learning_rate: 0.0028 - gradient_norm: 5.3647 - val_det_loss: 0.7409 - val_cls_loss: 0.5122 - val_box_loss: 0.0046 - val_reg_l2_loss: 0.1081 - val_loss: 0.8490
# Epoch 47/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3842 - cls_loss: 0.2712 - box_loss: 0.0023 - reg_l2_loss: 0.1081 - loss: 0.4924 - learning_rate: 0.0027 - gradient_norm: 5.3506 - val_det_loss: 0.4914 - val_cls_loss: 0.3366 - val_box_loss: 0.0031 - val_reg_l2_loss: 0.1081 - val_loss: 0.5995
# Epoch 48/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3544 - cls_loss: 0.2635 - box_loss: 0.0018 - reg_l2_loss: 0.1081 - loss: 0.4625 - learning_rate: 0.0027 - gradient_norm: 4.2064 - val_det_loss: 0.6662 - val_cls_loss: 0.5349 - val_box_loss: 0.0026 - val_reg_l2_loss: 0.1081 - val_loss: 0.7744
# Epoch 49/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3588 - cls_loss: 0.2595 - box_loss: 0.0020 - reg_l2_loss: 0.1081 - loss: 0.4669 - learning_rate: 0.0026 - gradient_norm: 3.7297 - val_det_loss: 0.6434 - val_cls_loss: 0.5067 - val_box_loss: 0.0027 - val_reg_l2_loss: 0.1081 - val_loss: 0.7516
# Epoch 50/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4228 - cls_loss: 0.2982 - box_loss: 0.0025 - reg_l2_loss: 0.1081 - loss: 0.5309 - learning_rate: 0.0025 - gradient_norm: 4.4381 - val_det_loss: 0.6603 - val_cls_loss: 0.5352 - val_box_loss: 0.0025 - val_reg_l2_loss: 0.1081 - val_loss: 0.7685
# Epoch 51/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3681 - cls_loss: 0.2562 - box_loss: 0.0022 - reg_l2_loss: 0.1081 - loss: 0.4762 - learning_rate: 0.0024 - gradient_norm: 6.1010 - val_det_loss: 0.7458 - val_cls_loss: 0.5867 - val_box_loss: 0.0032 - val_reg_l2_loss: 0.1081 - val_loss: 0.8539
# Epoch 52/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.4498 - cls_loss: 0.2968 - box_loss: 0.0031 - reg_l2_loss: 0.1081 - loss: 0.5579 - learning_rate: 0.0023 - gradient_norm: 5.2036 - val_det_loss: 0.7904 - val_cls_loss: 0.5802 - val_box_loss: 0.0042 - val_reg_l2_loss: 0.1081 - val_loss: 0.8985
# Epoch 53/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3850 - cls_loss: 0.2591 - box_loss: 0.0025 - reg_l2_loss: 0.1081 - loss: 0.4932 - learning_rate: 0.0023 - gradient_norm: 6.1135 - val_det_loss: 0.6520 - val_cls_loss: 0.4853 - val_box_loss: 0.0033 - val_reg_l2_loss: 0.1081 - val_loss: 0.7601
# Epoch 54/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3270 - cls_loss: 0.2327 - box_loss: 0.0019 - reg_l2_loss: 0.1081 - loss: 0.4351 - learning_rate: 0.0022 - gradient_norm: 5.1319 - val_det_loss: 0.8012 - val_cls_loss: 0.5855 - val_box_loss: 0.0043 - val_reg_l2_loss: 0.1081 - val_loss: 0.9093
# Epoch 55/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3174 - cls_loss: 0.2200 - box_loss: 0.0019 - reg_l2_loss: 0.1081 - loss: 0.4255 - learning_rate: 0.0021 - gradient_norm: 3.5039 - val_det_loss: 0.8945 - val_cls_loss: 0.6157 - val_box_loss: 0.0056 - val_reg_l2_loss: 0.1081 - val_loss: 1.0027
# Epoch 56/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3466 - cls_loss: 0.2373 - box_loss: 0.0022 - reg_l2_loss: 0.1081 - loss: 0.4547 - learning_rate: 0.0020 - gradient_norm: 4.6814 - val_det_loss: 0.9054 - val_cls_loss: 0.6028 - val_box_loss: 0.0061 - val_reg_l2_loss: 0.1081 - val_loss: 1.0136
# Epoch 57/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4758 - cls_loss: 0.3620 - box_loss: 0.0023 - reg_l2_loss: 0.1081 - loss: 0.5840 - learning_rate: 0.0020 - gradient_norm: 7.8316 - val_det_loss: 0.9353 - val_cls_loss: 0.6287 - val_box_loss: 0.0061 - val_reg_l2_loss: 0.1081 - val_loss: 1.0435
# Epoch 58/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3010 - cls_loss: 0.2174 - box_loss: 0.0017 - reg_l2_loss: 0.1081 - loss: 0.4092 - learning_rate: 0.0019 - gradient_norm: 4.9291 - val_det_loss: 0.9666 - val_cls_loss: 0.6489 - val_box_loss: 0.0064 - val_reg_l2_loss: 0.1081 - val_loss: 1.0747
# Epoch 59/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.4487 - cls_loss: 0.3429 - box_loss: 0.0021 - reg_l2_loss: 0.1081 - loss: 0.5568 - learning_rate: 0.0018 - gradient_norm: 6.6252 - val_det_loss: 1.0102 - val_cls_loss: 0.6680 - val_box_loss: 0.0068 - val_reg_l2_loss: 0.1081 - val_loss: 1.1183
# Epoch 60/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3299 - cls_loss: 0.2314 - box_loss: 0.0020 - reg_l2_loss: 0.1081 - loss: 0.4380 - learning_rate: 0.0017 - gradient_norm: 5.3474 - val_det_loss: 1.0277 - val_cls_loss: 0.6735 - val_box_loss: 0.0071 - val_reg_l2_loss: 0.1081 - val_loss: 1.1358
# Epoch 61/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3335 - cls_loss: 0.2425 - box_loss: 0.0018 - reg_l2_loss: 0.1082 - loss: 0.4417 - learning_rate: 0.0016 - gradient_norm: 3.7672 - val_det_loss: 1.0126 - val_cls_loss: 0.6798 - val_box_loss: 0.0067 - val_reg_l2_loss: 0.1082 - val_loss: 1.1207
# Epoch 62/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3380 - cls_loss: 0.2398 - box_loss: 0.0020 - reg_l2_loss: 0.1082 - loss: 0.4461 - learning_rate: 0.0016 - gradient_norm: 5.3224 - val_det_loss: 0.9686 - val_cls_loss: 0.6573 - val_box_loss: 0.0062 - val_reg_l2_loss: 0.1082 - val_loss: 1.0767
# Epoch 63/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3563 - cls_loss: 0.2495 - box_loss: 0.0021 - reg_l2_loss: 0.1082 - loss: 0.4645 - learning_rate: 0.0015 - gradient_norm: 3.2537 - val_det_loss: 0.9276 - val_cls_loss: 0.6498 - val_box_loss: 0.0056 - val_reg_l2_loss: 0.1082 - val_loss: 1.0357
# Epoch 64/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3022 - cls_loss: 0.2032 - box_loss: 0.0020 - reg_l2_loss: 0.1082 - loss: 0.4104 - learning_rate: 0.0014 - gradient_norm: 3.3874 - val_det_loss: 0.8648 - val_cls_loss: 0.6220 - val_box_loss: 0.0049 - val_reg_l2_loss: 0.1082 - val_loss: 0.9729
# Epoch 65/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2692 - cls_loss: 0.1920 - box_loss: 0.0015 - reg_l2_loss: 0.1082 - loss: 0.3774 - learning_rate: 0.0014 - gradient_norm: 3.7305 - val_det_loss: 0.8095 - val_cls_loss: 0.5980 - val_box_loss: 0.0042 - val_reg_l2_loss: 0.1082 - val_loss: 0.9177
# Epoch 66/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3474 - cls_loss: 0.2536 - box_loss: 0.0019 - reg_l2_loss: 0.1082 - loss: 0.4556 - learning_rate: 0.0013 - gradient_norm: 6.4466 - val_det_loss: 0.7453 - val_cls_loss: 0.5574 - val_box_loss: 0.0038 - val_reg_l2_loss: 0.1082 - val_loss: 0.8535
# Epoch 67/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3206 - cls_loss: 0.2251 - box_loss: 0.0019 - reg_l2_loss: 0.1082 - loss: 0.4288 - learning_rate: 0.0012 - gradient_norm: 4.1326 - val_det_loss: 0.5699 - val_cls_loss: 0.4006 - val_box_loss: 0.0034 - val_reg_l2_loss: 0.1082 - val_loss: 0.6780
# Epoch 68/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.3402 - cls_loss: 0.2400 - box_loss: 0.0020 - reg_l2_loss: 0.1082 - loss: 0.4483 - learning_rate: 0.0012 - gradient_norm: 3.6574 - val_det_loss: 0.4849 - val_cls_loss: 0.3248 - val_box_loss: 0.0032 - val_reg_l2_loss: 0.1082 - val_loss: 0.5931
# Epoch 69/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3197 - cls_loss: 0.2362 - box_loss: 0.0017 - reg_l2_loss: 0.1082 - loss: 0.4279 - learning_rate: 0.0011 - gradient_norm: 5.7814 - val_det_loss: 0.4504 - val_cls_loss: 0.2888 - val_box_loss: 0.0032 - val_reg_l2_loss: 0.1082 - val_loss: 0.5585
# Epoch 70/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2479 - cls_loss: 0.1927 - box_loss: 0.0011 - reg_l2_loss: 0.1082 - loss: 0.3560 - learning_rate: 0.0010 - gradient_norm: 3.2778 - val_det_loss: 0.4115 - val_cls_loss: 0.2680 - val_box_loss: 0.0029 - val_reg_l2_loss: 0.1082 - val_loss: 0.5197
# Epoch 71/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.3090 - cls_loss: 0.2299 - box_loss: 0.0016 - reg_l2_loss: 0.1082 - loss: 0.4171 - learning_rate: 9.5616e-04 - gradient_norm: 5.4534 - val_det_loss: 0.4301 - val_cls_loss: 0.2892 - val_box_loss: 0.0028 - val_reg_l2_loss: 0.1082 - val_loss: 0.5382
# Epoch 72/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2822 - cls_loss: 0.2097 - box_loss: 0.0015 - reg_l2_loss: 0.1082 - loss: 0.3904 - learning_rate: 8.9455e-04 - gradient_norm: 4.0142 - val_det_loss: 0.4234 - val_cls_loss: 0.2825 - val_box_loss: 0.0028 - val_reg_l2_loss: 0.1082 - val_loss: 0.5315
# Epoch 73/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2741 - cls_loss: 0.2085 - box_loss: 0.0013 - reg_l2_loss: 0.1082 - loss: 0.3823 - learning_rate: 8.3456e-04 - gradient_norm: 4.6535 - val_det_loss: 0.4154 - val_cls_loss: 0.2734 - val_box_loss: 0.0028 - val_reg_l2_loss: 0.1082 - val_loss: 0.5235
# Epoch 74/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2932 - cls_loss: 0.2105 - box_loss: 0.0017 - reg_l2_loss: 0.1082 - loss: 0.4014 - learning_rate: 7.7625e-04 - gradient_norm: 2.9944 - val_det_loss: 0.4107 - val_cls_loss: 0.2669 - val_box_loss: 0.0029 - val_reg_l2_loss: 0.1082 - val_loss: 0.5188
# Epoch 75/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2480 - cls_loss: 0.1807 - box_loss: 0.0013 - reg_l2_loss: 0.1082 - loss: 0.3562 - learning_rate: 7.1967e-04 - gradient_norm: 3.3362 - val_det_loss: 0.4183 - val_cls_loss: 0.2710 - val_box_loss: 0.0029 - val_reg_l2_loss: 0.1082 - val_loss: 0.5265
# Epoch 76/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2927 - cls_loss: 0.2074 - box_loss: 0.0017 - reg_l2_loss: 0.1082 - loss: 0.4008 - learning_rate: 6.6489e-04 - gradient_norm: 4.3174 - val_det_loss: 0.4462 - val_cls_loss: 0.2854 - val_box_loss: 0.0032 - val_reg_l2_loss: 0.1082 - val_loss: 0.5543
# Epoch 77/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2331 - cls_loss: 0.1797 - box_loss: 0.0011 - reg_l2_loss: 0.1082 - loss: 0.3412 - learning_rate: 6.1195e-04 - gradient_norm: 2.5285 - val_det_loss: 0.4581 - val_cls_loss: 0.2938 - val_box_loss: 0.0033 - val_reg_l2_loss: 0.1082 - val_loss: 0.5662
# Epoch 78/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2593 - cls_loss: 0.1806 - box_loss: 0.0016 - reg_l2_loss: 0.1082 - loss: 0.3675 - learning_rate: 5.6091e-04 - gradient_norm: 3.2629 - val_det_loss: 0.4510 - val_cls_loss: 0.2923 - val_box_loss: 0.0032 - val_reg_l2_loss: 0.1082 - val_loss: 0.5592
# Epoch 79/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2856 - cls_loss: 0.2164 - box_loss: 0.0014 - reg_l2_loss: 0.1082 - loss: 0.3938 - learning_rate: 5.1183e-04 - gradient_norm: 4.8758 - val_det_loss: 0.4422 - val_cls_loss: 0.2869 - val_box_loss: 0.0031 - val_reg_l2_loss: 0.1082 - val_loss: 0.5504
# Epoch 80/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2916 - cls_loss: 0.2199 - box_loss: 0.0014 - reg_l2_loss: 0.1082 - loss: 0.3998 - learning_rate: 4.6475e-04 - gradient_norm: 5.4349 - val_det_loss: 0.4491 - val_cls_loss: 0.2893 - val_box_loss: 0.0032 - val_reg_l2_loss: 0.1082 - val_loss: 0.5572
# Epoch 81/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.2919 - cls_loss: 0.2065 - box_loss: 0.0017 - reg_l2_loss: 0.1082 - loss: 0.4001 - learning_rate: 4.1972e-04 - gradient_norm: 4.0156 - val_det_loss: 0.4526 - val_cls_loss: 0.2926 - val_box_loss: 0.0032 - val_reg_l2_loss: 0.1082 - val_loss: 0.5607
# Epoch 82/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3428 - cls_loss: 0.2401 - box_loss: 0.0021 - reg_l2_loss: 0.1082 - loss: 0.4510 - learning_rate: 3.7678e-04 - gradient_norm: 5.7295 - val_det_loss: 0.4558 - val_cls_loss: 0.2907 - val_box_loss: 0.0033 - val_reg_l2_loss: 0.1082 - val_loss: 0.5639
# Epoch 83/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2692 - cls_loss: 0.2001 - box_loss: 0.0014 - reg_l2_loss: 0.1082 - loss: 0.3774 - learning_rate: 3.3598e-04 - gradient_norm: 4.2080 - val_det_loss: 0.4437 - val_cls_loss: 0.2771 - val_box_loss: 0.0033 - val_reg_l2_loss: 0.1082 - val_loss: 0.5518
# Epoch 84/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2807 - cls_loss: 0.2032 - box_loss: 0.0016 - reg_l2_loss: 0.1082 - loss: 0.3889 - learning_rate: 2.9736e-04 - gradient_norm: 3.9159 - val_det_loss: 0.4326 - val_cls_loss: 0.2669 - val_box_loss: 0.0033 - val_reg_l2_loss: 0.1082 - val_loss: 0.5408
# Epoch 85/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3382 - cls_loss: 0.2422 - box_loss: 0.0019 - reg_l2_loss: 0.1082 - loss: 0.4464 - learning_rate: 2.6096e-04 - gradient_norm: 4.6594 - val_det_loss: 0.4215 - val_cls_loss: 0.2606 - val_box_loss: 0.0032 - val_reg_l2_loss: 0.1082 - val_loss: 0.5296
# Epoch 86/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3078 - cls_loss: 0.2184 - box_loss: 0.0018 - reg_l2_loss: 0.1082 - loss: 0.4159 - learning_rate: 2.2681e-04 - gradient_norm: 5.5936 - val_det_loss: 0.4267 - val_cls_loss: 0.2667 - val_box_loss: 0.0032 - val_reg_l2_loss: 0.1082 - val_loss: 0.5349
# Epoch 87/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2387 - cls_loss: 0.1811 - box_loss: 0.0012 - reg_l2_loss: 0.1082 - loss: 0.3468 - learning_rate: 1.9495e-04 - gradient_norm: 2.8588 - val_det_loss: 0.4360 - val_cls_loss: 0.2748 - val_box_loss: 0.0032 - val_reg_l2_loss: 0.1082 - val_loss: 0.5441
# Epoch 88/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3355 - cls_loss: 0.2505 - box_loss: 0.0017 - reg_l2_loss: 0.1082 - loss: 0.4436 - learning_rate: 1.6541e-04 - gradient_norm: 4.8558 - val_det_loss: 0.4493 - val_cls_loss: 0.2845 - val_box_loss: 0.0033 - val_reg_l2_loss: 0.1082 - val_loss: 0.5574
# Epoch 89/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3017 - cls_loss: 0.2239 - box_loss: 0.0016 - reg_l2_loss: 0.1082 - loss: 0.4099 - learning_rate: 1.3822e-04 - gradient_norm: 3.0999 - val_det_loss: 0.4578 - val_cls_loss: 0.2888 - val_box_loss: 0.0034 - val_reg_l2_loss: 0.1082 - val_loss: 0.5659
# Epoch 90/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2771 - cls_loss: 0.2060 - box_loss: 0.0014 - reg_l2_loss: 0.1082 - loss: 0.3852 - learning_rate: 1.1341e-04 - gradient_norm: 3.1870 - val_det_loss: 0.4555 - val_cls_loss: 0.2836 - val_box_loss: 0.0034 - val_reg_l2_loss: 0.1082 - val_loss: 0.5637
# Epoch 91/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2567 - cls_loss: 0.1883 - box_loss: 0.0014 - reg_l2_loss: 0.1082 - loss: 0.3648 - learning_rate: 9.1009e-05 - gradient_norm: 3.6560 - val_det_loss: 0.4567 - val_cls_loss: 0.2843 - val_box_loss: 0.0034 - val_reg_l2_loss: 0.1082 - val_loss: 0.5648
# Epoch 92/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2420 - cls_loss: 0.1714 - box_loss: 0.0014 - reg_l2_loss: 0.1082 - loss: 0.3501 - learning_rate: 7.1028e-05 - gradient_norm: 3.2194 - val_det_loss: 0.4559 - val_cls_loss: 0.2852 - val_box_loss: 0.0034 - val_reg_l2_loss: 0.1082 - val_loss: 0.5641
# Epoch 93/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3391 - cls_loss: 0.2469 - box_loss: 0.0018 - reg_l2_loss: 0.1082 - loss: 0.4472 - learning_rate: 5.3493e-05 - gradient_norm: 3.5333 - val_det_loss: 0.4487 - val_cls_loss: 0.2789 - val_box_loss: 0.0034 - val_reg_l2_loss: 0.1082 - val_loss: 0.5569
# Epoch 94/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3027 - cls_loss: 0.2452 - box_loss: 0.0012 - reg_l2_loss: 0.1082 - loss: 0.4108 - learning_rate: 3.8422e-05 - gradient_norm: 3.1877 - val_det_loss: 0.4414 - val_cls_loss: 0.2729 - val_box_loss: 0.0034 - val_reg_l2_loss: 0.1082 - val_loss: 0.5496
# Epoch 95/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3388 - cls_loss: 0.2394 - box_loss: 0.0020 - reg_l2_loss: 0.1082 - loss: 0.4470 - learning_rate: 2.5829e-05 - gradient_norm: 4.9719 - val_det_loss: 0.4379 - val_cls_loss: 0.2718 - val_box_loss: 0.0033 - val_reg_l2_loss: 0.1082 - val_loss: 0.5461
# Epoch 96/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2759 - cls_loss: 0.1959 - box_loss: 0.0016 - reg_l2_loss: 0.1082 - loss: 0.3841 - learning_rate: 1.5727e-05 - gradient_norm: 4.3724 - val_det_loss: 0.4288 - val_cls_loss: 0.2683 - val_box_loss: 0.0032 - val_reg_l2_loss: 0.1082 - val_loss: 0.5370
# Epoch 97/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2600 - cls_loss: 0.1732 - box_loss: 0.0017 - reg_l2_loss: 0.1082 - loss: 0.3681 - learning_rate: 8.1273e-06 - gradient_norm: 3.0290 - val_det_loss: 0.4290 - val_cls_loss: 0.2686 - val_box_loss: 0.0032 - val_reg_l2_loss: 0.1082 - val_loss: 0.5372
# Epoch 98/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2954 - cls_loss: 0.2228 - box_loss: 0.0015 - reg_l2_loss: 0.1082 - loss: 0.4036 - learning_rate: 3.0362e-06 - gradient_norm: 3.3146 - val_det_loss: 0.4280 - val_cls_loss: 0.2690 - val_box_loss: 0.0032 - val_reg_l2_loss: 0.1082 - val_loss: 0.5362
# Epoch 99/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3583 - cls_loss: 0.2671 - box_loss: 0.0018 - reg_l2_loss: 0.1082 - loss: 0.4664 - learning_rate: 4.5955e-07 - gradient_norm: 4.5912 - val_det_loss: 0.4226 - val_cls_loss: 0.2648 - val_box_loss: 0.0032 - val_reg_l2_loss: 0.1082 - val_loss: 0.5308
# Epoch 100/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2434 - cls_loss: 0.1819 - box_loss: 0.0012 - reg_l2_loss: 0.1082 - loss: 0.3515 - learning_rate: 3.9961e-07 - gradient_norm: 3.1855 - val_det_loss: 0.4229 - val_cls_loss: 0.2660 - val_box_loss: 0.0031 - val_reg_l2_loss: 0.1082 - val_loss: 0.5311

# %% [markdown]
# ### Step 4. Evaluate the model with the validation data.
#
# After training the object detection model using the images in the training dataset, use the 10 images in the validation dataset to evaluate how the model performs against new data it has never seen before.
#
# As the default batch size is 64, it will take 1 step to go through the 10 images in the validation dataset.
#
# The evaluation metrics are same as [COCO](https://cocodataset.org/#detection-eval).

# %%
model.evaluate(val_data)
# Out:
# 1/1 [==============================] - 6s 6s/step
# {'AP': 0.46598303,
#  'AP50': 0.8341584,
#  'AP75': 0.5136139,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.46598303,
#  'ARmax1': 0.42916667,
#  'ARmax10': 0.5541667,
#  'ARmax100': 0.5541667,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.5541667,
#  'AP_/painting': 0.3237624,
#  'AP_/Real_Tunnel': 0.60820365}

# %%
# import matplotlib.pyplot as plt
# print(model.history.keys())
# # summarize history for loss
# plt.plot(model.history['loss'])
# plt.plot(model.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %% [markdown]
# ### Step 5: Export as a TensorFlow Lite model.
#
# Export the trained object detection model to the TensorFlow Lite format by specifying which folder you want to export the quantized model to. The default post-training quantization technique is [full integer quantization](https://www.tensorflow.org/lite/performance/post_training_integer_quant). This allows the TensorFlow Lite model to be smaller, run faster on Raspberry Pi CPU and also compatible with the Google Coral EdgeTPU.

# %%
model.export(export_dir='Thesis/', tflite_filename='android.tfliteDIFF1024')

# %% [markdown]
# ### Step 6:  Evaluate the TensorFlow Lite model.
#
# Several factors can affect the model accuracy when exporting to TFLite:
# * [Quantization](https://www.tensorflow.org/lite/performance/model_optimization) helps shrinking the model size by 4 times at the expense of some accuracy drop.
# * The original TensorFlow model uses per-class [non-max supression (NMS)](https://www.coursera.org/lecture/convolutional-neural-networks/non-max-suppression-dvrjH) for post-processing, while the TFLite model uses global NMS that's much faster but less accurate.
# Keras outputs maximum 100 detections while tflite outputs maximum 25 detections.
#
# Therefore you'll have to evaluate the exported TFLite model and compare its accuracy with the original TensorFlow model.

# %%
model.evaluate_tflite('Thesis/android.tfliteDIFF1024', val_data)
# Out:
# 7/7 [==============================] - 361s 51s/step
# {'AP': 0.45894626,
#  'AP50': 0.8341584,
#  'AP75': 0.42079207,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.45894626,
#  'ARmax1': 0.41666666,
#  'ARmax10': 0.51666665,
#  'ARmax100': 0.51666665,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.51666665,
#  'AP_/painting': 0.3159123,
#  'AP_/Real_Tunnel': 0.6019802}

# %%
# Download the TFLite model to your local computer.
# from google.colab import files
# files.download('android.tfliteDIFF1024')

# %% [markdown]
# ## Test the Android figurine detection model
#
# After training the model, let's test it with an image that the model hasn't seen before to get a sense of how good the model is.

# %%
#@title Load the trained TFLite model and define some visualization functions

#@markdown This code comes from the TFLite Object Detection [Raspberry Pi sample](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/raspberry_pi).

import platform
from typing import List, NamedTuple
import json

import cv2

Interpreter = tf.lite.Interpreter
load_delegate = tf.lite.experimental.load_delegate

# pylint: enable=g-import-not-at-top


class ObjectDetectorOptions(NamedTuple):
  """A config to initialize an object detector."""

  enable_edgetpu: bool = False
  """Enable the model to run on EdgeTPU."""

  label_allow_list: List[str] = None
  """The optional allow list of labels."""

  label_deny_list: List[str] = None
  """The optional deny list of labels."""

  max_results: int = -1
  """The maximum number of top-scored detection results to return."""

  num_threads: int = 1
  """The number of CPU threads to be used."""

  score_threshold: float = 0.0
  """The score threshold of detection results to return."""


class Rect(NamedTuple):
  """A rectangle in 2D space."""
  left: float
  top: float
  right: float
  bottom: float


class Category(NamedTuple):
  """A result of a classification task."""
  label: str
  score: float
  index: int


class Detection(NamedTuple):
  """A detected object as the result of an ObjectDetector."""
  bounding_box: Rect
  categories: List[Category]


def edgetpu_lib_name():
  """Returns the library name of EdgeTPU in the current platform."""
  return {
      'Darwin': 'libedgetpu.1.dylib',
      'Linux': 'libedgetpu.so.1',
      'Windows': 'edgetpu.dll',
  }.get(platform.system(), None)


class ObjectDetector:
  """A wrapper class for a TFLite object detection model."""

  _OUTPUT_LOCATION_NAME = 'location'
  _OUTPUT_CATEGORY_NAME = 'category'
  _OUTPUT_SCORE_NAME = 'score'
  _OUTPUT_NUMBER_NAME = 'number of detections'

  def __init__(
      self,
      model_path: str,
      options: ObjectDetectorOptions = ObjectDetectorOptions()
  ) -> None:
    """Initialize a TFLite object detection model.
    Args:
        model_path: Path to the TFLite model.
        options: The config to initialize an object detector. (Optional)
    Raises:
        ValueError: If the TFLite model is invalid.
        OSError: If the current OS isn't supported by EdgeTPU.
    """

    # Load metadata from model.
    displayer = metadata.MetadataDisplayer.with_model_file(model_path)

    # Save model metadata for preprocessing later.
    model_metadata = json.loads(displayer.get_metadata_json())
    process_units = model_metadata['subgraph_metadata'][0]['input_tensor_metadata'][0]['process_units']
    mean = 0.0
    std = 1.0
    for option in process_units:
      if option['options_type'] == 'NormalizationOptions':
        mean = option['options']['mean'][0]
        std = option['options']['std'][0]
    self._mean = mean
    self._std = std

    # Load label list from metadata.
    file_name = displayer.get_packed_associated_file_list()[0]
    label_map_file = displayer.get_associated_file_buffer(file_name).decode()
    label_list = list(filter(lambda x: len(x) > 0, label_map_file.splitlines()))
    self._label_list = label_list

    # Initialize TFLite model.
    if options.enable_edgetpu:
      if edgetpu_lib_name() is None:
        raise OSError("The current OS isn't supported by Coral EdgeTPU.")
      interpreter = Interpreter(
          model_path=model_path,
          experimental_delegates=[load_delegate(edgetpu_lib_name())],
          num_threads=options.num_threads)
    else:
      interpreter = Interpreter(
          model_path=model_path, num_threads=options.num_threads)

    interpreter.allocate_tensors()
    input_detail = interpreter.get_input_details()[0]

    # From TensorFlow 2.6, the order of the outputs become undefined.
    # Therefore we need to sort the tensor indices of TFLite outputs and to know
    # exactly the meaning of each output tensor. For example, if
    # output indices are [601, 599, 598, 600], tensor names and indices aligned
    # are:
    #   - location: 598
    #   - category: 599
    #   - score: 600
    #   - detection_count: 601
    # because of the op's ports of TFLITE_DETECTION_POST_PROCESS
    # (https://github.com/tensorflow/tensorflow/blob/a4fe268ea084e7d323133ed7b986e0ae259a2bc7/tensorflow/lite/kernels/detection_postprocess.cc#L47-L50).
    sorted_output_indices = sorted(
        [output['index'] for output in interpreter.get_output_details()])
    self._output_indices = {
        self._OUTPUT_LOCATION_NAME: sorted_output_indices[0],
        self._OUTPUT_CATEGORY_NAME: sorted_output_indices[1],
        self._OUTPUT_SCORE_NAME: sorted_output_indices[2],
        self._OUTPUT_NUMBER_NAME: sorted_output_indices[3],
    }

    self._input_size = input_detail['shape'][2], input_detail['shape'][1]
    self._is_quantized_input = input_detail['dtype'] == np.uint8
    self._interpreter = interpreter
    self._options = options

  def detect(self, input_image: np.ndarray) -> List[Detection]:
    """Run detection on an input image.
    Args:
        input_image: A [height, width, 3] RGB image. Note that height and width
          can be anything since the image will be immediately resized according
          to the needs of the model within this function.
    Returns:
        A Person instance.
    """
    image_height, image_width, _ = input_image.shape

    input_tensor = self._preprocess(input_image)

    self._set_input_tensor(input_tensor)
    self._interpreter.invoke()

    # Get all output details
    boxes = self._get_output_tensor(self._OUTPUT_LOCATION_NAME)
    classes = self._get_output_tensor(self._OUTPUT_CATEGORY_NAME)
    scores = self._get_output_tensor(self._OUTPUT_SCORE_NAME)
    count = int(self._get_output_tensor(self._OUTPUT_NUMBER_NAME))

    return self._postprocess(boxes, classes, scores, count, image_width,
                             image_height)

  def _preprocess(self, input_image: np.ndarray) -> np.ndarray:
    """Preprocess the input image as required by the TFLite model."""

    # Resize the input
    input_tensor = cv2.resize(input_image, self._input_size)

    # Normalize the input if it's a float model (aka. not quantized)
    if not self._is_quantized_input:
      input_tensor = (np.float32(input_tensor) - self._mean) / self._std

    # Add batch dimension
    input_tensor = np.expand_dims(input_tensor, axis=0)

    return input_tensor

  def _set_input_tensor(self, image):
    """Sets the input tensor."""
    tensor_index = self._interpreter.get_input_details()[0]['index']
    input_tensor = self._interpreter.tensor(tensor_index)()[0]
    input_tensor[:, :] = image

  def _get_output_tensor(self, name):
    """Returns the output tensor at the given index."""
    output_index = self._output_indices[name]
    tensor = np.squeeze(self._interpreter.get_tensor(output_index))
    return tensor

  def _postprocess(self, boxes: np.ndarray, classes: np.ndarray,
                   scores: np.ndarray, count: int, image_width: int,
                   image_height: int) -> List[Detection]:
    """Post-process the output of TFLite model into a list of Detection objects.
    Args:
        boxes: Bounding boxes of detected objects from the TFLite model.
        classes: Class index of the detected objects from the TFLite model.
        scores: Confidence scores of the detected objects from the TFLite model.
        count: Number of detected objects from the TFLite model.
        image_width: Width of the input image.
        image_height: Height of the input image.
    Returns:
        A list of Detection objects detected by the TFLite model.
    """
    results = []

    # Parse the model output into a list of Detection entities.
    for i in range(count):
      if scores[i] >= self._options.score_threshold:
        y_min, x_min, y_max, x_max = boxes[i]
        bounding_box = Rect(
            top=int(y_min * image_height),
            left=int(x_min * image_width),
            bottom=int(y_max * image_height),
            right=int(x_max * image_width))
        class_id = int(classes[i])
        category = Category(
            score=scores[i],
            label=self._label_list[class_id],  # 0 is reserved for background
            index=class_id)
        result = Detection(bounding_box=bounding_box, categories=[category])
        results.append(result)

    # Sort detection results by score ascending
    sorted_results = sorted(
        results,
        key=lambda detection: detection.categories[0].score,
        reverse=True)

    # Filter out detections in deny list
    filtered_results = sorted_results
    if self._options.label_deny_list is not None:
      filtered_results = list(
          filter(
              lambda detection: detection.categories[0].label not in self.
              _options.label_deny_list, filtered_results))

    # Keep only detections in allow list
    if self._options.label_allow_list is not None:
      filtered_results = list(
          filter(
              lambda detection: detection.categories[0].label in self._options.
              label_allow_list, filtered_results))

    # Only return maximum of max_results detection.
    if self._options.max_results > 0:
      result_count = min(len(filtered_results), self._options.max_results)
      filtered_results = filtered_results[:result_count]

    return filtered_results


_MARGIN = 10  # pixels
_ROW_SIZE = 10  # pixels
_FONT_SIZE = 1
_FONT_THICKNESS = 1
_TEXT_COLOR = (0, 0, 255)  # red


def visualize(
    image: np.ndarray,
    detections: List[Detection],
) -> np.ndarray:
  """Draws bounding boxes on the input image and return it.
  Args:
    image: The input RGB image.
    detections: The list of all "Detection" entities to be visualize.
  Returns:
    Image with bounding boxes.
  """
  for detection in detections:
    # Draw bounding_box
    start_point = detection.bounding_box.left, detection.bounding_box.top
    end_point = detection.bounding_box.right, detection.bounding_box.bottom
    cv2.rectangle(image, start_point, end_point, _TEXT_COLOR, 3)

    # Draw label and score
    category = detection.categories[0]
    class_name = category.label
    probability = round(category.score, 2)
    result_text = class_name + ' (' + str(probability) + ')'
    text_location = (_MARGIN + detection.bounding_box.left,
                     _MARGIN + _ROW_SIZE + detection.bounding_box.top)
    cv2.putText(image, result_text, text_location, cv2.FONT_HERSHEY_PLAIN,
                _FONT_SIZE, _TEXT_COLOR, _FONT_THICKNESS)

  return image

# %%
from PIL import Image
INPUT_IMAGE_ONE = 'Thesis/All_Photos/1024_DIFFNet/TEST_1024/0_disp.jpeg' #@param {type:"string"}
DETECTION_THRESHOLD = 0.5 #@param {type:"number"}
TFLITE_MODEL_PATH = "Thesis/android.tfliteDIFF1024" #@param {type:"string"}

TEMP_FILE = '/tmp/image.png'

# !wget -q -O $TEMP_FILE $INPUT_IMAGE_ONE

#image = Image.open(TEMP_FILE).convert('RGB')
image_one = Image.open(INPUT_IMAGE_ONE).convert('RGB')
image_one.thumbnail((512, 512), Image.ANTIALIAS)
image_np_one = np.asarray(image_one)

# Load the TFLite model
options = ObjectDetectorOptions(
      num_threads=4,
      score_threshold=DETECTION_THRESHOLD,
)
detector = ObjectDetector(model_path=TFLITE_MODEL_PATH, options=options)

# Run object detection estimation using the model.
detections = detector.detect(image_np_one)

# Draw keypoints and edges on input image
image_np_one = visualize(image_np_one, detections)

# Show the detection result
Image.fromarray(image_np_one)
# Out:
# <PIL.Image.Image image mode=RGB size=512x341 at 0x7FCCD56FCDC0>

# %%
#INPUT_IMAGE_URL = 'JPEG/Validate/2_33226e67-1692-4472-88be-acdbace303f5_1024x1024.jpg'
INPUT_IMAGE_URL = 'Thesis/All_Photos/1024_DIFFNet/TEST_1024/6_disp.jpeg'
DISP_IMAGE_OVERLAY = 'Thesis/All_Photos/1024_DIFFNet/TEST_1024/6_disp.jpeg'

# %%
#@title Run object detection and show the detection results

# from PIL import Image

# INPUT_IMAGE_URL = 'Depth_Map_Image/2_disp.jpeg'
# INPUT_IMAGE_URL = "http://download.tensorflow.org/example_images/android_figurine.jpg" #@param {type:"string"}
INPUT_IMAGE_URL = INPUT_IMAGE_URL #@param {type:"string"}
DETECTION_THRESHOLD = 0.5 #@param {type:"number"}
TFLITE_MODEL_PATH = "Thesis/android.tfliteDIFF1024" #@param {type:"string"}

TEMP_FILE = '/tmp/image.png'

# !wget -q -O $TEMP_FILE $INPUT_IMAGE_URL

#image = Image.open(TEMP_FILE).convert('RGB')
image = Image.open(INPUT_IMAGE_URL).convert('RGB')
image.thumbnail((512, 512), Image.ANTIALIAS)
image_np = np.asarray(image)

# Load the TFLite model
options = ObjectDetectorOptions(
      num_threads=4,
      score_threshold=DETECTION_THRESHOLD,
)
detector = ObjectDetector(model_path=TFLITE_MODEL_PATH, options=options)

# Run object detection estimation using the model.
detections = detector.detect(image_np)

# Draw keypoints and edges on input image
image_np = visualize(image_np, detections)

# Show the detection result
Image.fromarray(image_np)



# #image = Image.open(TEMP_FILE).convert('RGB')
# image_two = Image.open(DISP_IMAGE_OVERLAY).convert('RGB')
# image_two.thumbnail((512, 512), Image.ANTIALIAS)
# image_np_two = np.asarray(image_two)

# image_np_two = visualize(image_np_two, detections)
# Image.fromarray(image_np_two)
# Out:
# <PIL.Image.Image image mode=RGB size=512x288 at 0x7FCCCCD59190>

# %%
# image_two = Image.open(DISP_IMAGE_OVERLAY).convert('RGB')
# image_two.thumbnail((512, 512), Image.ANTIALIAS)
# image_np_two = np.asarray(image_two)

# image_np_two = visualize(image_np_two, detections)
# Image.fromarray(image_np_two)

# %%
t2 = time.perf_counter()
print('time taken to run:',t2-t1)
# Out:
# time taken to run: 2409.32351395

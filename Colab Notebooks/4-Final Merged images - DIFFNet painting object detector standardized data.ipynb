# %% [markdown]
# ## Preparation
#
# ### Install the required packages
# Start by installing the required packages, including the Model Maker package from the [GitHub repo](https://github.com/tensorflow/examples/tree/master/tensorflow_examples/lite/model_maker) and the pycocotools library you'll use for evaluation.

# %%
# !pip install -q tflite-model-maker
# !pip install -q tflite-support
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.3/577.3 KB 34.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 MB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 64.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 KB 11.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.6/128.6 KB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 85.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 104.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 KB 39.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 KB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 36.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.0/498.0 MB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 KB 42.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 68.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 KB 48.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 108.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 KB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.4/222.4 KB 29.0 MB/s eta 0:00:00
#   Building wheel for fire (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 2022.12.0 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.

# %% [markdown]
# Import the required packages.

# %%
import numpy as np
import os

from tflite_model_maker.config import ExportFormat, QuantizationConfig
from tflite_model_maker import model_spec
from tflite_model_maker import object_detector

from tflite_support import metadata

import tensorflow as tf
assert tf.__version__.startswith('2')

tf.get_logger().setLevel('ERROR')
from absl import logging
logging.set_verbosity(logging.ERROR)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.4 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %% [markdown]
# ### Prepare the dataset

# %%
#!wget https://storage.googleapis.com/download.tensorflow.org/data/android_figurine.zip
#!unzip -q android_figurine.zip
from google.colab import drive
drive.mount('/content/drive/', force_remount=True) #, force_remount=True
# Out:
# Mounted at /content/drive/

# %%
# Run this if need to force remount
import os
path = "/content" # /content is pretty much the root. you can choose other path in your colab workspace
os.chdir(path)

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/My Drive/
# Out:
# /content/drive/My Drive

# %%
# !unzip -q Colab_1024.zip # This should be on when running first time

# %% [markdown]
# ## Train the object detection model
#
# ### Step 1: Load the dataset
#
# * Images in `train_data` is used to train the custom object detection model.
# * Images in `val_data` is used to check if the model can generalize well to new images that it hasn't seen before.

# %%
# !pwd
# Out:
# /content/drive/My Drive

# %%
train_data = object_detector.DataLoader.from_pascal_voc(
    'Thesis/All_Photos/Combined/Combined_TRAIN',
    'Thesis/All_Photos/Combined/Combined_TRAIN',
    ['painting','Real_Tunnel']
)

val_data = object_detector.DataLoader.from_pascal_voc(
    'Thesis/All_Photos/Combined/Combined_TEST',
    'Thesis/All_Photos/Combined/Combined_TEST',
    ['painting','Real_Tunnel']
)

# %%
print(train_data.size)
# Out:
# 25

# %% [markdown]
# ### Step 2: Select a model architecture
#
# EfficientDet-Lite[0-4] are a family of mobile/IoT-friendly object detection models derived from the [EfficientDet](https://arxiv.org/abs/1911.09070) architecture.
#
# Here is the performance of each EfficientDet-Lite models compared to each others.
#
# | Model architecture | Size(MB)* | Latency(ms)** | Average Precision*** |
# |--------------------|-----------|---------------|----------------------|
# | EfficientDet-Lite0 | 4.4       | 146           | 25.69%               |
# | EfficientDet-Lite1 | 5.8       | 259           | 30.55%               |
# | EfficientDet-Lite2 | 7.2       | 396           | 33.97%               |
# | EfficientDet-Lite3 | 11.4      | 716           | 37.70%               |
# | EfficientDet-Lite4 | 19.9      | 1886          | 41.96%               |
#
# <i> * Size of the integer quantized models. <br/>
# ** Latency measured on Raspberry Pi 4 using 4 threads on CPU. <br/>
# *** Average Precision is the mAP (mean Average Precision) on the COCO 2017 validation dataset.
# </i>
#
# In this notebook, we use EfficientDet-Lite0 to train our model. You can choose other model architectures depending on whether speed or accuracy is more important to you.

# %%
spec = model_spec.get('efficientdet_lite4')

# %% [markdown]
# ### Step 3: Train the TensorFlow model with the training data.
#
# * Set `epochs = 20`, which means it will go through the training dataset 20 times. You can look at the validation accuracy during training and stop when you see validation loss (`val_loss`) stop decreasing to avoid overfitting.
# * Set `batch_size = 4` here so you will see that it takes 15 steps to go through the 62 images in the training dataset.
# * Set `train_whole_model=True` to fine-tune the whole model instead of just training the head layer to improve accuracy. The trade-off is that it may take longer to train the model.

# %%
import time
t1 = time.perf_counter()

# %%
model = object_detector.create(train_data, model_spec=spec, batch_size=4, train_whole_model=True, epochs=100, validation_data=val_data)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 165s 19s/step - det_loss: 1.7820 - cls_loss: 1.1584 - box_loss: 0.0125 - reg_l2_loss: 0.1078 - loss: 1.8898 - learning_rate: 0.0066 - gradient_norm: 1.3191 - val_det_loss: 1.6715 - val_cls_loss: 1.1627 - val_box_loss: 0.0102 - val_reg_l2_loss: 0.1078 - val_loss: 1.7793
# Epoch 2/100
# 6/6 [==============================] - 104s 18s/step - det_loss: 1.7310 - cls_loss: 1.1568 - box_loss: 0.0115 - reg_l2_loss: 0.1078 - loss: 1.8388 - learning_rate: 0.0050 - gradient_norm: 1.7852 - val_det_loss: 1.6014 - val_cls_loss: 1.1536 - val_box_loss: 0.0090 - val_reg_l2_loss: 0.1078 - val_loss: 1.7092
# Epoch 3/100
# 6/6 [==============================] - 97s 16s/step - det_loss: 1.6265 - cls_loss: 1.1405 - box_loss: 0.0097 - reg_l2_loss: 0.1078 - loss: 1.7342 - learning_rate: 0.0050 - gradient_norm: 1.6145 - val_det_loss: 1.5435 - val_cls_loss: 1.1427 - val_box_loss: 0.0080 - val_reg_l2_loss: 0.1078 - val_loss: 1.6513
# Epoch 4/100
# 6/6 [==============================] - 103s 18s/step - det_loss: 1.6255 - cls_loss: 1.1277 - box_loss: 0.0100 - reg_l2_loss: 0.1078 - loss: 1.7333 - learning_rate: 0.0050 - gradient_norm: 1.5518 - val_det_loss: 1.5008 - val_cls_loss: 1.1302 - val_box_loss: 0.0074 - val_reg_l2_loss: 0.1078 - val_loss: 1.6085
# Epoch 5/100
# 6/6 [==============================] - 114s 19s/step - det_loss: 1.5702 - cls_loss: 1.1166 - box_loss: 0.0091 - reg_l2_loss: 0.1078 - loss: 1.6780 - learning_rate: 0.0050 - gradient_norm: 1.7707 - val_det_loss: 1.4716 - val_cls_loss: 1.1145 - val_box_loss: 0.0071 - val_reg_l2_loss: 0.1078 - val_loss: 1.5794
# Epoch 6/100
# 6/6 [==============================] - 97s 16s/step - det_loss: 1.5000 - cls_loss: 1.0870 - box_loss: 0.0083 - reg_l2_loss: 0.1078 - loss: 1.6078 - learning_rate: 0.0050 - gradient_norm: 1.8627 - val_det_loss: 1.4366 - val_cls_loss: 1.0925 - val_box_loss: 0.0069 - val_reg_l2_loss: 0.1078 - val_loss: 1.5444
# Epoch 7/100
# 6/6 [==============================] - 97s 16s/step - det_loss: 1.4576 - cls_loss: 1.0581 - box_loss: 0.0080 - reg_l2_loss: 0.1078 - loss: 1.5653 - learning_rate: 0.0049 - gradient_norm: 2.2153 - val_det_loss: 1.3933 - val_cls_loss: 1.0585 - val_box_loss: 0.0067 - val_reg_l2_loss: 0.1078 - val_loss: 1.5010
# Epoch 8/100
# 6/6 [==============================] - 101s 17s/step - det_loss: 1.4526 - cls_loss: 1.0318 - box_loss: 0.0084 - reg_l2_loss: 0.1078 - loss: 1.5604 - learning_rate: 0.0049 - gradient_norm: 3.4237 - val_det_loss: 1.3354 - val_cls_loss: 0.9967 - val_box_loss: 0.0068 - val_reg_l2_loss: 0.1078 - val_loss: 1.4431
# Epoch 9/100
# 6/6 [==============================] - 96s 16s/step - det_loss: 1.3587 - cls_loss: 0.9801 - box_loss: 0.0076 - reg_l2_loss: 0.1078 - loss: 1.4665 - learning_rate: 0.0049 - gradient_norm: 2.8865 - val_det_loss: 1.2296 - val_cls_loss: 0.9082 - val_box_loss: 0.0064 - val_reg_l2_loss: 0.1078 - val_loss: 1.3374
# Epoch 10/100
# 6/6 [==============================] - 107s 18s/step - det_loss: 1.1860 - cls_loss: 0.8751 - box_loss: 0.0062 - reg_l2_loss: 0.1078 - loss: 1.2938 - learning_rate: 0.0049 - gradient_norm: 3.2326 - val_det_loss: 1.0927 - val_cls_loss: 0.7935 - val_box_loss: 0.0060 - val_reg_l2_loss: 0.1078 - val_loss: 1.2005
# Epoch 11/100
# 6/6 [==============================] - 101s 17s/step - det_loss: 1.1333 - cls_loss: 0.8105 - box_loss: 0.0065 - reg_l2_loss: 0.1078 - loss: 1.2411 - learning_rate: 0.0049 - gradient_norm: 3.2108 - val_det_loss: 1.0977 - val_cls_loss: 0.8013 - val_box_loss: 0.0059 - val_reg_l2_loss: 0.1078 - val_loss: 1.2055
# Epoch 12/100
# 6/6 [==============================] - 104s 17s/step - det_loss: 0.9365 - cls_loss: 0.6474 - box_loss: 0.0058 - reg_l2_loss: 0.1078 - loss: 1.0443 - learning_rate: 0.0048 - gradient_norm: 3.9243 - val_det_loss: 1.1720 - val_cls_loss: 0.9055 - val_box_loss: 0.0053 - val_reg_l2_loss: 0.1078 - val_loss: 1.2798
# Epoch 13/100
# 6/6 [==============================] - 104s 18s/step - det_loss: 0.9054 - cls_loss: 0.6507 - box_loss: 0.0051 - reg_l2_loss: 0.1078 - loss: 1.0132 - learning_rate: 0.0048 - gradient_norm: 4.6256 - val_det_loss: 0.9232 - val_cls_loss: 0.6790 - val_box_loss: 0.0049 - val_reg_l2_loss: 0.1078 - val_loss: 1.0310
# Epoch 14/100
# 6/6 [==============================] - 112s 19s/step - det_loss: 0.9280 - cls_loss: 0.6627 - box_loss: 0.0053 - reg_l2_loss: 0.1078 - loss: 1.0358 - learning_rate: 0.0048 - gradient_norm: 4.3045 - val_det_loss: 0.9369 - val_cls_loss: 0.6670 - val_box_loss: 0.0054 - val_reg_l2_loss: 0.1078 - val_loss: 1.0448
# Epoch 15/100
# 6/6 [==============================] - 103s 18s/step - det_loss: 0.7692 - cls_loss: 0.5404 - box_loss: 0.0046 - reg_l2_loss: 0.1078 - loss: 0.8770 - learning_rate: 0.0047 - gradient_norm: 3.7664 - val_det_loss: 1.0802 - val_cls_loss: 0.7336 - val_box_loss: 0.0069 - val_reg_l2_loss: 0.1078 - val_loss: 1.1881
# Epoch 16/100
# 6/6 [==============================] - 101s 17s/step - det_loss: 0.8575 - cls_loss: 0.6383 - box_loss: 0.0044 - reg_l2_loss: 0.1078 - loss: 0.9653 - learning_rate: 0.0047 - gradient_norm: 4.7389 - val_det_loss: 0.9243 - val_cls_loss: 0.7002 - val_box_loss: 0.0045 - val_reg_l2_loss: 0.1078 - val_loss: 1.0322
# Epoch 17/100
# 6/6 [==============================] - 103s 18s/step - det_loss: 0.7443 - cls_loss: 0.5222 - box_loss: 0.0044 - reg_l2_loss: 0.1078 - loss: 0.8521 - learning_rate: 0.0047 - gradient_norm: 3.5066 - val_det_loss: 0.6818 - val_cls_loss: 0.5412 - val_box_loss: 0.0028 - val_reg_l2_loss: 0.1078 - val_loss: 0.7897
# Epoch 18/100
# 6/6 [==============================] - 100s 17s/step - det_loss: 0.6360 - cls_loss: 0.4583 - box_loss: 0.0036 - reg_l2_loss: 0.1078 - loss: 0.7439 - learning_rate: 0.0046 - gradient_norm: 3.8441 - val_det_loss: 0.6178 - val_cls_loss: 0.4919 - val_box_loss: 0.0025 - val_reg_l2_loss: 0.1079 - val_loss: 0.7257
# Epoch 19/100
# 6/6 [==============================] - 97s 16s/step - det_loss: 0.5761 - cls_loss: 0.4333 - box_loss: 0.0029 - reg_l2_loss: 0.1079 - loss: 0.6840 - learning_rate: 0.0046 - gradient_norm: 3.6599 - val_det_loss: 0.6165 - val_cls_loss: 0.4689 - val_box_loss: 0.0030 - val_reg_l2_loss: 0.1079 - val_loss: 0.7244
# Epoch 20/100
# 6/6 [==============================] - 111s 19s/step - det_loss: 0.6082 - cls_loss: 0.4154 - box_loss: 0.0039 - reg_l2_loss: 0.1079 - loss: 0.7161 - learning_rate: 0.0045 - gradient_norm: 3.7719 - val_det_loss: 0.5951 - val_cls_loss: 0.4640 - val_box_loss: 0.0026 - val_reg_l2_loss: 0.1079 - val_loss: 0.7029
# Epoch 21/100
# 6/6 [==============================] - 96s 16s/step - det_loss: 0.6019 - cls_loss: 0.4426 - box_loss: 0.0032 - reg_l2_loss: 0.1079 - loss: 0.7098 - learning_rate: 0.0045 - gradient_norm: 3.5000 - val_det_loss: 0.5916 - val_cls_loss: 0.4814 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1079 - val_loss: 0.6995
# Epoch 22/100
# 6/6 [==============================] - 103s 18s/step - det_loss: 0.6283 - cls_loss: 0.4477 - box_loss: 0.0036 - reg_l2_loss: 0.1079 - loss: 0.7362 - learning_rate: 0.0044 - gradient_norm: 5.3788 - val_det_loss: 0.6424 - val_cls_loss: 0.5086 - val_box_loss: 0.0027 - val_reg_l2_loss: 0.1079 - val_loss: 0.7502
# Epoch 23/100
# 6/6 [==============================] - 104s 18s/step - det_loss: 0.5145 - cls_loss: 0.3879 - box_loss: 0.0025 - reg_l2_loss: 0.1079 - loss: 0.6224 - learning_rate: 0.0044 - gradient_norm: 4.4914 - val_det_loss: 0.6400 - val_cls_loss: 0.5006 - val_box_loss: 0.0028 - val_reg_l2_loss: 0.1079 - val_loss: 0.7479
# Epoch 24/100
# 6/6 [==============================] - 98s 17s/step - det_loss: 0.5299 - cls_loss: 0.3940 - box_loss: 0.0027 - reg_l2_loss: 0.1079 - loss: 0.6377 - learning_rate: 0.0043 - gradient_norm: 3.2833 - val_det_loss: 0.5704 - val_cls_loss: 0.4680 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1079 - val_loss: 0.6782
# Epoch 25/100
# 6/6 [==============================] - 103s 18s/step - det_loss: 0.4962 - cls_loss: 0.3417 - box_loss: 0.0031 - reg_l2_loss: 0.1079 - loss: 0.6041 - learning_rate: 0.0043 - gradient_norm: 3.5097 - val_det_loss: 0.4982 - val_cls_loss: 0.4089 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.6061
# Epoch 26/100
# 6/6 [==============================] - 102s 17s/step - det_loss: 0.5292 - cls_loss: 0.3766 - box_loss: 0.0031 - reg_l2_loss: 0.1079 - loss: 0.6371 - learning_rate: 0.0042 - gradient_norm: 2.8907 - val_det_loss: 0.5109 - val_cls_loss: 0.4152 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1079 - val_loss: 0.6188
# Epoch 27/100
# 6/6 [==============================] - 96s 16s/step - det_loss: 0.4663 - cls_loss: 0.3640 - box_loss: 0.0020 - reg_l2_loss: 0.1079 - loss: 0.5741 - learning_rate: 0.0042 - gradient_norm: 3.2951 - val_det_loss: 0.5274 - val_cls_loss: 0.4310 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1079 - val_loss: 0.6352
# Epoch 28/100
# 6/6 [==============================] - 102s 17s/step - det_loss: 0.5098 - cls_loss: 0.3614 - box_loss: 0.0030 - reg_l2_loss: 0.1079 - loss: 0.6177 - learning_rate: 0.0041 - gradient_norm: 6.0767 - val_det_loss: 0.4849 - val_cls_loss: 0.4057 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.1079 - val_loss: 0.5928
# Epoch 29/100
# 6/6 [==============================] - 103s 18s/step - det_loss: 0.5153 - cls_loss: 0.3951 - box_loss: 0.0024 - reg_l2_loss: 0.1079 - loss: 0.6232 - learning_rate: 0.0040 - gradient_norm: 5.7424 - val_det_loss: 0.4903 - val_cls_loss: 0.4141 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1079 - val_loss: 0.5982
# Epoch 30/100
# 6/6 [==============================] - 102s 17s/step - det_loss: 0.5774 - cls_loss: 0.4123 - box_loss: 0.0033 - reg_l2_loss: 0.1079 - loss: 0.6853 - learning_rate: 0.0040 - gradient_norm: 5.1952 - val_det_loss: 0.5421 - val_cls_loss: 0.4306 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1079 - val_loss: 0.6500
# Epoch 31/100
# 6/6 [==============================] - 96s 16s/step - det_loss: 0.4192 - cls_loss: 0.3245 - box_loss: 0.0019 - reg_l2_loss: 0.1079 - loss: 0.5271 - learning_rate: 0.0039 - gradient_norm: 2.9597 - val_det_loss: 0.5264 - val_cls_loss: 0.4257 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1079 - val_loss: 0.6343
# Epoch 32/100
# 6/6 [==============================] - 103s 18s/step - det_loss: 0.5632 - cls_loss: 0.3993 - box_loss: 0.0033 - reg_l2_loss: 0.1079 - loss: 0.6711 - learning_rate: 0.0039 - gradient_norm: 5.3958 - val_det_loss: 0.5731 - val_cls_loss: 0.4471 - val_box_loss: 0.0025 - val_reg_l2_loss: 0.1079 - val_loss: 0.6810
# Epoch 33/100
# 6/6 [==============================] - 97s 16s/step - det_loss: 0.4080 - cls_loss: 0.2963 - box_loss: 0.0022 - reg_l2_loss: 0.1079 - loss: 0.5159 - learning_rate: 0.0038 - gradient_norm: 4.2032 - val_det_loss: 0.6114 - val_cls_loss: 0.4656 - val_box_loss: 0.0029 - val_reg_l2_loss: 0.1079 - val_loss: 0.7193
# Epoch 34/100
# 6/6 [==============================] - 100s 17s/step - det_loss: 0.4168 - cls_loss: 0.2999 - box_loss: 0.0023 - reg_l2_loss: 0.1079 - loss: 0.5248 - learning_rate: 0.0037 - gradient_norm: 5.8599 - val_det_loss: 0.5694 - val_cls_loss: 0.4660 - val_box_loss: 0.0021 - val_reg_l2_loss: 0.1079 - val_loss: 0.6774
# Epoch 35/100
# 6/6 [==============================] - 109s 19s/step - det_loss: 0.4368 - cls_loss: 0.2999 - box_loss: 0.0027 - reg_l2_loss: 0.1079 - loss: 0.5448 - learning_rate: 0.0036 - gradient_norm: 5.6003 - val_det_loss: 0.6072 - val_cls_loss: 0.4932 - val_box_loss: 0.0023 - val_reg_l2_loss: 0.1079 - val_loss: 0.7151
# Epoch 36/100
# 6/6 [==============================] - 97s 16s/step - det_loss: 0.4193 - cls_loss: 0.3111 - box_loss: 0.0022 - reg_l2_loss: 0.1079 - loss: 0.5273 - learning_rate: 0.0036 - gradient_norm: 3.8397 - val_det_loss: 0.6153 - val_cls_loss: 0.4810 - val_box_loss: 0.0027 - val_reg_l2_loss: 0.1079 - val_loss: 0.7232
# Epoch 37/100
# 6/6 [==============================] - 107s 18s/step - det_loss: 0.4443 - cls_loss: 0.3246 - box_loss: 0.0024 - reg_l2_loss: 0.1079 - loss: 0.5523 - learning_rate: 0.0035 - gradient_norm: 5.0103 - val_det_loss: 0.5430 - val_cls_loss: 0.4555 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.6509
# Epoch 38/100
# 6/6 [==============================] - 97s 16s/step - det_loss: 0.3986 - cls_loss: 0.2741 - box_loss: 0.0025 - reg_l2_loss: 0.1079 - loss: 0.5065 - learning_rate: 0.0034 - gradient_norm: 5.0747 - val_det_loss: 0.5047 - val_cls_loss: 0.4333 - val_box_loss: 0.0014 - val_reg_l2_loss: 0.1079 - val_loss: 0.6127
# Epoch 39/100
# 6/6 [==============================] - 97s 17s/step - det_loss: 0.3377 - cls_loss: 0.2607 - box_loss: 0.0015 - reg_l2_loss: 0.1079 - loss: 0.4456 - learning_rate: 0.0034 - gradient_norm: 5.0541 - val_det_loss: 0.5256 - val_cls_loss: 0.4496 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1079 - val_loss: 0.6335
# Epoch 40/100
# 6/6 [==============================] - 112s 19s/step - det_loss: 0.4542 - cls_loss: 0.3319 - box_loss: 0.0024 - reg_l2_loss: 0.1079 - loss: 0.5622 - learning_rate: 0.0033 - gradient_norm: 5.6729 - val_det_loss: 0.5405 - val_cls_loss: 0.4541 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.6485
# Epoch 41/100
# 6/6 [==============================] - 96s 16s/step - det_loss: 0.3942 - cls_loss: 0.2917 - box_loss: 0.0020 - reg_l2_loss: 0.1080 - loss: 0.5021 - learning_rate: 0.0032 - gradient_norm: 4.7522 - val_det_loss: 0.5658 - val_cls_loss: 0.4761 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1080 - val_loss: 0.6737
# Epoch 42/100
# 6/6 [==============================] - 98s 17s/step - det_loss: 0.3250 - cls_loss: 0.2277 - box_loss: 0.0019 - reg_l2_loss: 0.1080 - loss: 0.4330 - learning_rate: 0.0031 - gradient_norm: 3.4519 - val_det_loss: 0.6016 - val_cls_loss: 0.4959 - val_box_loss: 0.0021 - val_reg_l2_loss: 0.1080 - val_loss: 0.7096
# Epoch 43/100
# 6/6 [==============================] - 102s 17s/step - det_loss: 0.3670 - cls_loss: 0.2757 - box_loss: 0.0018 - reg_l2_loss: 0.1080 - loss: 0.4750 - learning_rate: 0.0031 - gradient_norm: 5.3676 - val_det_loss: 0.6089 - val_cls_loss: 0.5013 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1080 - val_loss: 0.7169
# Epoch 44/100
# 6/6 [==============================] - 97s 16s/step - det_loss: 0.2996 - cls_loss: 0.2161 - box_loss: 0.0017 - reg_l2_loss: 0.1080 - loss: 0.4076 - learning_rate: 0.0030 - gradient_norm: 3.3465 - val_det_loss: 0.5958 - val_cls_loss: 0.4943 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.7038
# Epoch 45/100
# 6/6 [==============================] - 103s 18s/step - det_loss: 0.3733 - cls_loss: 0.2657 - box_loss: 0.0022 - reg_l2_loss: 0.1080 - loss: 0.4813 - learning_rate: 0.0029 - gradient_norm: 4.0144 - val_det_loss: 0.5838 - val_cls_loss: 0.4797 - val_box_loss: 0.0021 - val_reg_l2_loss: 0.1080 - val_loss: 0.6918
# Epoch 46/100
# 6/6 [==============================] - 105s 18s/step - det_loss: 0.3092 - cls_loss: 0.2206 - box_loss: 0.0018 - reg_l2_loss: 0.1080 - loss: 0.4171 - learning_rate: 0.0028 - gradient_norm: 3.2292 - val_det_loss: 0.5810 - val_cls_loss: 0.4660 - val_box_loss: 0.0023 - val_reg_l2_loss: 0.1080 - val_loss: 0.6890
# Epoch 47/100
# 6/6 [==============================] - 98s 16s/step - det_loss: 0.3562 - cls_loss: 0.2627 - box_loss: 0.0019 - reg_l2_loss: 0.1080 - loss: 0.4642 - learning_rate: 0.0027 - gradient_norm: 4.7780 - val_det_loss: 0.5907 - val_cls_loss: 0.4599 - val_box_loss: 0.0026 - val_reg_l2_loss: 0.1080 - val_loss: 0.6987
# Epoch 48/100
# 6/6 [==============================] - 103s 18s/step - det_loss: 0.3077 - cls_loss: 0.2368 - box_loss: 0.0014 - reg_l2_loss: 0.1080 - loss: 0.4157 - learning_rate: 0.0027 - gradient_norm: 3.2632 - val_det_loss: 0.5682 - val_cls_loss: 0.4560 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1080 - val_loss: 0.6762
# Epoch 49/100
# 6/6 [==============================] - 98s 17s/step - det_loss: 0.3131 - cls_loss: 0.2283 - box_loss: 0.0017 - reg_l2_loss: 0.1080 - loss: 0.4210 - learning_rate: 0.0026 - gradient_norm: 3.5052 - val_det_loss: 0.5512 - val_cls_loss: 0.4390 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1080 - val_loss: 0.6592
# Epoch 50/100
# 6/6 [==============================] - 99s 17s/step - det_loss: 0.3428 - cls_loss: 0.2631 - box_loss: 0.0016 - reg_l2_loss: 0.1080 - loss: 0.4508 - learning_rate: 0.0025 - gradient_norm: 4.0741 - val_det_loss: 0.5422 - val_cls_loss: 0.4285 - val_box_loss: 0.0023 - val_reg_l2_loss: 0.1080 - val_loss: 0.6501
# Epoch 51/100
# 6/6 [==============================] - 101s 17s/step - det_loss: 0.2872 - cls_loss: 0.2132 - box_loss: 0.0015 - reg_l2_loss: 0.1080 - loss: 0.3951 - learning_rate: 0.0024 - gradient_norm: 3.2240 - val_det_loss: 0.5099 - val_cls_loss: 0.4103 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.6178
# Epoch 52/100
# 6/6 [==============================] - 101s 17s/step - det_loss: 0.2467 - cls_loss: 0.1802 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3546 - learning_rate: 0.0023 - gradient_norm: 2.4835 - val_det_loss: 0.4846 - val_cls_loss: 0.3913 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.5926
# Epoch 53/100
# 6/6 [==============================] - 96s 16s/step - det_loss: 0.2678 - cls_loss: 0.2104 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3758 - learning_rate: 0.0023 - gradient_norm: 3.4830 - val_det_loss: 0.4829 - val_cls_loss: 0.3790 - val_box_loss: 0.0021 - val_reg_l2_loss: 0.1080 - val_loss: 0.5909
# Epoch 54/100
# 6/6 [==============================] - 104s 18s/step - det_loss: 0.2737 - cls_loss: 0.2002 - box_loss: 0.0015 - reg_l2_loss: 0.1080 - loss: 0.3817 - learning_rate: 0.0022 - gradient_norm: 3.5847 - val_det_loss: 0.4758 - val_cls_loss: 0.3762 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.5838
# Epoch 55/100
# 6/6 [==============================] - 99s 17s/step - det_loss: 0.2855 - cls_loss: 0.2177 - box_loss: 0.0014 - reg_l2_loss: 0.1080 - loss: 0.3935 - learning_rate: 0.0021 - gradient_norm: 2.4173 - val_det_loss: 0.4716 - val_cls_loss: 0.3821 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1080 - val_loss: 0.5796
# Epoch 56/100
# 6/6 [==============================] - 97s 17s/step - det_loss: 0.2532 - cls_loss: 0.1891 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3612 - learning_rate: 0.0020 - gradient_norm: 3.0338 - val_det_loss: 0.4928 - val_cls_loss: 0.3874 - val_box_loss: 0.0021 - val_reg_l2_loss: 0.1080 - val_loss: 0.6007
# Epoch 57/100
# 6/6 [==============================] - 96s 16s/step - det_loss: 0.2407 - cls_loss: 0.1798 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3486 - learning_rate: 0.0020 - gradient_norm: 2.2247 - val_det_loss: 0.4819 - val_cls_loss: 0.3843 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.5899
# Epoch 58/100
# 6/6 [==============================] - 101s 17s/step - det_loss: 0.2473 - cls_loss: 0.1951 - box_loss: 0.0010 - reg_l2_loss: 0.1080 - loss: 0.3553 - learning_rate: 0.0019 - gradient_norm: 2.4476 - val_det_loss: 0.4649 - val_cls_loss: 0.3740 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1080 - val_loss: 0.5729
# Epoch 59/100
# 6/6 [==============================] - 105s 17s/step - det_loss: 0.2664 - cls_loss: 0.1920 - box_loss: 0.0015 - reg_l2_loss: 0.1080 - loss: 0.3744 - learning_rate: 0.0018 - gradient_norm: 4.0875 - val_det_loss: 0.4567 - val_cls_loss: 0.3597 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.5647
# Epoch 60/100
# 6/6 [==============================] - 104s 18s/step - det_loss: 0.2701 - cls_loss: 0.2169 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3781 - learning_rate: 0.0017 - gradient_norm: 2.8809 - val_det_loss: 0.4538 - val_cls_loss: 0.3552 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.5618
# Epoch 61/100
# 6/6 [==============================] - 99s 17s/step - det_loss: 0.2728 - cls_loss: 0.2080 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3807 - learning_rate: 0.0016 - gradient_norm: 3.7199 - val_det_loss: 0.4539 - val_cls_loss: 0.3560 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.5619
# Epoch 62/100
# 6/6 [==============================] - 100s 17s/step - det_loss: 0.2107 - cls_loss: 0.1622 - box_loss: 9.7017e-04 - reg_l2_loss: 0.1080 - loss: 0.3187 - learning_rate: 0.0016 - gradient_norm: 2.2593 - val_det_loss: 0.4600 - val_cls_loss: 0.3683 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1080 - val_loss: 0.5680
# Epoch 63/100
# 6/6 [==============================] - 98s 17s/step - det_loss: 0.2507 - cls_loss: 0.1885 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3587 - learning_rate: 0.0015 - gradient_norm: 3.2152 - val_det_loss: 0.4539 - val_cls_loss: 0.3690 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1080 - val_loss: 0.5619
# Epoch 64/100
# 6/6 [==============================] - 99s 17s/step - det_loss: 0.3273 - cls_loss: 0.2468 - box_loss: 0.0016 - reg_l2_loss: 0.1080 - loss: 0.4353 - learning_rate: 0.0014 - gradient_norm: 4.0852 - val_det_loss: 0.4668 - val_cls_loss: 0.3854 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.1080 - val_loss: 0.5748
# Epoch 65/100
# 6/6 [==============================] - 109s 19s/step - det_loss: 0.2895 - cls_loss: 0.2299 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3975 - learning_rate: 0.0014 - gradient_norm: 3.5996 - val_det_loss: 0.4932 - val_cls_loss: 0.3997 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.6011
# Epoch 66/100
# 6/6 [==============================] - 100s 17s/step - det_loss: 0.2086 - cls_loss: 0.1534 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3165 - learning_rate: 0.0013 - gradient_norm: 3.0921 - val_det_loss: 0.5100 - val_cls_loss: 0.4061 - val_box_loss: 0.0021 - val_reg_l2_loss: 0.1080 - val_loss: 0.6180
# Epoch 67/100
# 6/6 [==============================] - 98s 17s/step - det_loss: 0.2746 - cls_loss: 0.2057 - box_loss: 0.0014 - reg_l2_loss: 0.1080 - loss: 0.3825 - learning_rate: 0.0012 - gradient_norm: 3.7348 - val_det_loss: 0.5209 - val_cls_loss: 0.4185 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.6289
# Epoch 68/100
# 6/6 [==============================] - 99s 17s/step - det_loss: 0.3422 - cls_loss: 0.2614 - box_loss: 0.0016 - reg_l2_loss: 0.1080 - loss: 0.4502 - learning_rate: 0.0012 - gradient_norm: 5.1576 - val_det_loss: 0.5224 - val_cls_loss: 0.4253 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.6303
# Epoch 69/100
# 6/6 [==============================] - 101s 17s/step - det_loss: 0.2402 - cls_loss: 0.1903 - box_loss: 9.9807e-04 - reg_l2_loss: 0.1080 - loss: 0.3482 - learning_rate: 0.0011 - gradient_norm: 3.4285 - val_det_loss: 0.5232 - val_cls_loss: 0.4280 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.6312
# Epoch 70/100
# 6/6 [==============================] - 105s 18s/step - det_loss: 0.2938 - cls_loss: 0.2112 - box_loss: 0.0017 - reg_l2_loss: 0.1080 - loss: 0.4018 - learning_rate: 0.0010 - gradient_norm: 4.0124 - val_det_loss: 0.5253 - val_cls_loss: 0.4293 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.6332
# Epoch 71/100
# 6/6 [==============================] - 102s 17s/step - det_loss: 0.2455 - cls_loss: 0.1805 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3535 - learning_rate: 9.5616e-04 - gradient_norm: 3.4578 - val_det_loss: 0.5177 - val_cls_loss: 0.4223 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.6257
# Epoch 72/100
# 6/6 [==============================] - 105s 18s/step - det_loss: 0.2115 - cls_loss: 0.1612 - box_loss: 0.0010 - reg_l2_loss: 0.1080 - loss: 0.3194 - learning_rate: 8.9455e-04 - gradient_norm: 2.1830 - val_det_loss: 0.5023 - val_cls_loss: 0.4110 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1080 - val_loss: 0.6103
# Epoch 73/100
# 6/6 [==============================] - 101s 17s/step - det_loss: 0.2607 - cls_loss: 0.2117 - box_loss: 9.7995e-04 - reg_l2_loss: 0.1080 - loss: 0.3687 - learning_rate: 8.3456e-04 - gradient_norm: 3.4185 - val_det_loss: 0.4945 - val_cls_loss: 0.4063 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1080 - val_loss: 0.6025
# Epoch 74/100
# 6/6 [==============================] - 98s 17s/step - det_loss: 0.2678 - cls_loss: 0.2035 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3758 - learning_rate: 7.7625e-04 - gradient_norm: 3.7901 - val_det_loss: 0.4861 - val_cls_loss: 0.3994 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1080 - val_loss: 0.5941
# Epoch 75/100
# 6/6 [==============================] - 105s 18s/step - det_loss: 0.2391 - cls_loss: 0.1930 - box_loss: 9.2144e-04 - reg_l2_loss: 0.1080 - loss: 0.3470 - learning_rate: 7.1967e-04 - gradient_norm: 4.5544 - val_det_loss: 0.4703 - val_cls_loss: 0.3855 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1080 - val_loss: 0.5783
# Epoch 76/100
# 6/6 [==============================] - 101s 17s/step - det_loss: 0.2281 - cls_loss: 0.1754 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3361 - learning_rate: 6.6489e-04 - gradient_norm: 2.5183 - val_det_loss: 0.4720 - val_cls_loss: 0.3852 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1080 - val_loss: 0.5800
# Epoch 77/100
# 6/6 [==============================] - 104s 17s/step - det_loss: 0.2480 - cls_loss: 0.1871 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3559 - learning_rate: 6.1195e-04 - gradient_norm: 3.7320 - val_det_loss: 0.4790 - val_cls_loss: 0.3902 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1080 - val_loss: 0.5869
# Epoch 78/100
# 6/6 [==============================] - 101s 17s/step - det_loss: 0.2033 - cls_loss: 0.1566 - box_loss: 9.3247e-04 - reg_l2_loss: 0.1080 - loss: 0.3112 - learning_rate: 5.6091e-04 - gradient_norm: 2.3509 - val_det_loss: 0.4791 - val_cls_loss: 0.3907 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1080 - val_loss: 0.5871
# Epoch 79/100
# 6/6 [==============================] - 102s 17s/step - det_loss: 0.2396 - cls_loss: 0.1882 - box_loss: 0.0010 - reg_l2_loss: 0.1080 - loss: 0.3476 - learning_rate: 5.1183e-04 - gradient_norm: 2.7498 - val_det_loss: 0.4771 - val_cls_loss: 0.3900 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1080 - val_loss: 0.5851
# Epoch 80/100
# 6/6 [==============================] - 105s 18s/step - det_loss: 0.2277 - cls_loss: 0.1804 - box_loss: 9.4710e-04 - reg_l2_loss: 0.1080 - loss: 0.3357 - learning_rate: 4.6475e-04 - gradient_norm: 2.2387 - val_det_loss: 0.4796 - val_cls_loss: 0.3914 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1080 - val_loss: 0.5875
# Epoch 81/100
# 6/6 [==============================] - 100s 17s/step - det_loss: 0.2562 - cls_loss: 0.1974 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3642 - learning_rate: 4.1972e-04 - gradient_norm: 2.8067 - val_det_loss: 0.4856 - val_cls_loss: 0.3962 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1080 - val_loss: 0.5935
# Epoch 82/100
# 6/6 [==============================] - 98s 17s/step - det_loss: 0.2043 - cls_loss: 0.1662 - box_loss: 7.6345e-04 - reg_l2_loss: 0.1080 - loss: 0.3123 - learning_rate: 3.7678e-04 - gradient_norm: 3.1184 - val_det_loss: 0.4924 - val_cls_loss: 0.4011 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1080 - val_loss: 0.6003
# Epoch 83/100
# 6/6 [==============================] - 106s 17s/step - det_loss: 0.1987 - cls_loss: 0.1602 - box_loss: 7.7081e-04 - reg_l2_loss: 0.1080 - loss: 0.3067 - learning_rate: 3.3598e-04 - gradient_norm: 2.4200 - val_det_loss: 0.4942 - val_cls_loss: 0.4025 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1080 - val_loss: 0.6021
# Epoch 84/100
# 6/6 [==============================] - 100s 17s/step - det_loss: 0.2703 - cls_loss: 0.2055 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3783 - learning_rate: 2.9736e-04 - gradient_norm: 3.5566 - val_det_loss: 0.4956 - val_cls_loss: 0.4031 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1080 - val_loss: 0.6036
# Epoch 85/100
# 6/6 [==============================] - 106s 18s/step - det_loss: 0.1956 - cls_loss: 0.1582 - box_loss: 7.4935e-04 - reg_l2_loss: 0.1080 - loss: 0.3036 - learning_rate: 2.6096e-04 - gradient_norm: 3.4516 - val_det_loss: 0.5032 - val_cls_loss: 0.4080 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.6111
# Epoch 86/100
# 6/6 [==============================] - 101s 17s/step - det_loss: 0.2458 - cls_loss: 0.1924 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3538 - learning_rate: 2.2681e-04 - gradient_norm: 2.8274 - val_det_loss: 0.5069 - val_cls_loss: 0.4101 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.6149
# Epoch 87/100
# 6/6 [==============================] - 101s 17s/step - det_loss: 0.2172 - cls_loss: 0.1711 - box_loss: 9.2368e-04 - reg_l2_loss: 0.1080 - loss: 0.3252 - learning_rate: 1.9495e-04 - gradient_norm: 2.6196 - val_det_loss: 0.5134 - val_cls_loss: 0.4142 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.6214
# Epoch 88/100
# 6/6 [==============================] - 99s 17s/step - det_loss: 0.2134 - cls_loss: 0.1623 - box_loss: 0.0010 - reg_l2_loss: 0.1080 - loss: 0.3214 - learning_rate: 1.6541e-04 - gradient_norm: 2.2852 - val_det_loss: 0.5117 - val_cls_loss: 0.4120 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.6197
# Epoch 89/100
# 6/6 [==============================] - 104s 17s/step - det_loss: 0.2023 - cls_loss: 0.1608 - box_loss: 8.3134e-04 - reg_l2_loss: 0.1080 - loss: 0.3103 - learning_rate: 1.3822e-04 - gradient_norm: 2.9683 - val_det_loss: 0.5096 - val_cls_loss: 0.4109 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.6176
# Epoch 90/100
# 6/6 [==============================] - 103s 18s/step - det_loss: 0.2182 - cls_loss: 0.1653 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3262 - learning_rate: 1.1341e-04 - gradient_norm: 2.3870 - val_det_loss: 0.5123 - val_cls_loss: 0.4127 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.6203
# Epoch 91/100
# 6/6 [==============================] - 101s 17s/step - det_loss: 0.2035 - cls_loss: 0.1693 - box_loss: 6.8476e-04 - reg_l2_loss: 0.1080 - loss: 0.3115 - learning_rate: 9.1009e-05 - gradient_norm: 2.1032 - val_det_loss: 0.5161 - val_cls_loss: 0.4151 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.6241
# Epoch 92/100
# 6/6 [==============================] - 102s 17s/step - det_loss: 0.2656 - cls_loss: 0.2176 - box_loss: 9.5966e-04 - reg_l2_loss: 0.1080 - loss: 0.3735 - learning_rate: 7.1028e-05 - gradient_norm: 3.3129 - val_det_loss: 0.5196 - val_cls_loss: 0.4171 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.6275
# Epoch 93/100
# 6/6 [==============================] - 102s 17s/step - det_loss: 0.2246 - cls_loss: 0.1772 - box_loss: 9.4782e-04 - reg_l2_loss: 0.1080 - loss: 0.3326 - learning_rate: 5.3493e-05 - gradient_norm: 2.4543 - val_det_loss: 0.5172 - val_cls_loss: 0.4153 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.6252
# Epoch 94/100
# 6/6 [==============================] - 100s 17s/step - det_loss: 0.2448 - cls_loss: 0.1809 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3528 - learning_rate: 3.8422e-05 - gradient_norm: 2.9567 - val_det_loss: 0.5135 - val_cls_loss: 0.4122 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.6215
# Epoch 95/100
# 6/6 [==============================] - 109s 18s/step - det_loss: 0.2607 - cls_loss: 0.1990 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3687 - learning_rate: 2.5829e-05 - gradient_norm: 4.0079 - val_det_loss: 0.5078 - val_cls_loss: 0.4084 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.6158
# Epoch 96/100
# 6/6 [==============================] - 98s 17s/step - det_loss: 0.2480 - cls_loss: 0.1825 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3559 - learning_rate: 1.5727e-05 - gradient_norm: 3.9381 - val_det_loss: 0.4958 - val_cls_loss: 0.4004 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.6038
# Epoch 97/100
# 6/6 [==============================] - 101s 17s/step - det_loss: 0.2003 - cls_loss: 0.1573 - box_loss: 8.6053e-04 - reg_l2_loss: 0.1080 - loss: 0.3083 - learning_rate: 8.1273e-06 - gradient_norm: 2.4935 - val_det_loss: 0.4962 - val_cls_loss: 0.4007 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.6041
# Epoch 98/100
# 6/6 [==============================] - 102s 17s/step - det_loss: 0.2671 - cls_loss: 0.2016 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3750 - learning_rate: 3.0362e-06 - gradient_norm: 2.8641 - val_det_loss: 0.4929 - val_cls_loss: 0.3978 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.6008
# Epoch 99/100
# 6/6 [==============================] - 100s 17s/step - det_loss: 0.1962 - cls_loss: 0.1488 - box_loss: 9.4765e-04 - reg_l2_loss: 0.1080 - loss: 0.3042 - learning_rate: 4.5955e-07 - gradient_norm: 2.1128 - val_det_loss: 0.4892 - val_cls_loss: 0.3957 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.5972
# Epoch 100/100
# 6/6 [==============================] - 111s 19s/step - det_loss: 0.2617 - cls_loss: 0.2095 - box_loss: 0.0010 - reg_l2_loss: 0.1080 - loss: 0.3697 - learning_rate: 3.9961e-07 - gradient_norm: 2.7267 - val_det_loss: 0.4894 - val_cls_loss: 0.3962 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.5974

# %% [markdown]
# ### Step 4. Evaluate the model with the validation data.
#
# After training the object detection model using the images in the training dataset, use the 10 images in the validation dataset to evaluate how the model performs against new data it has never seen before.
#
# As the default batch size is 64, it will take 1 step to go through the 10 images in the validation dataset.
#
# The evaluation metrics are same as [COCO](https://cocodataset.org/#detection-eval).

# %%
model.evaluate(val_data)
# Out:
# 1/1 [==============================] - 10s 10s/step
# {'AP': 0.5587412,
#  'AP50': 0.9092409,
#  'AP75': 0.5742146,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.5640395,
#  'ARmax1': 0.6125,
#  'ARmax10': 0.67083335,
#  'ARmax100': 0.70416665,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.70416665,
#  'AP_/painting': 0.61160004,
#  'AP_/Real_Tunnel': 0.5058824}

# %%
# import matplotlib.pyplot as plt
# print(model.history.keys())
# # summarize history for loss
# plt.plot(model.history['loss'])
# plt.plot(model.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %% [markdown]
# ### Step 5: Export as a TensorFlow Lite model.
#
# Export the trained object detection model to the TensorFlow Lite format by specifying which folder you want to export the quantized model to. The default post-training quantization technique is [full integer quantization](https://www.tensorflow.org/lite/performance/post_training_integer_quant). This allows the TensorFlow Lite model to be smaller, run faster on Raspberry Pi CPU and also compatible with the Google Coral EdgeTPU.

# %%
model.export(export_dir='Thesis/', tflite_filename='android.tfliteMerged')

# %% [markdown]
# ### Step 6:  Evaluate the TensorFlow Lite model.
#
# Several factors can affect the model accuracy when exporting to TFLite:
# * [Quantization](https://www.tensorflow.org/lite/performance/model_optimization) helps shrinking the model size by 4 times at the expense of some accuracy drop.
# * The original TensorFlow model uses per-class [non-max supression (NMS)](https://www.coursera.org/lecture/convolutional-neural-networks/non-max-suppression-dvrjH) for post-processing, while the TFLite model uses global NMS that's much faster but less accurate.
# Keras outputs maximum 100 detections while tflite outputs maximum 25 detections.
#
# Therefore you'll have to evaluate the exported TFLite model and compare its accuracy with the original TensorFlow model.

# %%
model.evaluate_tflite('Thesis/android.tfliteMerged', val_data)
# Out:
# 7/7 [==============================] - 295s 42s/step
# {'AP': 0.5416549,
#  'AP50': 0.8998114,
#  'AP75': 0.5429043,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.5453383,
#  'ARmax1': 0.6,
#  'ARmax10': 0.6,
#  'ARmax100': 0.6,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.6,
#  'AP_/painting': 0.5990099,
#  'AP_/Real_Tunnel': 0.48429987}

# %%
# Download the TFLite model to your local computer.
# from google.colab import files
# files.download('android.tfliteMerged')

# %% [markdown]
# ## Test the Android figurine detection model
#
# After training the model, let's test it with an image that the model hasn't seen before to get a sense of how good the model is.

# %%
#@title Load the trained TFLite model and define some visualization functions

#@markdown This code comes from the TFLite Object Detection [Raspberry Pi sample](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/raspberry_pi).

import platform
from typing import List, NamedTuple
import json

import cv2

Interpreter = tf.lite.Interpreter
load_delegate = tf.lite.experimental.load_delegate

# pylint: enable=g-import-not-at-top


class ObjectDetectorOptions(NamedTuple):
  """A config to initialize an object detector."""

  enable_edgetpu: bool = False
  """Enable the model to run on EdgeTPU."""

  label_allow_list: List[str] = None
  """The optional allow list of labels."""

  label_deny_list: List[str] = None
  """The optional deny list of labels."""

  max_results: int = -1
  """The maximum number of top-scored detection results to return."""

  num_threads: int = 1
  """The number of CPU threads to be used."""

  score_threshold: float = 0.0
  """The score threshold of detection results to return."""


class Rect(NamedTuple):
  """A rectangle in 2D space."""
  left: float
  top: float
  right: float
  bottom: float


class Category(NamedTuple):
  """A result of a classification task."""
  label: str
  score: float
  index: int


class Detection(NamedTuple):
  """A detected object as the result of an ObjectDetector."""
  bounding_box: Rect
  categories: List[Category]


def edgetpu_lib_name():
  """Returns the library name of EdgeTPU in the current platform."""
  return {
      'Darwin': 'libedgetpu.1.dylib',
      'Linux': 'libedgetpu.so.1',
      'Windows': 'edgetpu.dll',
  }.get(platform.system(), None)


class ObjectDetector:
  """A wrapper class for a TFLite object detection model."""

  _OUTPUT_LOCATION_NAME = 'location'
  _OUTPUT_CATEGORY_NAME = 'category'
  _OUTPUT_SCORE_NAME = 'score'
  _OUTPUT_NUMBER_NAME = 'number of detections'

  def __init__(
      self,
      model_path: str,
      options: ObjectDetectorOptions = ObjectDetectorOptions()
  ) -> None:
    """Initialize a TFLite object detection model.
    Args:
        model_path: Path to the TFLite model.
        options: The config to initialize an object detector. (Optional)
    Raises:
        ValueError: If the TFLite model is invalid.
        OSError: If the current OS isn't supported by EdgeTPU.
    """

    # Load metadata from model.
    displayer = metadata.MetadataDisplayer.with_model_file(model_path)

    # Save model metadata for preprocessing later.
    model_metadata = json.loads(displayer.get_metadata_json())
    process_units = model_metadata['subgraph_metadata'][0]['input_tensor_metadata'][0]['process_units']
    mean = 0.0
    std = 1.0
    for option in process_units:
      if option['options_type'] == 'NormalizationOptions':
        mean = option['options']['mean'][0]
        std = option['options']['std'][0]
    self._mean = mean
    self._std = std

    # Load label list from metadata.
    file_name = displayer.get_packed_associated_file_list()[0]
    label_map_file = displayer.get_associated_file_buffer(file_name).decode()
    label_list = list(filter(lambda x: len(x) > 0, label_map_file.splitlines()))
    self._label_list = label_list

    # Initialize TFLite model.
    if options.enable_edgetpu:
      if edgetpu_lib_name() is None:
        raise OSError("The current OS isn't supported by Coral EdgeTPU.")
      interpreter = Interpreter(
          model_path=model_path,
          experimental_delegates=[load_delegate(edgetpu_lib_name())],
          num_threads=options.num_threads)
    else:
      interpreter = Interpreter(
          model_path=model_path, num_threads=options.num_threads)

    interpreter.allocate_tensors()
    input_detail = interpreter.get_input_details()[0]

    # From TensorFlow 2.6, the order of the outputs become undefined.
    # Therefore we need to sort the tensor indices of TFLite outputs and to know
    # exactly the meaning of each output tensor. For example, if
    # output indices are [601, 599, 598, 600], tensor names and indices aligned
    # are:
    #   - location: 598
    #   - category: 599
    #   - score: 600
    #   - detection_count: 601
    # because of the op's ports of TFLITE_DETECTION_POST_PROCESS
    # (https://github.com/tensorflow/tensorflow/blob/a4fe268ea084e7d323133ed7b986e0ae259a2bc7/tensorflow/lite/kernels/detection_postprocess.cc#L47-L50).
    sorted_output_indices = sorted(
        [output['index'] for output in interpreter.get_output_details()])
    self._output_indices = {
        self._OUTPUT_LOCATION_NAME: sorted_output_indices[0],
        self._OUTPUT_CATEGORY_NAME: sorted_output_indices[1],
        self._OUTPUT_SCORE_NAME: sorted_output_indices[2],
        self._OUTPUT_NUMBER_NAME: sorted_output_indices[3],
    }

    self._input_size = input_detail['shape'][2], input_detail['shape'][1]
    self._is_quantized_input = input_detail['dtype'] == np.uint8
    self._interpreter = interpreter
    self._options = options

  def detect(self, input_image: np.ndarray) -> List[Detection]:
    """Run detection on an input image.
    Args:
        input_image: A [height, width, 3] RGB image. Note that height and width
          can be anything since the image will be immediately resized according
          to the needs of the model within this function.
    Returns:
        A Person instance.
    """
    image_height, image_width, _ = input_image.shape

    input_tensor = self._preprocess(input_image)

    self._set_input_tensor(input_tensor)
    self._interpreter.invoke()

    # Get all output details
    boxes = self._get_output_tensor(self._OUTPUT_LOCATION_NAME)
    classes = self._get_output_tensor(self._OUTPUT_CATEGORY_NAME)
    scores = self._get_output_tensor(self._OUTPUT_SCORE_NAME)
    count = int(self._get_output_tensor(self._OUTPUT_NUMBER_NAME))

    return self._postprocess(boxes, classes, scores, count, image_width,
                             image_height)

  def _preprocess(self, input_image: np.ndarray) -> np.ndarray:
    """Preprocess the input image as required by the TFLite model."""

    # Resize the input
    input_tensor = cv2.resize(input_image, self._input_size)

    # Normalize the input if it's a float model (aka. not quantized)
    if not self._is_quantized_input:
      input_tensor = (np.float32(input_tensor) - self._mean) / self._std

    # Add batch dimension
    input_tensor = np.expand_dims(input_tensor, axis=0)

    return input_tensor

  def _set_input_tensor(self, image):
    """Sets the input tensor."""
    tensor_index = self._interpreter.get_input_details()[0]['index']
    input_tensor = self._interpreter.tensor(tensor_index)()[0]
    input_tensor[:, :] = image

  def _get_output_tensor(self, name):
    """Returns the output tensor at the given index."""
    output_index = self._output_indices[name]
    tensor = np.squeeze(self._interpreter.get_tensor(output_index))
    return tensor

  def _postprocess(self, boxes: np.ndarray, classes: np.ndarray,
                   scores: np.ndarray, count: int, image_width: int,
                   image_height: int) -> List[Detection]:
    """Post-process the output of TFLite model into a list of Detection objects.
    Args:
        boxes: Bounding boxes of detected objects from the TFLite model.
        classes: Class index of the detected objects from the TFLite model.
        scores: Confidence scores of the detected objects from the TFLite model.
        count: Number of detected objects from the TFLite model.
        image_width: Width of the input image.
        image_height: Height of the input image.
    Returns:
        A list of Detection objects detected by the TFLite model.
    """
    results = []

    # Parse the model output into a list of Detection entities.
    for i in range(count):
      if scores[i] >= self._options.score_threshold:
        y_min, x_min, y_max, x_max = boxes[i]
        bounding_box = Rect(
            top=int(y_min * image_height),
            left=int(x_min * image_width),
            bottom=int(y_max * image_height),
            right=int(x_max * image_width))
        class_id = int(classes[i])
        category = Category(
            score=scores[i],
            label=self._label_list[class_id],  # 0 is reserved for background
            index=class_id)
        result = Detection(bounding_box=bounding_box, categories=[category])
        results.append(result)

    # Sort detection results by score ascending
    sorted_results = sorted(
        results,
        key=lambda detection: detection.categories[0].score,
        reverse=True)

    # Filter out detections in deny list
    filtered_results = sorted_results
    if self._options.label_deny_list is not None:
      filtered_results = list(
          filter(
              lambda detection: detection.categories[0].label not in self.
              _options.label_deny_list, filtered_results))

    # Keep only detections in allow list
    if self._options.label_allow_list is not None:
      filtered_results = list(
          filter(
              lambda detection: detection.categories[0].label in self._options.
              label_allow_list, filtered_results))

    # Only return maximum of max_results detection.
    if self._options.max_results > 0:
      result_count = min(len(filtered_results), self._options.max_results)
      filtered_results = filtered_results[:result_count]

    return filtered_results


_MARGIN = 10  # pixels
_ROW_SIZE = 10  # pixels
_FONT_SIZE = 1
_FONT_THICKNESS = 1
_TEXT_COLOR = (0, 0, 255)  # red


def visualize(
    image: np.ndarray,
    detections: List[Detection],
) -> np.ndarray:
  """Draws bounding boxes on the input image and return it.
  Args:
    image: The input RGB image.
    detections: The list of all "Detection" entities to be visualize.
  Returns:
    Image with bounding boxes.
  """
  for detection in detections:
    # Draw bounding_box
    start_point = detection.bounding_box.left, detection.bounding_box.top
    end_point = detection.bounding_box.right, detection.bounding_box.bottom
    cv2.rectangle(image, start_point, end_point, _TEXT_COLOR, 3)

    # Draw label and score
    category = detection.categories[0]
    class_name = category.label
    probability = round(category.score, 2)
    result_text = class_name + ' (' + str(probability) + ')'
    text_location = (_MARGIN + detection.bounding_box.left,
                     _MARGIN + _ROW_SIZE + detection.bounding_box.top)
    cv2.putText(image, result_text, text_location, cv2.FONT_HERSHEY_PLAIN,
                _FONT_SIZE, _TEXT_COLOR, _FONT_THICKNESS)

  return image

# %%
from PIL import Image
INPUT_IMAGE_ONE = 'Thesis/All_Photos/Combined/Combined_TEST/0_merged.jpg' #@param {type:"string"}
DETECTION_THRESHOLD = 0.5 #@param {type:"number"}
TFLITE_MODEL_PATH = "Thesis/android.tfliteMerged" #@param {type:"string"}

TEMP_FILE = '/tmp/image.png'

# !wget -q -O $TEMP_FILE $INPUT_IMAGE_ONE

#image = Image.open(TEMP_FILE).convert('RGB')
image_one = Image.open(INPUT_IMAGE_ONE).convert('RGB')
image_one.thumbnail((512, 512), Image.ANTIALIAS)
image_np_one = np.asarray(image_one)

# Load the TFLite model
options = ObjectDetectorOptions(
      num_threads=4,
      score_threshold=DETECTION_THRESHOLD,
)
detector = ObjectDetector(model_path=TFLITE_MODEL_PATH, options=options)

# Run object detection estimation using the model.
detections = detector.detect(image_np_one)

# Draw keypoints and edges on input image
image_np_one = visualize(image_np_one, detections)

# Show the detection result
Image.fromarray(image_np_one)
# Out:
# <PIL.Image.Image image mode=RGB size=512x341 at 0x7F11D15956D0>

# %%
#INPUT_IMAGE_URL = 'JPEG/Validate/2_33226e67-1692-4472-88be-acdbace303f5_1024x1024.jpg'
INPUT_IMAGE_URL = 'Thesis/All_Photos/Combined/Combined_TEST/6_merged.jpg'
DISP_IMAGE_OVERLAY = 'Thesis/All_Photos/Combined/Combined_TEST/6_merged.jpg'

# %%
#@title Run object detection and show the detection results

# from PIL import Image

# INPUT_IMAGE_URL = 'Depth_Map_Image/2_disp.jpeg'
# INPUT_IMAGE_URL = "http://download.tensorflow.org/example_images/android_figurine.jpg" #@param {type:"string"}
INPUT_IMAGE_URL = INPUT_IMAGE_URL #@param {type:"string"}
DETECTION_THRESHOLD = 0.5 #@param {type:"number"}
TFLITE_MODEL_PATH = "Thesis/android.tfliteMerged" #@param {type:"string"}

TEMP_FILE = '/tmp/image.png'

# !wget -q -O $TEMP_FILE $INPUT_IMAGE_URL

#image = Image.open(TEMP_FILE).convert('RGB')
image = Image.open(INPUT_IMAGE_URL).convert('RGB')
image.thumbnail((512, 512), Image.ANTIALIAS)
image_np = np.asarray(image)

# Load the TFLite model
options = ObjectDetectorOptions(
      num_threads=4,
      score_threshold=DETECTION_THRESHOLD,
)
detector = ObjectDetector(model_path=TFLITE_MODEL_PATH, options=options)

# Run object detection estimation using the model.
detections = detector.detect(image_np)

# Draw keypoints and edges on input image
image_np = visualize(image_np, detections)

# Show the detection result
Image.fromarray(image_np)



# #image = Image.open(TEMP_FILE).convert('RGB')
# image_two = Image.open(DISP_IMAGE_OVERLAY).convert('RGB')
# image_two.thumbnail((512, 512), Image.ANTIALIAS)
# image_np_two = np.asarray(image_two)

# image_np_two = visualize(image_np_two, detections)
# Image.fromarray(image_np_two)
# Out:
# <PIL.Image.Image image mode=RGB size=512x288 at 0x7F11CF8F7550>

# %%
# image_two = Image.open(DISP_IMAGE_OVERLAY).convert('RGB')
# image_two.thumbnail((512, 512), Image.ANTIALIAS)
# image_np_two = np.asarray(image_two)

# image_np_two = visualize(image_np_two, detections)
# Image.fromarray(image_np_two)

# %%
t2 = time.perf_counter()
print('time taken to run:',t2-t1)
# Out:
# time taken to run: 10890.567765677999

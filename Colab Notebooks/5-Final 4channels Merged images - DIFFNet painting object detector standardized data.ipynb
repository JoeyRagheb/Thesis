# %% [markdown]
# ## Preparation
#
# ### Install the required packages
# Start by installing the required packages, including the Model Maker package from the [GitHub repo](https://github.com/tensorflow/examples/tree/master/tensorflow_examples/lite/model_maker) and the pycocotools library you'll use for evaluation.

# %%
# !pip install -q tflite-model-maker
# !pip install -q tflite-support
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.3/577.3 KB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 KB 16.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 57.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 KB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 MB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 KB 22.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.6/128.6 KB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 25.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 14.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.0/498.0 MB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 KB 36.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 KB 45.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 73.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 109.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 KB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.4/222.4 KB 27.3 MB/s eta 0:00:00
#   Building wheel for fire (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 2022.12.0 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.

# %% [markdown]
# Import the required packages.

# %%
import numpy as np
import os

from tflite_model_maker.config import ExportFormat, QuantizationConfig
from tflite_model_maker import model_spec
from tflite_model_maker import object_detector

from tflite_support import metadata

import tensorflow as tf
assert tf.__version__.startswith('2')

tf.get_logger().setLevel('ERROR')
from absl import logging
logging.set_verbosity(logging.ERROR)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.4 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %% [markdown]
# ### Prepare the dataset

# %%
#!wget https://storage.googleapis.com/download.tensorflow.org/data/android_figurine.zip
#!unzip -q android_figurine.zip
from google.colab import drive
drive.mount('/content/drive/', force_remount=True) #, force_remount=True
# Out:
# Mounted at /content/drive/

# %%
# Run this if need to force remount
import os
path = "/content" # /content is pretty much the root. you can choose other path in your colab workspace
os.chdir(path)

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/My Drive/
# Out:
# /content/drive/My Drive

# %%
# !unzip -q Colab_1024.zip # This should be on when running first time

# %% [markdown]
# ## Train the object detection model
#
# ### Step 1: Load the dataset
#
# * Images in `train_data` is used to train the custom object detection model.
# * Images in `val_data` is used to check if the model can generalize well to new images that it hasn't seen before.

# %%
# !pwd
# Out:
# /content/drive/My Drive

# %%
train_data = object_detector.DataLoader.from_pascal_voc(
    'Thesis/All_Photos/6_channels/6_TRAIN',
    'Thesis/All_Photos/6_channels/6_TRAIN',
    ['painting','Real_Tunnel']
)

val_data = object_detector.DataLoader.from_pascal_voc(
    'Thesis/All_Photos/6_channels/6_TEST',
    'Thesis/All_Photos/6_channels/6_TEST',
    ['painting','Real_Tunnel']
)

# %%
print(train_data.size)
# Out:
# 25

# %%
print(val_data.size)
# Out:
# 7

# %% [markdown]
# ### Step 2: Select a model architecture
#
# EfficientDet-Lite[0-4] are a family of mobile/IoT-friendly object detection models derived from the [EfficientDet](https://arxiv.org/abs/1911.09070) architecture.
#
# Here is the performance of each EfficientDet-Lite models compared to each others.
#
# | Model architecture | Size(MB)* | Latency(ms)** | Average Precision*** |
# |--------------------|-----------|---------------|----------------------|
# | EfficientDet-Lite0 | 4.4       | 146           | 25.69%               |
# | EfficientDet-Lite1 | 5.8       | 259           | 30.55%               |
# | EfficientDet-Lite2 | 7.2       | 396           | 33.97%               |
# | EfficientDet-Lite3 | 11.4      | 716           | 37.70%               |
# | EfficientDet-Lite4 | 19.9      | 1886          | 41.96%               |
#
# <i> * Size of the integer quantized models. <br/>
# ** Latency measured on Raspberry Pi 4 using 4 threads on CPU. <br/>
# *** Average Precision is the mAP (mean Average Precision) on the COCO 2017 validation dataset.
# </i>
#
# In this notebook, we use EfficientDet-Lite0 to train our model. You can choose other model architectures depending on whether speed or accuracy is more important to you.

# %%
spec = model_spec.get('efficientdet_lite4')

# %% [markdown]
# ### Step 3: Train the TensorFlow model with the training data.
#
# * Set `epochs = 20`, which means it will go through the training dataset 20 times. You can look at the validation accuracy during training and stop when you see validation loss (`val_loss`) stop decreasing to avoid overfitting.
# * Set `batch_size = 4` here so you will see that it takes 15 steps to go through the 62 images in the training dataset.
# * Set `train_whole_model=True` to fine-tune the whole model instead of just training the head layer to improve accuracy. The trade-off is that it may take longer to train the model.

# %%
import time
t1 = time.perf_counter()

# %%
model = object_detector.create(train_data, model_spec=spec, batch_size=4, train_whole_model=True, epochs=100, validation_data=val_data)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 85s 3s/step - det_loss: 1.7529 - cls_loss: 1.1558 - box_loss: 0.0119 - reg_l2_loss: 0.1078 - loss: 1.8607 - learning_rate: 0.0066 - gradient_norm: 1.4559 - val_det_loss: 1.6758 - val_cls_loss: 1.1582 - val_box_loss: 0.0104 - val_reg_l2_loss: 0.1078 - val_loss: 1.7836
# Epoch 2/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 1.7044 - cls_loss: 1.1482 - box_loss: 0.0111 - reg_l2_loss: 0.1078 - loss: 1.8122 - learning_rate: 0.0050 - gradient_norm: 1.4725 - val_det_loss: 1.5925 - val_cls_loss: 1.1494 - val_box_loss: 0.0089 - val_reg_l2_loss: 0.1078 - val_loss: 1.7003
# Epoch 3/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 1.6401 - cls_loss: 1.1382 - box_loss: 0.0100 - reg_l2_loss: 0.1078 - loss: 1.7479 - learning_rate: 0.0050 - gradient_norm: 1.6215 - val_det_loss: 1.5115 - val_cls_loss: 1.1362 - val_box_loss: 0.0075 - val_reg_l2_loss: 0.1078 - val_loss: 1.6193
# Epoch 4/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 1.5769 - cls_loss: 1.1247 - box_loss: 0.0090 - reg_l2_loss: 0.1078 - loss: 1.6846 - learning_rate: 0.0050 - gradient_norm: 2.7916 - val_det_loss: 1.4571 - val_cls_loss: 1.1175 - val_box_loss: 0.0068 - val_reg_l2_loss: 0.1078 - val_loss: 1.5648
# Epoch 5/100
# 6/6 [==============================] - 18s 3s/step - det_loss: 1.5724 - cls_loss: 1.1137 - box_loss: 0.0092 - reg_l2_loss: 0.1078 - loss: 1.6802 - learning_rate: 0.0050 - gradient_norm: 2.1028 - val_det_loss: 1.3982 - val_cls_loss: 1.0898 - val_box_loss: 0.0062 - val_reg_l2_loss: 0.1078 - val_loss: 1.5060
# Epoch 6/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 1.4434 - cls_loss: 1.0889 - box_loss: 0.0071 - reg_l2_loss: 0.1078 - loss: 1.5512 - learning_rate: 0.0050 - gradient_norm: 3.1555 - val_det_loss: 1.3443 - val_cls_loss: 1.0456 - val_box_loss: 0.0060 - val_reg_l2_loss: 0.1078 - val_loss: 1.4521
# Epoch 7/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 1.4299 - cls_loss: 1.0558 - box_loss: 0.0075 - reg_l2_loss: 0.1078 - loss: 1.5376 - learning_rate: 0.0049 - gradient_norm: 4.0069 - val_det_loss: 1.2986 - val_cls_loss: 0.9722 - val_box_loss: 0.0065 - val_reg_l2_loss: 0.1078 - val_loss: 1.4064
# Epoch 8/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 1.3801 - cls_loss: 1.0333 - box_loss: 0.0069 - reg_l2_loss: 0.1078 - loss: 1.4879 - learning_rate: 0.0049 - gradient_norm: 4.9293 - val_det_loss: 1.1751 - val_cls_loss: 0.8804 - val_box_loss: 0.0059 - val_reg_l2_loss: 0.1078 - val_loss: 1.2829
# Epoch 9/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.2203 - cls_loss: 0.9286 - box_loss: 0.0058 - reg_l2_loss: 0.1078 - loss: 1.3280 - learning_rate: 0.0049 - gradient_norm: 3.3617 - val_det_loss: 0.9852 - val_cls_loss: 0.7568 - val_box_loss: 0.0046 - val_reg_l2_loss: 0.1078 - val_loss: 1.0930
# Epoch 10/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 1.1749 - cls_loss: 0.8677 - box_loss: 0.0061 - reg_l2_loss: 0.1078 - loss: 1.2827 - learning_rate: 0.0049 - gradient_norm: 4.3729 - val_det_loss: 0.9066 - val_cls_loss: 0.7249 - val_box_loss: 0.0036 - val_reg_l2_loss: 0.1078 - val_loss: 1.0144
# Epoch 11/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.0086 - cls_loss: 0.7712 - box_loss: 0.0047 - reg_l2_loss: 0.1078 - loss: 1.1165 - learning_rate: 0.0049 - gradient_norm: 3.4441 - val_det_loss: 1.0568 - val_cls_loss: 0.8411 - val_box_loss: 0.0043 - val_reg_l2_loss: 0.1078 - val_loss: 1.1646
# Epoch 12/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.8990 - cls_loss: 0.6850 - box_loss: 0.0043 - reg_l2_loss: 0.1078 - loss: 1.0068 - learning_rate: 0.0048 - gradient_norm: 3.2659 - val_det_loss: 0.9463 - val_cls_loss: 0.7787 - val_box_loss: 0.0034 - val_reg_l2_loss: 0.1078 - val_loss: 1.0541
# Epoch 13/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.8169 - cls_loss: 0.6186 - box_loss: 0.0040 - reg_l2_loss: 0.1078 - loss: 0.9248 - learning_rate: 0.0048 - gradient_norm: 3.6355 - val_det_loss: 0.8319 - val_cls_loss: 0.6550 - val_box_loss: 0.0035 - val_reg_l2_loss: 0.1078 - val_loss: 0.9397
# Epoch 14/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.7402 - cls_loss: 0.5548 - box_loss: 0.0037 - reg_l2_loss: 0.1078 - loss: 0.8481 - learning_rate: 0.0048 - gradient_norm: 3.5007 - val_det_loss: 0.7309 - val_cls_loss: 0.6087 - val_box_loss: 0.0024 - val_reg_l2_loss: 0.1078 - val_loss: 0.8387
# Epoch 15/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.6825 - cls_loss: 0.5165 - box_loss: 0.0033 - reg_l2_loss: 0.1078 - loss: 0.7903 - learning_rate: 0.0047 - gradient_norm: 4.8401 - val_det_loss: 0.7181 - val_cls_loss: 0.5703 - val_box_loss: 0.0030 - val_reg_l2_loss: 0.1078 - val_loss: 0.8260
# Epoch 16/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.7568 - cls_loss: 0.5606 - box_loss: 0.0039 - reg_l2_loss: 0.1078 - loss: 0.8647 - learning_rate: 0.0047 - gradient_norm: 5.5006 - val_det_loss: 0.6541 - val_cls_loss: 0.5429 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1078 - val_loss: 0.7619
# Epoch 17/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.7182 - cls_loss: 0.5551 - box_loss: 0.0033 - reg_l2_loss: 0.1079 - loss: 0.8261 - learning_rate: 0.0047 - gradient_norm: 3.9781 - val_det_loss: 0.6346 - val_cls_loss: 0.5404 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1079 - val_loss: 0.7425
# Epoch 18/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.6651 - cls_loss: 0.4918 - box_loss: 0.0035 - reg_l2_loss: 0.1079 - loss: 0.7730 - learning_rate: 0.0046 - gradient_norm: 3.7163 - val_det_loss: 0.7119 - val_cls_loss: 0.5965 - val_box_loss: 0.0023 - val_reg_l2_loss: 0.1079 - val_loss: 0.8197
# Epoch 19/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.6244 - cls_loss: 0.4588 - box_loss: 0.0033 - reg_l2_loss: 0.1079 - loss: 0.7323 - learning_rate: 0.0046 - gradient_norm: 4.5755 - val_det_loss: 0.6329 - val_cls_loss: 0.5444 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.7408
# Epoch 20/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.6818 - cls_loss: 0.5182 - box_loss: 0.0033 - reg_l2_loss: 0.1079 - loss: 0.7897 - learning_rate: 0.0045 - gradient_norm: 4.9077 - val_det_loss: 0.6345 - val_cls_loss: 0.5537 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.1079 - val_loss: 0.7424
# Epoch 21/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.6290 - cls_loss: 0.4740 - box_loss: 0.0031 - reg_l2_loss: 0.1079 - loss: 0.7369 - learning_rate: 0.0045 - gradient_norm: 4.9774 - val_det_loss: 0.6953 - val_cls_loss: 0.5850 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1079 - val_loss: 0.8032
# Epoch 22/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.5635 - cls_loss: 0.4149 - box_loss: 0.0030 - reg_l2_loss: 0.1079 - loss: 0.6714 - learning_rate: 0.0044 - gradient_norm: 3.2161 - val_det_loss: 0.7740 - val_cls_loss: 0.6384 - val_box_loss: 0.0027 - val_reg_l2_loss: 0.1079 - val_loss: 0.8818
# Epoch 23/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.5505 - cls_loss: 0.4056 - box_loss: 0.0029 - reg_l2_loss: 0.1079 - loss: 0.6584 - learning_rate: 0.0044 - gradient_norm: 3.8324 - val_det_loss: 0.7986 - val_cls_loss: 0.6603 - val_box_loss: 0.0028 - val_reg_l2_loss: 0.1079 - val_loss: 0.9065
# Epoch 24/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.5267 - cls_loss: 0.4034 - box_loss: 0.0025 - reg_l2_loss: 0.1079 - loss: 0.6346 - learning_rate: 0.0043 - gradient_norm: 4.4729 - val_det_loss: 0.7224 - val_cls_loss: 0.6020 - val_box_loss: 0.0024 - val_reg_l2_loss: 0.1079 - val_loss: 0.8303
# Epoch 25/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.5731 - cls_loss: 0.4094 - box_loss: 0.0033 - reg_l2_loss: 0.1079 - loss: 0.6810 - learning_rate: 0.0043 - gradient_norm: 5.6212 - val_det_loss: 0.6199 - val_cls_loss: 0.5262 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1079 - val_loss: 0.7278
# Epoch 26/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.4677 - cls_loss: 0.3464 - box_loss: 0.0024 - reg_l2_loss: 0.1079 - loss: 0.5756 - learning_rate: 0.0042 - gradient_norm: 5.0912 - val_det_loss: 0.4478 - val_cls_loss: 0.3920 - val_box_loss: 0.0011 - val_reg_l2_loss: 0.1079 - val_loss: 0.5557
# Epoch 27/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4711 - cls_loss: 0.3288 - box_loss: 0.0028 - reg_l2_loss: 0.1079 - loss: 0.5790 - learning_rate: 0.0042 - gradient_norm: 4.8128 - val_det_loss: 0.4176 - val_cls_loss: 0.3686 - val_box_loss: 9.7996e-04 - val_reg_l2_loss: 0.1079 - val_loss: 0.5255
# Epoch 28/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.4774 - cls_loss: 0.3376 - box_loss: 0.0028 - reg_l2_loss: 0.1079 - loss: 0.5853 - learning_rate: 0.0041 - gradient_norm: 4.4652 - val_det_loss: 0.4062 - val_cls_loss: 0.3562 - val_box_loss: 0.0010 - val_reg_l2_loss: 0.1079 - val_loss: 0.5142
# Epoch 29/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4333 - cls_loss: 0.3252 - box_loss: 0.0022 - reg_l2_loss: 0.1079 - loss: 0.5412 - learning_rate: 0.0040 - gradient_norm: 4.4789 - val_det_loss: 0.4271 - val_cls_loss: 0.3416 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.5350
# Epoch 30/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3853 - cls_loss: 0.2698 - box_loss: 0.0023 - reg_l2_loss: 0.1079 - loss: 0.4933 - learning_rate: 0.0040 - gradient_norm: 4.8940 - val_det_loss: 0.3337 - val_cls_loss: 0.2764 - val_box_loss: 0.0011 - val_reg_l2_loss: 0.1079 - val_loss: 0.4416
# Epoch 31/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.3462 - cls_loss: 0.2515 - box_loss: 0.0019 - reg_l2_loss: 0.1079 - loss: 0.4542 - learning_rate: 0.0039 - gradient_norm: 3.4850 - val_det_loss: 0.3478 - val_cls_loss: 0.2841 - val_box_loss: 0.0013 - val_reg_l2_loss: 0.1079 - val_loss: 0.4557
# Epoch 32/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4519 - cls_loss: 0.3331 - box_loss: 0.0024 - reg_l2_loss: 0.1079 - loss: 0.5598 - learning_rate: 0.0039 - gradient_norm: 4.8011 - val_det_loss: 0.3613 - val_cls_loss: 0.2743 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.4692
# Epoch 33/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.4159 - cls_loss: 0.3172 - box_loss: 0.0020 - reg_l2_loss: 0.1079 - loss: 0.5238 - learning_rate: 0.0038 - gradient_norm: 3.5324 - val_det_loss: 0.3229 - val_cls_loss: 0.2603 - val_box_loss: 0.0013 - val_reg_l2_loss: 0.1080 - val_loss: 0.4308
# Epoch 34/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3680 - cls_loss: 0.2730 - box_loss: 0.0019 - reg_l2_loss: 0.1080 - loss: 0.4759 - learning_rate: 0.0037 - gradient_norm: 2.3904 - val_det_loss: 0.3637 - val_cls_loss: 0.3039 - val_box_loss: 0.0012 - val_reg_l2_loss: 0.1080 - val_loss: 0.4716
# Epoch 35/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 0.3617 - cls_loss: 0.2722 - box_loss: 0.0018 - reg_l2_loss: 0.1080 - loss: 0.4696 - learning_rate: 0.0036 - gradient_norm: 3.5165 - val_det_loss: 0.3214 - val_cls_loss: 0.2571 - val_box_loss: 0.0013 - val_reg_l2_loss: 0.1080 - val_loss: 0.4294
# Epoch 36/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3628 - cls_loss: 0.2662 - box_loss: 0.0019 - reg_l2_loss: 0.1080 - loss: 0.4708 - learning_rate: 0.0036 - gradient_norm: 3.6326 - val_det_loss: 0.3144 - val_cls_loss: 0.2440 - val_box_loss: 0.0014 - val_reg_l2_loss: 0.1080 - val_loss: 0.4224
# Epoch 37/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3344 - cls_loss: 0.2515 - box_loss: 0.0017 - reg_l2_loss: 0.1080 - loss: 0.4423 - learning_rate: 0.0035 - gradient_norm: 3.5533 - val_det_loss: 0.3291 - val_cls_loss: 0.2489 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.1080 - val_loss: 0.4370
# Epoch 38/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.3207 - cls_loss: 0.2224 - box_loss: 0.0020 - reg_l2_loss: 0.1080 - loss: 0.4287 - learning_rate: 0.0034 - gradient_norm: 3.2478 - val_det_loss: 0.3245 - val_cls_loss: 0.2598 - val_box_loss: 0.0013 - val_reg_l2_loss: 0.1080 - val_loss: 0.4324
# Epoch 39/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3007 - cls_loss: 0.2036 - box_loss: 0.0019 - reg_l2_loss: 0.1080 - loss: 0.4087 - learning_rate: 0.0034 - gradient_norm: 3.5386 - val_det_loss: 0.3172 - val_cls_loss: 0.2529 - val_box_loss: 0.0013 - val_reg_l2_loss: 0.1080 - val_loss: 0.4252
# Epoch 40/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 0.3566 - cls_loss: 0.2565 - box_loss: 0.0020 - reg_l2_loss: 0.1080 - loss: 0.4646 - learning_rate: 0.0033 - gradient_norm: 3.1561 - val_det_loss: 0.3581 - val_cls_loss: 0.2457 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1080 - val_loss: 0.4661
# Epoch 41/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.3323 - cls_loss: 0.2450 - box_loss: 0.0017 - reg_l2_loss: 0.1080 - loss: 0.4403 - learning_rate: 0.0032 - gradient_norm: 4.4700 - val_det_loss: 0.2889 - val_cls_loss: 0.2264 - val_box_loss: 0.0013 - val_reg_l2_loss: 0.1080 - val_loss: 0.3969
# Epoch 42/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.4254 - cls_loss: 0.2941 - box_loss: 0.0026 - reg_l2_loss: 0.1080 - loss: 0.5334 - learning_rate: 0.0031 - gradient_norm: 3.5589 - val_det_loss: 0.2727 - val_cls_loss: 0.2260 - val_box_loss: 9.3299e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3807
# Epoch 43/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3140 - cls_loss: 0.2143 - box_loss: 0.0020 - reg_l2_loss: 0.1080 - loss: 0.4219 - learning_rate: 0.0031 - gradient_norm: 3.9466 - val_det_loss: 0.3100 - val_cls_loss: 0.2350 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4179
# Epoch 44/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3119 - cls_loss: 0.2115 - box_loss: 0.0020 - reg_l2_loss: 0.1080 - loss: 0.4198 - learning_rate: 0.0030 - gradient_norm: 2.6124 - val_det_loss: 0.2758 - val_cls_loss: 0.2203 - val_box_loss: 0.0011 - val_reg_l2_loss: 0.1080 - val_loss: 0.3838
# Epoch 45/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 0.3104 - cls_loss: 0.2320 - box_loss: 0.0016 - reg_l2_loss: 0.1080 - loss: 0.4183 - learning_rate: 0.0029 - gradient_norm: 3.6321 - val_det_loss: 0.2722 - val_cls_loss: 0.2159 - val_box_loss: 0.0011 - val_reg_l2_loss: 0.1080 - val_loss: 0.3802
# Epoch 46/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3248 - cls_loss: 0.2477 - box_loss: 0.0015 - reg_l2_loss: 0.1080 - loss: 0.4328 - learning_rate: 0.0028 - gradient_norm: 4.0695 - val_det_loss: 0.2913 - val_cls_loss: 0.2242 - val_box_loss: 0.0013 - val_reg_l2_loss: 0.1080 - val_loss: 0.3993
# Epoch 47/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.3344 - cls_loss: 0.2504 - box_loss: 0.0017 - reg_l2_loss: 0.1080 - loss: 0.4424 - learning_rate: 0.0027 - gradient_norm: 4.7122 - val_det_loss: 0.2800 - val_cls_loss: 0.2346 - val_box_loss: 9.0857e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3880
# Epoch 48/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.3953 - cls_loss: 0.2961 - box_loss: 0.0020 - reg_l2_loss: 0.1080 - loss: 0.5033 - learning_rate: 0.0027 - gradient_norm: 3.9626 - val_det_loss: 0.2507 - val_cls_loss: 0.2137 - val_box_loss: 7.4103e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3587
# Epoch 49/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2873 - cls_loss: 0.2155 - box_loss: 0.0014 - reg_l2_loss: 0.1080 - loss: 0.3953 - learning_rate: 0.0026 - gradient_norm: 3.2513 - val_det_loss: 0.2468 - val_cls_loss: 0.2092 - val_box_loss: 7.5262e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3548
# Epoch 50/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2934 - cls_loss: 0.2123 - box_loss: 0.0016 - reg_l2_loss: 0.1080 - loss: 0.4014 - learning_rate: 0.0025 - gradient_norm: 4.2578 - val_det_loss: 0.2534 - val_cls_loss: 0.2171 - val_box_loss: 7.2619e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3614
# Epoch 51/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3362 - cls_loss: 0.2471 - box_loss: 0.0018 - reg_l2_loss: 0.1080 - loss: 0.4442 - learning_rate: 0.0024 - gradient_norm: 3.7978 - val_det_loss: 0.2487 - val_cls_loss: 0.2124 - val_box_loss: 7.2644e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3567
# Epoch 52/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2619 - cls_loss: 0.1818 - box_loss: 0.0016 - reg_l2_loss: 0.1080 - loss: 0.3699 - learning_rate: 0.0023 - gradient_norm: 3.0543 - val_det_loss: 0.2732 - val_cls_loss: 0.2293 - val_box_loss: 8.7773e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3812
# Epoch 53/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2707 - cls_loss: 0.2019 - box_loss: 0.0014 - reg_l2_loss: 0.1080 - loss: 0.3787 - learning_rate: 0.0023 - gradient_norm: 3.6224 - val_det_loss: 0.2781 - val_cls_loss: 0.2357 - val_box_loss: 8.4666e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3860
# Epoch 54/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2728 - cls_loss: 0.1981 - box_loss: 0.0015 - reg_l2_loss: 0.1080 - loss: 0.3808 - learning_rate: 0.0022 - gradient_norm: 2.9158 - val_det_loss: 0.2704 - val_cls_loss: 0.2278 - val_box_loss: 8.5246e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3784
# Epoch 55/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2290 - cls_loss: 0.1736 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3370 - learning_rate: 0.0021 - gradient_norm: 3.0591 - val_det_loss: 0.2618 - val_cls_loss: 0.2247 - val_box_loss: 7.4228e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3698
# Epoch 56/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2585 - cls_loss: 0.1977 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3665 - learning_rate: 0.0020 - gradient_norm: 3.7204 - val_det_loss: 0.2705 - val_cls_loss: 0.2244 - val_box_loss: 9.2211e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3785
# Epoch 57/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2511 - cls_loss: 0.1876 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3591 - learning_rate: 0.0020 - gradient_norm: 2.4242 - val_det_loss: 0.2923 - val_cls_loss: 0.2477 - val_box_loss: 8.9095e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.4003
# Epoch 58/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3157 - cls_loss: 0.2297 - box_loss: 0.0017 - reg_l2_loss: 0.1080 - loss: 0.4237 - learning_rate: 0.0019 - gradient_norm: 3.7512 - val_det_loss: 0.2919 - val_cls_loss: 0.2467 - val_box_loss: 9.0353e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3999
# Epoch 59/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2797 - cls_loss: 0.1984 - box_loss: 0.0016 - reg_l2_loss: 0.1080 - loss: 0.3877 - learning_rate: 0.0018 - gradient_norm: 3.3780 - val_det_loss: 0.2772 - val_cls_loss: 0.2285 - val_box_loss: 9.7311e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3852
# Epoch 60/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2429 - cls_loss: 0.1818 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3509 - learning_rate: 0.0017 - gradient_norm: 3.6265 - val_det_loss: 0.2787 - val_cls_loss: 0.2211 - val_box_loss: 0.0012 - val_reg_l2_loss: 0.1080 - val_loss: 0.3867
# Epoch 61/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2894 - cls_loss: 0.2118 - box_loss: 0.0016 - reg_l2_loss: 0.1080 - loss: 0.3974 - learning_rate: 0.0016 - gradient_norm: 3.7418 - val_det_loss: 0.2695 - val_cls_loss: 0.2226 - val_box_loss: 9.3769e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3775
# Epoch 62/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3492 - cls_loss: 0.2609 - box_loss: 0.0018 - reg_l2_loss: 0.1080 - loss: 0.4572 - learning_rate: 0.0016 - gradient_norm: 5.5328 - val_det_loss: 0.2556 - val_cls_loss: 0.2089 - val_box_loss: 9.3468e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3636
# Epoch 63/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2634 - cls_loss: 0.2010 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3714 - learning_rate: 0.0015 - gradient_norm: 3.4762 - val_det_loss: 0.2399 - val_cls_loss: 0.1928 - val_box_loss: 9.4180e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3479
# Epoch 64/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2392 - cls_loss: 0.1851 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3472 - learning_rate: 0.0014 - gradient_norm: 2.9104 - val_det_loss: 0.2477 - val_cls_loss: 0.1995 - val_box_loss: 9.6500e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3557
# Epoch 65/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2271 - cls_loss: 0.1661 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3351 - learning_rate: 0.0014 - gradient_norm: 2.4177 - val_det_loss: 0.2422 - val_cls_loss: 0.1969 - val_box_loss: 9.0577e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3502
# Epoch 66/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2182 - cls_loss: 0.1635 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3262 - learning_rate: 0.0013 - gradient_norm: 2.2003 - val_det_loss: 0.2391 - val_cls_loss: 0.1988 - val_box_loss: 8.0588e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3471
# Epoch 67/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2305 - cls_loss: 0.1770 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3385 - learning_rate: 0.0012 - gradient_norm: 2.3882 - val_det_loss: 0.2238 - val_cls_loss: 0.1855 - val_box_loss: 7.6617e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3318
# Epoch 68/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 0.2500 - cls_loss: 0.1888 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3580 - learning_rate: 0.0012 - gradient_norm: 2.9908 - val_det_loss: 0.2201 - val_cls_loss: 0.1817 - val_box_loss: 7.6612e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3281
# Epoch 69/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2191 - cls_loss: 0.1759 - box_loss: 8.6466e-04 - reg_l2_loss: 0.1080 - loss: 0.3271 - learning_rate: 0.0011 - gradient_norm: 3.2209 - val_det_loss: 0.2169 - val_cls_loss: 0.1793 - val_box_loss: 7.5047e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3249
# Epoch 70/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2352 - cls_loss: 0.1875 - box_loss: 9.5436e-04 - reg_l2_loss: 0.1080 - loss: 0.3432 - learning_rate: 0.0010 - gradient_norm: 3.0787 - val_det_loss: 0.2180 - val_cls_loss: 0.1812 - val_box_loss: 7.3669e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3260
# Epoch 71/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2144 - cls_loss: 0.1679 - box_loss: 9.2893e-04 - reg_l2_loss: 0.1080 - loss: 0.3224 - learning_rate: 9.5616e-04 - gradient_norm: 3.1376 - val_det_loss: 0.2206 - val_cls_loss: 0.1836 - val_box_loss: 7.3910e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3286
# Epoch 72/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2107 - cls_loss: 0.1617 - box_loss: 9.7938e-04 - reg_l2_loss: 0.1080 - loss: 0.3187 - learning_rate: 8.9455e-04 - gradient_norm: 2.6424 - val_det_loss: 0.2191 - val_cls_loss: 0.1843 - val_box_loss: 6.9519e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3271
# Epoch 73/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2085 - cls_loss: 0.1591 - box_loss: 9.8731e-04 - reg_l2_loss: 0.1080 - loss: 0.3165 - learning_rate: 8.3456e-04 - gradient_norm: 3.5937 - val_det_loss: 0.2129 - val_cls_loss: 0.1788 - val_box_loss: 6.8143e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3209
# Epoch 74/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1916 - cls_loss: 0.1431 - box_loss: 9.7072e-04 - reg_l2_loss: 0.1080 - loss: 0.2996 - learning_rate: 7.7625e-04 - gradient_norm: 2.6715 - val_det_loss: 0.2122 - val_cls_loss: 0.1785 - val_box_loss: 6.7431e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3202
# Epoch 75/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 0.3232 - cls_loss: 0.2141 - box_loss: 0.0022 - reg_l2_loss: 0.1080 - loss: 0.4312 - learning_rate: 7.1967e-04 - gradient_norm: 3.7387 - val_det_loss: 0.2039 - val_cls_loss: 0.1723 - val_box_loss: 6.3093e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3119
# Epoch 76/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2577 - cls_loss: 0.2074 - box_loss: 0.0010 - reg_l2_loss: 0.1080 - loss: 0.3657 - learning_rate: 6.6489e-04 - gradient_norm: 4.3694 - val_det_loss: 0.2073 - val_cls_loss: 0.1740 - val_box_loss: 6.6751e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3153
# Epoch 77/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2441 - cls_loss: 0.1934 - box_loss: 0.0010 - reg_l2_loss: 0.1080 - loss: 0.3521 - learning_rate: 6.1195e-04 - gradient_norm: 3.0538 - val_det_loss: 0.2072 - val_cls_loss: 0.1744 - val_box_loss: 6.5726e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3152
# Epoch 78/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2052 - cls_loss: 0.1667 - box_loss: 7.7010e-04 - reg_l2_loss: 0.1080 - loss: 0.3132 - learning_rate: 5.6091e-04 - gradient_norm: 2.3951 - val_det_loss: 0.2044 - val_cls_loss: 0.1744 - val_box_loss: 5.9810e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3124
# Epoch 79/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2477 - cls_loss: 0.1841 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3557 - learning_rate: 5.1183e-04 - gradient_norm: 3.1808 - val_det_loss: 0.2032 - val_cls_loss: 0.1751 - val_box_loss: 5.6265e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3112
# Epoch 80/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2710 - cls_loss: 0.2043 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3790 - learning_rate: 4.6475e-04 - gradient_norm: 4.4045 - val_det_loss: 0.2075 - val_cls_loss: 0.1786 - val_box_loss: 5.7875e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3155
# Epoch 81/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2597 - cls_loss: 0.2003 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3677 - learning_rate: 4.1972e-04 - gradient_norm: 2.8362 - val_det_loss: 0.2159 - val_cls_loss: 0.1845 - val_box_loss: 6.2910e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3239
# Epoch 82/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2637 - cls_loss: 0.2028 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3717 - learning_rate: 3.7678e-04 - gradient_norm: 3.9588 - val_det_loss: 0.2239 - val_cls_loss: 0.1891 - val_box_loss: 6.9667e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3319
# Epoch 83/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1994 - cls_loss: 0.1598 - box_loss: 7.9086e-04 - reg_l2_loss: 0.1080 - loss: 0.3074 - learning_rate: 3.3598e-04 - gradient_norm: 1.7235 - val_det_loss: 0.2278 - val_cls_loss: 0.1911 - val_box_loss: 7.3307e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3358
# Epoch 84/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2385 - cls_loss: 0.1713 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3465 - learning_rate: 2.9736e-04 - gradient_norm: 2.5211 - val_det_loss: 0.2274 - val_cls_loss: 0.1911 - val_box_loss: 7.2419e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3354
# Epoch 85/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2006 - cls_loss: 0.1500 - box_loss: 0.0010 - reg_l2_loss: 0.1080 - loss: 0.3086 - learning_rate: 2.6096e-04 - gradient_norm: 2.3507 - val_det_loss: 0.2257 - val_cls_loss: 0.1918 - val_box_loss: 6.7872e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3337
# Epoch 86/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2012 - cls_loss: 0.1648 - box_loss: 7.2714e-04 - reg_l2_loss: 0.1080 - loss: 0.3092 - learning_rate: 2.2681e-04 - gradient_norm: 2.2933 - val_det_loss: 0.2236 - val_cls_loss: 0.1907 - val_box_loss: 6.5824e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3316
# Epoch 87/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2283 - cls_loss: 0.1696 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3363 - learning_rate: 1.9495e-04 - gradient_norm: 2.5890 - val_det_loss: 0.2222 - val_cls_loss: 0.1897 - val_box_loss: 6.4865e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3302
# Epoch 88/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2096 - cls_loss: 0.1662 - box_loss: 8.6815e-04 - reg_l2_loss: 0.1080 - loss: 0.3176 - learning_rate: 1.6541e-04 - gradient_norm: 2.3557 - val_det_loss: 0.2207 - val_cls_loss: 0.1879 - val_box_loss: 6.5688e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3287
# Epoch 89/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2657 - cls_loss: 0.2010 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3737 - learning_rate: 1.3822e-04 - gradient_norm: 2.9945 - val_det_loss: 0.2199 - val_cls_loss: 0.1867 - val_box_loss: 6.6314e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3279
# Epoch 90/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2057 - cls_loss: 0.1632 - box_loss: 8.4947e-04 - reg_l2_loss: 0.1080 - loss: 0.3137 - learning_rate: 1.1341e-04 - gradient_norm: 2.3998 - val_det_loss: 0.2182 - val_cls_loss: 0.1855 - val_box_loss: 6.5450e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3262
# Epoch 91/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2232 - cls_loss: 0.1606 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3313 - learning_rate: 9.1009e-05 - gradient_norm: 2.7673 - val_det_loss: 0.2160 - val_cls_loss: 0.1833 - val_box_loss: 6.5376e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3240
# Epoch 92/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2154 - cls_loss: 0.1604 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3234 - learning_rate: 7.1028e-05 - gradient_norm: 2.9714 - val_det_loss: 0.2164 - val_cls_loss: 0.1836 - val_box_loss: 6.5510e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3244
# Epoch 93/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2215 - cls_loss: 0.1788 - box_loss: 8.5490e-04 - reg_l2_loss: 0.1080 - loss: 0.3295 - learning_rate: 5.3493e-05 - gradient_norm: 2.7718 - val_det_loss: 0.2168 - val_cls_loss: 0.1843 - val_box_loss: 6.4921e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3248
# Epoch 94/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1864 - cls_loss: 0.1462 - box_loss: 8.0324e-04 - reg_l2_loss: 0.1080 - loss: 0.2944 - learning_rate: 3.8422e-05 - gradient_norm: 2.4003 - val_det_loss: 0.2152 - val_cls_loss: 0.1830 - val_box_loss: 6.4410e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3232
# Epoch 95/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2984 - cls_loss: 0.2263 - box_loss: 0.0014 - reg_l2_loss: 0.1080 - loss: 0.4064 - learning_rate: 2.5829e-05 - gradient_norm: 2.8360 - val_det_loss: 0.2127 - val_cls_loss: 0.1807 - val_box_loss: 6.3945e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3207
# Epoch 96/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 0.1969 - cls_loss: 0.1479 - box_loss: 9.7950e-04 - reg_l2_loss: 0.1080 - loss: 0.3049 - learning_rate: 1.5727e-05 - gradient_norm: 2.9656 - val_det_loss: 0.2122 - val_cls_loss: 0.1802 - val_box_loss: 6.4054e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3202
# Epoch 97/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2232 - cls_loss: 0.1727 - box_loss: 0.0010 - reg_l2_loss: 0.1080 - loss: 0.3312 - learning_rate: 8.1273e-06 - gradient_norm: 2.7635 - val_det_loss: 0.2130 - val_cls_loss: 0.1811 - val_box_loss: 6.3821e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3210
# Epoch 98/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2308 - cls_loss: 0.1855 - box_loss: 9.0516e-04 - reg_l2_loss: 0.1080 - loss: 0.3388 - learning_rate: 3.0362e-06 - gradient_norm: 2.1848 - val_det_loss: 0.2120 - val_cls_loss: 0.1804 - val_box_loss: 6.3254e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3200
# Epoch 99/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2061 - cls_loss: 0.1528 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3141 - learning_rate: 4.5955e-07 - gradient_norm: 2.2052 - val_det_loss: 0.2117 - val_cls_loss: 0.1802 - val_box_loss: 6.3143e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3197
# Epoch 100/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 0.2182 - cls_loss: 0.1709 - box_loss: 9.4612e-04 - reg_l2_loss: 0.1080 - loss: 0.3262 - learning_rate: 3.9961e-07 - gradient_norm: 2.0615 - val_det_loss: 0.2122 - val_cls_loss: 0.1803 - val_box_loss: 6.3768e-04 - val_reg_l2_loss: 0.1080 - val_loss: 0.3202

# %% [markdown]
# ### Step 4. Evaluate the model with the validation data.
#
# After training the object detection model using the images in the training dataset, use the 10 images in the validation dataset to evaluate how the model performs against new data it has never seen before.
#
# As the default batch size is 64, it will take 1 step to go through the 10 images in the validation dataset.
#
# The evaluation metrics are same as [COCO](https://cocodataset.org/#detection-eval).

# %%
model.evaluate(val_data)
# Out:
# 1/1 [==============================] - 9s 9s/step
# {'AP': 0.6998409,
#  'AP50': 0.91601837,
#  'AP75': 0.84529704,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.7001222,
#  'ARmax1': 0.77916664,
#  'ARmax10': 0.7916667,
#  'ARmax100': 0.7916667,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.7916667,
#  'AP_/painting': 0.83267325,
#  'AP_/Real_Tunnel': 0.5670085}

# %%
# import matplotlib.pyplot as plt
# print(model.history.keys())
# # summarize history for loss
# plt.plot(model.history['loss'])
# plt.plot(model.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %% [markdown]
# ### Step 5: Export as a TensorFlow Lite model.
#
# Export the trained object detection model to the TensorFlow Lite format by specifying which folder you want to export the quantized model to. The default post-training quantization technique is [full integer quantization](https://www.tensorflow.org/lite/performance/post_training_integer_quant). This allows the TensorFlow Lite model to be smaller, run faster on Raspberry Pi CPU and also compatible with the Google Coral EdgeTPU.

# %%
model.export(export_dir='Thesis/', tflite_filename='android.tfliteMentorFOURChannelsMerged')

# %% [markdown]
# ### Step 6:  Evaluate the TensorFlow Lite model.
#
# Several factors can affect the model accuracy when exporting to TFLite:
# * [Quantization](https://www.tensorflow.org/lite/performance/model_optimization) helps shrinking the model size by 4 times at the expense of some accuracy drop.
# * The original TensorFlow model uses per-class [non-max supression (NMS)](https://www.coursera.org/lecture/convolutional-neural-networks/non-max-suppression-dvrjH) for post-processing, while the TFLite model uses global NMS that's much faster but less accurate.
# Keras outputs maximum 100 detections while tflite outputs maximum 25 detections.
#
# Therefore you'll have to evaluate the exported TFLite model and compare its accuracy with the original TensorFlow model.

# %%
model.evaluate_tflite('Thesis/android.tfliteMentorFOURChannelsMerged', val_data)
# Out:
# 7/7 [==============================] - 422s 60s/step
# {'AP': 0.7018211,
#  'AP50': 0.91601837,
#  'AP75': 0.84529704,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.7018211,
#  'ARmax1': 0.775,
#  'ARmax10': 0.775,
#  'ARmax100': 0.775,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.775,
#  'AP_/painting': 0.7990099,
#  'AP_/Real_Tunnel': 0.60463226}

# %%
# Download the TFLite model to your local computer.
# from google.colab import files
# files.download('android.tfliteMentorFOURChannelsMerged')

# %% [markdown]
# ## Test the Android figurine detection model
#
# After training the model, let's test it with an image that the model hasn't seen before to get a sense of how good the model is.

# %%
#@title Load the trained TFLite model and define some visualization functions

#@markdown This code comes from the TFLite Object Detection [Raspberry Pi sample](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/raspberry_pi).

import platform
from typing import List, NamedTuple
import json

import cv2

Interpreter = tf.lite.Interpreter
load_delegate = tf.lite.experimental.load_delegate

# pylint: enable=g-import-not-at-top


class ObjectDetectorOptions(NamedTuple):
  """A config to initialize an object detector."""

  enable_edgetpu: bool = False
  """Enable the model to run on EdgeTPU."""

  label_allow_list: List[str] = None
  """The optional allow list of labels."""

  label_deny_list: List[str] = None
  """The optional deny list of labels."""

  max_results: int = -1
  """The maximum number of top-scored detection results to return."""

  num_threads: int = 1
  """The number of CPU threads to be used."""

  score_threshold: float = 0.0
  """The score threshold of detection results to return."""


class Rect(NamedTuple):
  """A rectangle in 2D space."""
  left: float
  top: float
  right: float
  bottom: float


class Category(NamedTuple):
  """A result of a classification task."""
  label: str
  score: float
  index: int


class Detection(NamedTuple):
  """A detected object as the result of an ObjectDetector."""
  bounding_box: Rect
  categories: List[Category]


def edgetpu_lib_name():
  """Returns the library name of EdgeTPU in the current platform."""
  return {
      'Darwin': 'libedgetpu.1.dylib',
      'Linux': 'libedgetpu.so.1',
      'Windows': 'edgetpu.dll',
  }.get(platform.system(), None)


class ObjectDetector:
  """A wrapper class for a TFLite object detection model."""

  _OUTPUT_LOCATION_NAME = 'location'
  _OUTPUT_CATEGORY_NAME = 'category'
  _OUTPUT_SCORE_NAME = 'score'
  _OUTPUT_NUMBER_NAME = 'number of detections'

  def __init__(
      self,
      model_path: str,
      options: ObjectDetectorOptions = ObjectDetectorOptions()
  ) -> None:
    """Initialize a TFLite object detection model.
    Args:
        model_path: Path to the TFLite model.
        options: The config to initialize an object detector. (Optional)
    Raises:
        ValueError: If the TFLite model is invalid.
        OSError: If the current OS isn't supported by EdgeTPU.
    """

    # Load metadata from model.
    displayer = metadata.MetadataDisplayer.with_model_file(model_path)

    # Save model metadata for preprocessing later.
    model_metadata = json.loads(displayer.get_metadata_json())
    process_units = model_metadata['subgraph_metadata'][0]['input_tensor_metadata'][0]['process_units']
    mean = 0.0
    std = 1.0
    for option in process_units:
      if option['options_type'] == 'NormalizationOptions':
        mean = option['options']['mean'][0]
        std = option['options']['std'][0]
    self._mean = mean
    self._std = std

    # Load label list from metadata.
    file_name = displayer.get_packed_associated_file_list()[0]
    label_map_file = displayer.get_associated_file_buffer(file_name).decode()
    label_list = list(filter(lambda x: len(x) > 0, label_map_file.splitlines()))
    self._label_list = label_list

    # Initialize TFLite model.
    if options.enable_edgetpu:
      if edgetpu_lib_name() is None:
        raise OSError("The current OS isn't supported by Coral EdgeTPU.")
      interpreter = Interpreter(
          model_path=model_path,
          experimental_delegates=[load_delegate(edgetpu_lib_name())],
          num_threads=options.num_threads)
    else:
      interpreter = Interpreter(
          model_path=model_path, num_threads=options.num_threads)

    interpreter.allocate_tensors()
    input_detail = interpreter.get_input_details()[0]

    # From TensorFlow 2.6, the order of the outputs become undefined.
    # Therefore we need to sort the tensor indices of TFLite outputs and to know
    # exactly the meaning of each output tensor. For example, if
    # output indices are [601, 599, 598, 600], tensor names and indices aligned
    # are:
    #   - location: 598
    #   - category: 599
    #   - score: 600
    #   - detection_count: 601
    # because of the op's ports of TFLITE_DETECTION_POST_PROCESS
    # (https://github.com/tensorflow/tensorflow/blob/a4fe268ea084e7d323133ed7b986e0ae259a2bc7/tensorflow/lite/kernels/detection_postprocess.cc#L47-L50).
    sorted_output_indices = sorted(
        [output['index'] for output in interpreter.get_output_details()])
    self._output_indices = {
        self._OUTPUT_LOCATION_NAME: sorted_output_indices[0],
        self._OUTPUT_CATEGORY_NAME: sorted_output_indices[1],
        self._OUTPUT_SCORE_NAME: sorted_output_indices[2],
        self._OUTPUT_NUMBER_NAME: sorted_output_indices[3],
    }

    self._input_size = input_detail['shape'][2], input_detail['shape'][1]
    self._is_quantized_input = input_detail['dtype'] == np.uint8
    self._interpreter = interpreter
    self._options = options

  def detect(self, input_image: np.ndarray) -> List[Detection]:
    """Run detection on an input image.
    Args:
        input_image: A [height, width, 3] RGB image. Note that height and width
          can be anything since the image will be immediately resized according
          to the needs of the model within this function.
    Returns:
        A Person instance.
    """
    image_height, image_width, _ = input_image.shape

    input_tensor = self._preprocess(input_image)

    self._set_input_tensor(input_tensor)
    self._interpreter.invoke()

    # Get all output details
    boxes = self._get_output_tensor(self._OUTPUT_LOCATION_NAME)
    classes = self._get_output_tensor(self._OUTPUT_CATEGORY_NAME)
    scores = self._get_output_tensor(self._OUTPUT_SCORE_NAME)
    count = int(self._get_output_tensor(self._OUTPUT_NUMBER_NAME))

    return self._postprocess(boxes, classes, scores, count, image_width,
                             image_height)

  def _preprocess(self, input_image: np.ndarray) -> np.ndarray:
    """Preprocess the input image as required by the TFLite model."""

    # Resize the input
    input_tensor = cv2.resize(input_image, self._input_size)

    # Normalize the input if it's a float model (aka. not quantized)
    if not self._is_quantized_input:
      input_tensor = (np.float32(input_tensor) - self._mean) / self._std

    # Add batch dimension
    input_tensor = np.expand_dims(input_tensor, axis=0)

    return input_tensor

  def _set_input_tensor(self, image):
    """Sets the input tensor."""
    tensor_index = self._interpreter.get_input_details()[0]['index']
    input_tensor = self._interpreter.tensor(tensor_index)()[0]
    input_tensor[:, :] = image

  def _get_output_tensor(self, name):
    """Returns the output tensor at the given index."""
    output_index = self._output_indices[name]
    tensor = np.squeeze(self._interpreter.get_tensor(output_index))
    return tensor

  def _postprocess(self, boxes: np.ndarray, classes: np.ndarray,
                   scores: np.ndarray, count: int, image_width: int,
                   image_height: int) -> List[Detection]:
    """Post-process the output of TFLite model into a list of Detection objects.
    Args:
        boxes: Bounding boxes of detected objects from the TFLite model.
        classes: Class index of the detected objects from the TFLite model.
        scores: Confidence scores of the detected objects from the TFLite model.
        count: Number of detected objects from the TFLite model.
        image_width: Width of the input image.
        image_height: Height of the input image.
    Returns:
        A list of Detection objects detected by the TFLite model.
    """
    results = []

    # Parse the model output into a list of Detection entities.
    for i in range(count):
      if scores[i] >= self._options.score_threshold:
        y_min, x_min, y_max, x_max = boxes[i]
        bounding_box = Rect(
            top=int(y_min * image_height),
            left=int(x_min * image_width),
            bottom=int(y_max * image_height),
            right=int(x_max * image_width))
        class_id = int(classes[i])
        category = Category(
            score=scores[i],
            label=self._label_list[class_id],  # 0 is reserved for background
            index=class_id)
        result = Detection(bounding_box=bounding_box, categories=[category])
        results.append(result)

    # Sort detection results by score ascending
    sorted_results = sorted(
        results,
        key=lambda detection: detection.categories[0].score,
        reverse=True)

    # Filter out detections in deny list
    filtered_results = sorted_results
    if self._options.label_deny_list is not None:
      filtered_results = list(
          filter(
              lambda detection: detection.categories[0].label not in self.
              _options.label_deny_list, filtered_results))

    # Keep only detections in allow list
    if self._options.label_allow_list is not None:
      filtered_results = list(
          filter(
              lambda detection: detection.categories[0].label in self._options.
              label_allow_list, filtered_results))

    # Only return maximum of max_results detection.
    if self._options.max_results > 0:
      result_count = min(len(filtered_results), self._options.max_results)
      filtered_results = filtered_results[:result_count]

    return filtered_results


_MARGIN = 10  # pixels
_ROW_SIZE = 10  # pixels
_FONT_SIZE = 1
_FONT_THICKNESS = 1
_TEXT_COLOR = (0, 0, 255)  # red


def visualize(
    image: np.ndarray,
    detections: List[Detection],
) -> np.ndarray:
  """Draws bounding boxes on the input image and return it.
  Args:
    image: The input RGB image.
    detections: The list of all "Detection" entities to be visualize.
  Returns:
    Image with bounding boxes.
  """
  for detection in detections:
    # Draw bounding_box
    start_point = detection.bounding_box.left, detection.bounding_box.top
    end_point = detection.bounding_box.right, detection.bounding_box.bottom
    cv2.rectangle(image, start_point, end_point, _TEXT_COLOR, 3)

    # Draw label and score
    category = detection.categories[0]
    class_name = category.label
    probability = round(category.score, 2)
    result_text = class_name + ' (' + str(probability) + ')'
    text_location = (_MARGIN + detection.bounding_box.left,
                     _MARGIN + _ROW_SIZE + detection.bounding_box.top)
    cv2.putText(image, result_text, text_location, cv2.FONT_HERSHEY_PLAIN,
                _FONT_SIZE, _TEXT_COLOR, _FONT_THICKNESS)

  return image

# %%
from PIL import Image
INPUT_IMAGE_ONE = 'Thesis/All_Photos/6_channels/6_TEST/0_disp.jpg' #@param {type:"string"}
DETECTION_THRESHOLD = 0.5 #@param {type:"number"}
TFLITE_MODEL_PATH = "Thesis/android.tfliteMentorFOURChannelsMerged" #@param {type:"string"}

TEMP_FILE = '/tmp/image.png'

# !wget -q -O $TEMP_FILE $INPUT_IMAGE_ONE

#image = Image.open(TEMP_FILE).convert('RGB')
image_one = Image.open(INPUT_IMAGE_ONE).convert('RGB')
image_one.thumbnail((512, 512), Image.ANTIALIAS)
image_np_one = np.asarray(image_one)

# Load the TFLite model
options = ObjectDetectorOptions(
      num_threads=4,
      score_threshold=DETECTION_THRESHOLD,
)
detector = ObjectDetector(model_path=TFLITE_MODEL_PATH, options=options)

# Run object detection estimation using the model.
detections = detector.detect(image_np_one)

# Draw keypoints and edges on input image
image_np_one = visualize(image_np_one, detections)

# Show the detection result
Image.fromarray(image_np_one)
# Out:
# <PIL.Image.Image image mode=RGB size=512x341 at 0x7F0B924511F0>

# %%
#INPUT_IMAGE_URL = 'JPEG/Validate/2_33226e67-1692-4472-88be-acdbace303f5_1024x1024.jpg'
INPUT_IMAGE_URL = 'Thesis/All_Photos/6_channels/6_TEST/6_disp.jpg'
DISP_IMAGE_OVERLAY = 'Thesis/All_Photos/6_channels/6_TEST/6_disp.jpg'

# %%
#@title Run object detection and show the detection results

# from PIL import Image

# INPUT_IMAGE_URL = 'Depth_Map_Image/2_disp.jpeg'
# INPUT_IMAGE_URL = "http://download.tensorflow.org/example_images/android_figurine.jpg" #@param {type:"string"}
INPUT_IMAGE_URL = INPUT_IMAGE_URL #@param {type:"string"}
DETECTION_THRESHOLD = 0.5 #@param {type:"number"}
TFLITE_MODEL_PATH = "Thesis/android.tfliteMentorFOURChannelsMerged" #@param {type:"string"}

TEMP_FILE = '/tmp/image.png'

# !wget -q -O $TEMP_FILE $INPUT_IMAGE_URL

#image = Image.open(TEMP_FILE).convert('RGB')
image = Image.open(INPUT_IMAGE_URL).convert('RGB')
image.thumbnail((512, 512), Image.ANTIALIAS)
image_np = np.asarray(image)

# Load the TFLite model
options = ObjectDetectorOptions(
      num_threads=4,
      score_threshold=DETECTION_THRESHOLD,
)
detector = ObjectDetector(model_path=TFLITE_MODEL_PATH, options=options)

# Run object detection estimation using the model.
detections = detector.detect(image_np)

# Draw keypoints and edges on input image
image_np = visualize(image_np, detections)

# Show the detection result
Image.fromarray(image_np)



# #image = Image.open(TEMP_FILE).convert('RGB')
# image_two = Image.open(DISP_IMAGE_OVERLAY).convert('RGB')
# image_two.thumbnail((512, 512), Image.ANTIALIAS)
# image_np_two = np.asarray(image_two)

# image_np_two = visualize(image_np_two, detections)
# Image.fromarray(image_np_two)
# Out:
# <PIL.Image.Image image mode=RGB size=512x288 at 0x7F0B92451F10>

# %%
# image_two = Image.open(DISP_IMAGE_OVERLAY).convert('RGB')
# image_two.thumbnail((512, 512), Image.ANTIALIAS)
# image_np_two = np.asarray(image_two)

# image_np_two = visualize(image_np_two, detections)
# Image.fromarray(image_np_two)

# %%
t2 = time.perf_counter()
print('time taken to run:',t2-t1)
# Out:
# time taken to run: 1950.1378216389999

# %% [markdown]
# ## Preparation
#
# ### Install the required packages
# Start by installing the required packages, including the Model Maker package from the [GitHub repo](https://github.com/tensorflow/examples/tree/master/tensorflow_examples/lite/model_maker) and the pycocotools library you'll use for evaluation.

# %%
# !pip install -q tflite-model-maker
# !pip install -q tflite-support
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.3/577.3 KB 34.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 58.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 MB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 KB 48.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 80.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 58.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 KB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 KB 26.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.6/128.6 KB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 68.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.0/498.0 MB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 KB 41.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 KB 50.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 71.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 98.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 KB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.4/222.4 KB 29.3 MB/s eta 0:00:00
#   Building wheel for fire (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 2022.12.0 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.

# %% [markdown]
# Import the required packages.

# %%
import numpy as np
import os

from tflite_model_maker.config import ExportFormat, QuantizationConfig
from tflite_model_maker import model_spec
from tflite_model_maker import object_detector

from tflite_support import metadata

import tensorflow as tf
assert tf.__version__.startswith('2')

tf.get_logger().setLevel('ERROR')
from absl import logging
logging.set_verbosity(logging.ERROR)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.4 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %% [markdown]
# ### Prepare the dataset

# %%
#!wget https://storage.googleapis.com/download.tensorflow.org/data/android_figurine.zip
#!unzip -q android_figurine.zip
from google.colab import drive
drive.mount('/content/drive/', force_remount=True) #, force_remount=True
# Out:
# Mounted at /content/drive/

# %%
# Run this if need to force remount
import os
path = "/content" # /content is pretty much the root. you can choose other path in your colab workspace
os.chdir(path)

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/My Drive/
# Out:
# /content/drive/My Drive

# %%
#!unzip -q Colab_data.zip # This should be on when running first time

# %% [markdown]
# ## Train the object detection model
#
# ### Step 1: Load the dataset
#
# * Images in `train_data` is used to train the custom object detection model.
# * Images in `val_data` is used to check if the model can generalize well to new images that it hasn't seen before.

# %%
# !pwd
# Out:
# /content/drive/My Drive

# %%
train_data = object_detector.DataLoader.from_pascal_voc(
    'Thesis/All_Photos/640_DIFFNet/640_TRAIN',
    'Thesis/All_Photos/640_DIFFNet/640_TRAIN',
    ['painting','Real_Tunnel']
)

val_data = object_detector.DataLoader.from_pascal_voc(
    'Thesis/All_Photos/640_DIFFNet/640_TEST',
    'Thesis/All_Photos/640_DIFFNet/640_TEST',
    ['painting','Real_Tunnel']
)

# %%
print(train_data.size)
# Out:
# 25

# %% [markdown]
# ### Step 2: Select a model architecture
#
# EfficientDet-Lite[0-4] are a family of mobile/IoT-friendly object detection models derived from the [EfficientDet](https://arxiv.org/abs/1911.09070) architecture.
#
# Here is the performance of each EfficientDet-Lite models compared to each others.
#
# | Model architecture | Size(MB)* | Latency(ms)** | Average Precision*** |
# |--------------------|-----------|---------------|----------------------|
# | EfficientDet-Lite0 | 4.4       | 146           | 25.69%               |
# | EfficientDet-Lite1 | 5.8       | 259           | 30.55%               |
# | EfficientDet-Lite2 | 7.2       | 396           | 33.97%               |
# | EfficientDet-Lite3 | 11.4      | 716           | 37.70%               |
# | EfficientDet-Lite4 | 19.9      | 1886          | 41.96%               |
#
# <i> * Size of the integer quantized models. <br/>
# ** Latency measured on Raspberry Pi 4 using 4 threads on CPU. <br/>
# *** Average Precision is the mAP (mean Average Precision) on the COCO 2017 validation dataset.
# </i>
#
# In this notebook, we use EfficientDet-Lite0 to train our model. You can choose other model architectures depending on whether speed or accuracy is more important to you.

# %%
spec = model_spec.get('efficientdet_lite4')

# %% [markdown]
# ### Step 3: Train the TensorFlow model with the training data.
#
# * Set `epochs = 20`, which means it will go through the training dataset 20 times. You can look at the validation accuracy during training and stop when you see validation loss (`val_loss`) stop decreasing to avoid overfitting.
# * Set `batch_size = 4` here so you will see that it takes 15 steps to go through the 62 images in the training dataset.
# * Set `train_whole_model=True` to fine-tune the whole model instead of just training the head layer to improve accuracy. The trade-off is that it may take longer to train the model.

# %%
import time
t1 = time.perf_counter()

# %%
model = object_detector.create(train_data, model_spec=spec, batch_size=4, train_whole_model=True, epochs=100, validation_data=val_data)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 71s 2s/step - det_loss: 1.7568 - cls_loss: 1.1546 - box_loss: 0.0120 - reg_l2_loss: 0.1078 - loss: 1.8645 - learning_rate: 0.0066 - gradient_norm: 2.0030 - val_det_loss: 1.6815 - val_cls_loss: 1.1563 - val_box_loss: 0.0105 - val_reg_l2_loss: 0.1078 - val_loss: 1.7892
# Epoch 2/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.7142 - cls_loss: 1.1499 - box_loss: 0.0113 - reg_l2_loss: 0.1078 - loss: 1.8220 - learning_rate: 0.0050 - gradient_norm: 2.1338 - val_det_loss: 1.6083 - val_cls_loss: 1.1461 - val_box_loss: 0.0092 - val_reg_l2_loss: 0.1078 - val_loss: 1.7161
# Epoch 3/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 1.6790 - cls_loss: 1.1428 - box_loss: 0.0107 - reg_l2_loss: 0.1078 - loss: 1.7868 - learning_rate: 0.0050 - gradient_norm: 3.5863 - val_det_loss: 1.5494 - val_cls_loss: 1.1347 - val_box_loss: 0.0083 - val_reg_l2_loss: 0.1078 - val_loss: 1.6572
# Epoch 4/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 1.6748 - cls_loss: 1.1352 - box_loss: 0.0108 - reg_l2_loss: 0.1078 - loss: 1.7825 - learning_rate: 0.0050 - gradient_norm: 2.8158 - val_det_loss: 1.4985 - val_cls_loss: 1.1239 - val_box_loss: 0.0075 - val_reg_l2_loss: 0.1078 - val_loss: 1.6063
# Epoch 5/100
# 6/6 [==============================] - 15s 3s/step - det_loss: 1.5948 - cls_loss: 1.1167 - box_loss: 0.0096 - reg_l2_loss: 0.1078 - loss: 1.7025 - learning_rate: 0.0050 - gradient_norm: 2.5134 - val_det_loss: 1.4604 - val_cls_loss: 1.1044 - val_box_loss: 0.0071 - val_reg_l2_loss: 0.1078 - val_loss: 1.5682
# Epoch 6/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.5679 - cls_loss: 1.1003 - box_loss: 0.0094 - reg_l2_loss: 0.1078 - loss: 1.6757 - learning_rate: 0.0050 - gradient_norm: 2.3247 - val_det_loss: 1.4153 - val_cls_loss: 1.0763 - val_box_loss: 0.0068 - val_reg_l2_loss: 0.1078 - val_loss: 1.5231
# Epoch 7/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.5220 - cls_loss: 1.0813 - box_loss: 0.0088 - reg_l2_loss: 0.1078 - loss: 1.6297 - learning_rate: 0.0049 - gradient_norm: 3.6441 - val_det_loss: 1.3665 - val_cls_loss: 1.0406 - val_box_loss: 0.0065 - val_reg_l2_loss: 0.1078 - val_loss: 1.4743
# Epoch 8/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.4308 - cls_loss: 1.0381 - box_loss: 0.0079 - reg_l2_loss: 0.1078 - loss: 1.5386 - learning_rate: 0.0049 - gradient_norm: 4.0324 - val_det_loss: 1.3235 - val_cls_loss: 0.9891 - val_box_loss: 0.0067 - val_reg_l2_loss: 0.1078 - val_loss: 1.4313
# Epoch 9/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 1.4028 - cls_loss: 1.0150 - box_loss: 0.0078 - reg_l2_loss: 0.1078 - loss: 1.5105 - learning_rate: 0.0049 - gradient_norm: 3.7829 - val_det_loss: 1.2494 - val_cls_loss: 0.9323 - val_box_loss: 0.0063 - val_reg_l2_loss: 0.1078 - val_loss: 1.3572
# Epoch 10/100
# 6/6 [==============================] - 12s 2s/step - det_loss: 1.3340 - cls_loss: 0.9567 - box_loss: 0.0075 - reg_l2_loss: 0.1078 - loss: 1.4418 - learning_rate: 0.0049 - gradient_norm: 5.5536 - val_det_loss: 1.1225 - val_cls_loss: 0.8225 - val_box_loss: 0.0060 - val_reg_l2_loss: 0.1078 - val_loss: 1.2303
# Epoch 11/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 1.2511 - cls_loss: 0.8966 - box_loss: 0.0071 - reg_l2_loss: 0.1078 - loss: 1.3589 - learning_rate: 0.0049 - gradient_norm: 6.6117 - val_det_loss: 1.0492 - val_cls_loss: 0.7425 - val_box_loss: 0.0061 - val_reg_l2_loss: 0.1078 - val_loss: 1.1570
# Epoch 12/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.0994 - cls_loss: 0.7696 - box_loss: 0.0066 - reg_l2_loss: 0.1078 - loss: 1.2072 - learning_rate: 0.0048 - gradient_norm: 5.1804 - val_det_loss: 1.0083 - val_cls_loss: 0.7307 - val_box_loss: 0.0056 - val_reg_l2_loss: 0.1078 - val_loss: 1.1161
# Epoch 13/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.0260 - cls_loss: 0.7324 - box_loss: 0.0059 - reg_l2_loss: 0.1078 - loss: 1.1338 - learning_rate: 0.0048 - gradient_norm: 6.1034 - val_det_loss: 0.9657 - val_cls_loss: 0.6791 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.1078 - val_loss: 1.0735
# Epoch 14/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.9351 - cls_loss: 0.6475 - box_loss: 0.0058 - reg_l2_loss: 0.1078 - loss: 1.0429 - learning_rate: 0.0048 - gradient_norm: 6.2298 - val_det_loss: 0.9474 - val_cls_loss: 0.6607 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.1078 - val_loss: 1.0553
# Epoch 15/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.9086 - cls_loss: 0.6340 - box_loss: 0.0055 - reg_l2_loss: 0.1078 - loss: 1.0165 - learning_rate: 0.0047 - gradient_norm: 5.6866 - val_det_loss: 0.8811 - val_cls_loss: 0.6337 - val_box_loss: 0.0049 - val_reg_l2_loss: 0.1078 - val_loss: 0.9889
# Epoch 16/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.7820 - cls_loss: 0.5455 - box_loss: 0.0047 - reg_l2_loss: 0.1079 - loss: 0.8898 - learning_rate: 0.0047 - gradient_norm: 6.0241 - val_det_loss: 0.9599 - val_cls_loss: 0.6649 - val_box_loss: 0.0059 - val_reg_l2_loss: 0.1079 - val_loss: 1.0677
# Epoch 17/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.9121 - cls_loss: 0.6230 - box_loss: 0.0058 - reg_l2_loss: 0.1079 - loss: 1.0200 - learning_rate: 0.0047 - gradient_norm: 7.6864 - val_det_loss: 1.0814 - val_cls_loss: 0.7558 - val_box_loss: 0.0065 - val_reg_l2_loss: 0.1079 - val_loss: 1.1892
# Epoch 18/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.8785 - cls_loss: 0.6030 - box_loss: 0.0055 - reg_l2_loss: 0.1079 - loss: 0.9864 - learning_rate: 0.0046 - gradient_norm: 8.6523 - val_det_loss: 1.0653 - val_cls_loss: 0.7458 - val_box_loss: 0.0064 - val_reg_l2_loss: 0.1079 - val_loss: 1.1732
# Epoch 19/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.9153 - cls_loss: 0.6386 - box_loss: 0.0055 - reg_l2_loss: 0.1079 - loss: 1.0232 - learning_rate: 0.0046 - gradient_norm: 8.4034 - val_det_loss: 1.0112 - val_cls_loss: 0.7083 - val_box_loss: 0.0061 - val_reg_l2_loss: 0.1079 - val_loss: 1.1191
# Epoch 20/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.8880 - cls_loss: 0.6184 - box_loss: 0.0054 - reg_l2_loss: 0.1079 - loss: 0.9959 - learning_rate: 0.0045 - gradient_norm: 8.0661 - val_det_loss: 1.0580 - val_cls_loss: 0.7836 - val_box_loss: 0.0055 - val_reg_l2_loss: 0.1079 - val_loss: 1.1659
# Epoch 21/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.7105 - cls_loss: 0.4913 - box_loss: 0.0044 - reg_l2_loss: 0.1079 - loss: 0.8184 - learning_rate: 0.0045 - gradient_norm: 8.3374 - val_det_loss: 1.1586 - val_cls_loss: 0.8764 - val_box_loss: 0.0056 - val_reg_l2_loss: 0.1079 - val_loss: 1.2665
# Epoch 22/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.7477 - cls_loss: 0.5032 - box_loss: 0.0049 - reg_l2_loss: 0.1079 - loss: 0.8556 - learning_rate: 0.0044 - gradient_norm: 8.8796 - val_det_loss: 1.1512 - val_cls_loss: 0.8659 - val_box_loss: 0.0057 - val_reg_l2_loss: 0.1079 - val_loss: 1.2591
# Epoch 23/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.7699 - cls_loss: 0.5252 - box_loss: 0.0049 - reg_l2_loss: 0.1080 - loss: 0.8778 - learning_rate: 0.0044 - gradient_norm: 7.3371 - val_det_loss: 1.1026 - val_cls_loss: 0.7746 - val_box_loss: 0.0066 - val_reg_l2_loss: 0.1080 - val_loss: 1.2106
# Epoch 24/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.7324 - cls_loss: 0.4831 - box_loss: 0.0050 - reg_l2_loss: 0.1080 - loss: 0.8403 - learning_rate: 0.0043 - gradient_norm: 7.2150 - val_det_loss: 1.1392 - val_cls_loss: 0.7711 - val_box_loss: 0.0074 - val_reg_l2_loss: 0.1080 - val_loss: 1.2472
# Epoch 25/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.6884 - cls_loss: 0.4800 - box_loss: 0.0042 - reg_l2_loss: 0.1080 - loss: 0.7964 - learning_rate: 0.0043 - gradient_norm: 5.0501 - val_det_loss: 1.1552 - val_cls_loss: 0.8235 - val_box_loss: 0.0066 - val_reg_l2_loss: 0.1080 - val_loss: 1.2632
# Epoch 26/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.6755 - cls_loss: 0.4653 - box_loss: 0.0042 - reg_l2_loss: 0.1080 - loss: 0.7835 - learning_rate: 0.0042 - gradient_norm: 5.6355 - val_det_loss: 1.1462 - val_cls_loss: 0.7855 - val_box_loss: 0.0072 - val_reg_l2_loss: 0.1080 - val_loss: 1.2542
# Epoch 27/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.6553 - cls_loss: 0.4599 - box_loss: 0.0039 - reg_l2_loss: 0.1080 - loss: 0.7633 - learning_rate: 0.0042 - gradient_norm: 4.6986 - val_det_loss: 1.2693 - val_cls_loss: 0.8306 - val_box_loss: 0.0088 - val_reg_l2_loss: 0.1080 - val_loss: 1.3773
# Epoch 28/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.5941 - cls_loss: 0.4116 - box_loss: 0.0036 - reg_l2_loss: 0.1080 - loss: 0.7021 - learning_rate: 0.0041 - gradient_norm: 5.9434 - val_det_loss: 1.2254 - val_cls_loss: 0.8472 - val_box_loss: 0.0076 - val_reg_l2_loss: 0.1080 - val_loss: 1.3335
# Epoch 29/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.5793 - cls_loss: 0.3986 - box_loss: 0.0036 - reg_l2_loss: 0.1080 - loss: 0.6873 - learning_rate: 0.0040 - gradient_norm: 6.1896 - val_det_loss: 1.2324 - val_cls_loss: 0.8026 - val_box_loss: 0.0086 - val_reg_l2_loss: 0.1080 - val_loss: 1.3405
# Epoch 30/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.6509 - cls_loss: 0.4629 - box_loss: 0.0038 - reg_l2_loss: 0.1080 - loss: 0.7589 - learning_rate: 0.0040 - gradient_norm: 7.4841 - val_det_loss: 1.2615 - val_cls_loss: 0.8300 - val_box_loss: 0.0086 - val_reg_l2_loss: 0.1080 - val_loss: 1.3696
# Epoch 31/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.6341 - cls_loss: 0.4268 - box_loss: 0.0041 - reg_l2_loss: 0.1080 - loss: 0.7421 - learning_rate: 0.0039 - gradient_norm: 5.9720 - val_det_loss: 1.2706 - val_cls_loss: 0.8372 - val_box_loss: 0.0087 - val_reg_l2_loss: 0.1080 - val_loss: 1.3786
# Epoch 32/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.6522 - cls_loss: 0.4369 - box_loss: 0.0043 - reg_l2_loss: 0.1080 - loss: 0.7602 - learning_rate: 0.0039 - gradient_norm: 6.3503 - val_det_loss: 1.1241 - val_cls_loss: 0.7702 - val_box_loss: 0.0071 - val_reg_l2_loss: 0.1080 - val_loss: 1.2321
# Epoch 33/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.5821 - cls_loss: 0.3921 - box_loss: 0.0038 - reg_l2_loss: 0.1081 - loss: 0.6901 - learning_rate: 0.0038 - gradient_norm: 5.2240 - val_det_loss: 1.0232 - val_cls_loss: 0.6911 - val_box_loss: 0.0066 - val_reg_l2_loss: 0.1081 - val_loss: 1.1313
# Epoch 34/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.6151 - cls_loss: 0.4264 - box_loss: 0.0038 - reg_l2_loss: 0.1081 - loss: 0.7232 - learning_rate: 0.0037 - gradient_norm: 7.4136 - val_det_loss: 0.9032 - val_cls_loss: 0.6023 - val_box_loss: 0.0060 - val_reg_l2_loss: 0.1081 - val_loss: 1.0112
# Epoch 35/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.6469 - cls_loss: 0.4411 - box_loss: 0.0041 - reg_l2_loss: 0.1081 - loss: 0.7549 - learning_rate: 0.0036 - gradient_norm: 7.1031 - val_det_loss: 0.8674 - val_cls_loss: 0.6144 - val_box_loss: 0.0051 - val_reg_l2_loss: 0.1081 - val_loss: 0.9755
# Epoch 36/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4959 - cls_loss: 0.3648 - box_loss: 0.0026 - reg_l2_loss: 0.1081 - loss: 0.6040 - learning_rate: 0.0036 - gradient_norm: 5.3862 - val_det_loss: 0.9242 - val_cls_loss: 0.6487 - val_box_loss: 0.0055 - val_reg_l2_loss: 0.1081 - val_loss: 1.0322
# Epoch 37/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.5734 - cls_loss: 0.3930 - box_loss: 0.0036 - reg_l2_loss: 0.1081 - loss: 0.6814 - learning_rate: 0.0035 - gradient_norm: 6.6142 - val_det_loss: 0.9841 - val_cls_loss: 0.6675 - val_box_loss: 0.0063 - val_reg_l2_loss: 0.1081 - val_loss: 1.0922
# Epoch 38/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.4815 - cls_loss: 0.3168 - box_loss: 0.0033 - reg_l2_loss: 0.1081 - loss: 0.5896 - learning_rate: 0.0034 - gradient_norm: 4.3482 - val_det_loss: 0.8943 - val_cls_loss: 0.6143 - val_box_loss: 0.0056 - val_reg_l2_loss: 0.1081 - val_loss: 1.0024
# Epoch 39/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4674 - cls_loss: 0.3341 - box_loss: 0.0027 - reg_l2_loss: 0.1081 - loss: 0.5755 - learning_rate: 0.0034 - gradient_norm: 5.4624 - val_det_loss: 0.9431 - val_cls_loss: 0.5942 - val_box_loss: 0.0070 - val_reg_l2_loss: 0.1081 - val_loss: 1.0512
# Epoch 40/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4634 - cls_loss: 0.3238 - box_loss: 0.0028 - reg_l2_loss: 0.1081 - loss: 0.5714 - learning_rate: 0.0033 - gradient_norm: 5.0984 - val_det_loss: 0.9270 - val_cls_loss: 0.6001 - val_box_loss: 0.0065 - val_reg_l2_loss: 0.1081 - val_loss: 1.0351
# Epoch 41/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.4637 - cls_loss: 0.2984 - box_loss: 0.0033 - reg_l2_loss: 0.1081 - loss: 0.5718 - learning_rate: 0.0032 - gradient_norm: 4.2913 - val_det_loss: 0.9164 - val_cls_loss: 0.6288 - val_box_loss: 0.0058 - val_reg_l2_loss: 0.1081 - val_loss: 1.0245
# Epoch 42/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4213 - cls_loss: 0.2937 - box_loss: 0.0026 - reg_l2_loss: 0.1081 - loss: 0.5294 - learning_rate: 0.0031 - gradient_norm: 4.6840 - val_det_loss: 0.8622 - val_cls_loss: 0.5873 - val_box_loss: 0.0055 - val_reg_l2_loss: 0.1081 - val_loss: 0.9703
# Epoch 43/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.5630 - cls_loss: 0.3772 - box_loss: 0.0037 - reg_l2_loss: 0.1081 - loss: 0.6711 - learning_rate: 0.0031 - gradient_norm: 5.1775 - val_det_loss: 0.8321 - val_cls_loss: 0.5727 - val_box_loss: 0.0052 - val_reg_l2_loss: 0.1081 - val_loss: 0.9402
# Epoch 44/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.5875 - cls_loss: 0.4063 - box_loss: 0.0036 - reg_l2_loss: 0.1081 - loss: 0.6956 - learning_rate: 0.0030 - gradient_norm: 5.6447 - val_det_loss: 0.8087 - val_cls_loss: 0.5486 - val_box_loss: 0.0052 - val_reg_l2_loss: 0.1081 - val_loss: 0.9168
# Epoch 45/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4423 - cls_loss: 0.3035 - box_loss: 0.0028 - reg_l2_loss: 0.1081 - loss: 0.5505 - learning_rate: 0.0029 - gradient_norm: 6.2078 - val_det_loss: 0.5891 - val_cls_loss: 0.3943 - val_box_loss: 0.0039 - val_reg_l2_loss: 0.1081 - val_loss: 0.6972
# Epoch 46/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4266 - cls_loss: 0.2912 - box_loss: 0.0027 - reg_l2_loss: 0.1081 - loss: 0.5347 - learning_rate: 0.0028 - gradient_norm: 5.7738 - val_det_loss: 0.7912 - val_cls_loss: 0.5427 - val_box_loss: 0.0050 - val_reg_l2_loss: 0.1081 - val_loss: 0.8993
# Epoch 47/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.4140 - cls_loss: 0.2959 - box_loss: 0.0024 - reg_l2_loss: 0.1081 - loss: 0.5221 - learning_rate: 0.0027 - gradient_norm: 5.4365 - val_det_loss: 0.8645 - val_cls_loss: 0.5701 - val_box_loss: 0.0059 - val_reg_l2_loss: 0.1081 - val_loss: 0.9726
# Epoch 48/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.5615 - cls_loss: 0.4130 - box_loss: 0.0030 - reg_l2_loss: 0.1081 - loss: 0.6697 - learning_rate: 0.0027 - gradient_norm: 6.1573 - val_det_loss: 0.8684 - val_cls_loss: 0.5597 - val_box_loss: 0.0062 - val_reg_l2_loss: 0.1081 - val_loss: 0.9765
# Epoch 49/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4236 - cls_loss: 0.2900 - box_loss: 0.0027 - reg_l2_loss: 0.1081 - loss: 0.5317 - learning_rate: 0.0026 - gradient_norm: 3.4968 - val_det_loss: 0.8362 - val_cls_loss: 0.5262 - val_box_loss: 0.0062 - val_reg_l2_loss: 0.1081 - val_loss: 0.9443
# Epoch 50/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.5192 - cls_loss: 0.3752 - box_loss: 0.0029 - reg_l2_loss: 0.1081 - loss: 0.6273 - learning_rate: 0.0025 - gradient_norm: 4.6538 - val_det_loss: 0.7884 - val_cls_loss: 0.4581 - val_box_loss: 0.0066 - val_reg_l2_loss: 0.1081 - val_loss: 0.8966
# Epoch 51/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.4556 - cls_loss: 0.3094 - box_loss: 0.0029 - reg_l2_loss: 0.1081 - loss: 0.5637 - learning_rate: 0.0024 - gradient_norm: 5.5767 - val_det_loss: 0.7202 - val_cls_loss: 0.3791 - val_box_loss: 0.0068 - val_reg_l2_loss: 0.1081 - val_loss: 0.8283
# Epoch 52/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4221 - cls_loss: 0.2962 - box_loss: 0.0025 - reg_l2_loss: 0.1081 - loss: 0.5303 - learning_rate: 0.0023 - gradient_norm: 5.0485 - val_det_loss: 0.6863 - val_cls_loss: 0.4180 - val_box_loss: 0.0054 - val_reg_l2_loss: 0.1081 - val_loss: 0.7944
# Epoch 53/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.5667 - cls_loss: 0.3804 - box_loss: 0.0037 - reg_l2_loss: 0.1081 - loss: 0.6749 - learning_rate: 0.0023 - gradient_norm: 6.5002 - val_det_loss: 0.6428 - val_cls_loss: 0.4102 - val_box_loss: 0.0047 - val_reg_l2_loss: 0.1081 - val_loss: 0.7509
# Epoch 54/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.4974 - cls_loss: 0.3193 - box_loss: 0.0036 - reg_l2_loss: 0.1081 - loss: 0.6056 - learning_rate: 0.0022 - gradient_norm: 4.6942 - val_det_loss: 0.5538 - val_cls_loss: 0.3545 - val_box_loss: 0.0040 - val_reg_l2_loss: 0.1081 - val_loss: 0.6620
# Epoch 55/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4496 - cls_loss: 0.3013 - box_loss: 0.0030 - reg_l2_loss: 0.1081 - loss: 0.5577 - learning_rate: 0.0021 - gradient_norm: 4.4119 - val_det_loss: 0.5220 - val_cls_loss: 0.3380 - val_box_loss: 0.0037 - val_reg_l2_loss: 0.1081 - val_loss: 0.6302
# Epoch 56/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3651 - cls_loss: 0.2639 - box_loss: 0.0020 - reg_l2_loss: 0.1081 - loss: 0.4732 - learning_rate: 0.0020 - gradient_norm: 4.2269 - val_det_loss: 0.5177 - val_cls_loss: 0.3126 - val_box_loss: 0.0041 - val_reg_l2_loss: 0.1081 - val_loss: 0.6259
# Epoch 57/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.3738 - cls_loss: 0.2667 - box_loss: 0.0021 - reg_l2_loss: 0.1081 - loss: 0.4819 - learning_rate: 0.0020 - gradient_norm: 4.3508 - val_det_loss: 0.4946 - val_cls_loss: 0.2878 - val_box_loss: 0.0041 - val_reg_l2_loss: 0.1081 - val_loss: 0.6028
# Epoch 58/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.4207 - cls_loss: 0.3079 - box_loss: 0.0023 - reg_l2_loss: 0.1081 - loss: 0.5289 - learning_rate: 0.0019 - gradient_norm: 5.1679 - val_det_loss: 0.4926 - val_cls_loss: 0.2697 - val_box_loss: 0.0045 - val_reg_l2_loss: 0.1081 - val_loss: 0.6007
# Epoch 59/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3470 - cls_loss: 0.2458 - box_loss: 0.0020 - reg_l2_loss: 0.1081 - loss: 0.4551 - learning_rate: 0.0018 - gradient_norm: 3.9138 - val_det_loss: 0.4708 - val_cls_loss: 0.2534 - val_box_loss: 0.0043 - val_reg_l2_loss: 0.1081 - val_loss: 0.5790
# Epoch 60/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3686 - cls_loss: 0.2360 - box_loss: 0.0027 - reg_l2_loss: 0.1081 - loss: 0.4767 - learning_rate: 0.0017 - gradient_norm: 3.7349 - val_det_loss: 0.4695 - val_cls_loss: 0.2782 - val_box_loss: 0.0038 - val_reg_l2_loss: 0.1081 - val_loss: 0.5776
# Epoch 61/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.3974 - cls_loss: 0.2928 - box_loss: 0.0021 - reg_l2_loss: 0.1081 - loss: 0.5056 - learning_rate: 0.0016 - gradient_norm: 4.1260 - val_det_loss: 0.5096 - val_cls_loss: 0.3054 - val_box_loss: 0.0041 - val_reg_l2_loss: 0.1081 - val_loss: 0.6178
# Epoch 62/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.4023 - cls_loss: 0.2642 - box_loss: 0.0028 - reg_l2_loss: 0.1081 - loss: 0.5105 - learning_rate: 0.0016 - gradient_norm: 4.8065 - val_det_loss: 0.5111 - val_cls_loss: 0.3192 - val_box_loss: 0.0038 - val_reg_l2_loss: 0.1081 - val_loss: 0.6192
# Epoch 63/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4970 - cls_loss: 0.3544 - box_loss: 0.0029 - reg_l2_loss: 0.1081 - loss: 0.6051 - learning_rate: 0.0015 - gradient_norm: 4.3788 - val_det_loss: 0.5086 - val_cls_loss: 0.3069 - val_box_loss: 0.0040 - val_reg_l2_loss: 0.1081 - val_loss: 0.6167
# Epoch 64/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4371 - cls_loss: 0.3217 - box_loss: 0.0023 - reg_l2_loss: 0.1081 - loss: 0.5453 - learning_rate: 0.0014 - gradient_norm: 6.7419 - val_det_loss: 0.5140 - val_cls_loss: 0.3149 - val_box_loss: 0.0040 - val_reg_l2_loss: 0.1081 - val_loss: 0.6221
# Epoch 65/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.4023 - cls_loss: 0.2585 - box_loss: 0.0029 - reg_l2_loss: 0.1081 - loss: 0.5105 - learning_rate: 0.0014 - gradient_norm: 5.1488 - val_det_loss: 0.5173 - val_cls_loss: 0.2944 - val_box_loss: 0.0045 - val_reg_l2_loss: 0.1081 - val_loss: 0.6255
# Epoch 66/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3458 - cls_loss: 0.2309 - box_loss: 0.0023 - reg_l2_loss: 0.1081 - loss: 0.4539 - learning_rate: 0.0013 - gradient_norm: 4.4347 - val_det_loss: 0.4972 - val_cls_loss: 0.2832 - val_box_loss: 0.0043 - val_reg_l2_loss: 0.1081 - val_loss: 0.6053
# Epoch 67/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.3130 - cls_loss: 0.2271 - box_loss: 0.0017 - reg_l2_loss: 0.1081 - loss: 0.4212 - learning_rate: 0.0012 - gradient_norm: 3.2872 - val_det_loss: 0.7307 - val_cls_loss: 0.4734 - val_box_loss: 0.0051 - val_reg_l2_loss: 0.1081 - val_loss: 0.8389
# Epoch 68/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.3238 - cls_loss: 0.2158 - box_loss: 0.0022 - reg_l2_loss: 0.1081 - loss: 0.4319 - learning_rate: 0.0012 - gradient_norm: 4.5551 - val_det_loss: 0.4542 - val_cls_loss: 0.2724 - val_box_loss: 0.0036 - val_reg_l2_loss: 0.1081 - val_loss: 0.5624
# Epoch 69/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3885 - cls_loss: 0.2521 - box_loss: 0.0027 - reg_l2_loss: 0.1081 - loss: 0.4967 - learning_rate: 0.0011 - gradient_norm: 4.1263 - val_det_loss: 0.4793 - val_cls_loss: 0.3223 - val_box_loss: 0.0031 - val_reg_l2_loss: 0.1081 - val_loss: 0.5875
# Epoch 70/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3479 - cls_loss: 0.2417 - box_loss: 0.0021 - reg_l2_loss: 0.1081 - loss: 0.4560 - learning_rate: 0.0010 - gradient_norm: 3.2521 - val_det_loss: 0.4507 - val_cls_loss: 0.2942 - val_box_loss: 0.0031 - val_reg_l2_loss: 0.1081 - val_loss: 0.5589
# Epoch 71/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.2776 - cls_loss: 0.2005 - box_loss: 0.0015 - reg_l2_loss: 0.1081 - loss: 0.3857 - learning_rate: 9.5616e-04 - gradient_norm: 3.3621 - val_det_loss: 0.4442 - val_cls_loss: 0.2865 - val_box_loss: 0.0032 - val_reg_l2_loss: 0.1081 - val_loss: 0.5523
# Epoch 72/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.3574 - cls_loss: 0.2545 - box_loss: 0.0021 - reg_l2_loss: 0.1081 - loss: 0.4656 - learning_rate: 8.9455e-04 - gradient_norm: 5.4837 - val_det_loss: 0.4648 - val_cls_loss: 0.2936 - val_box_loss: 0.0034 - val_reg_l2_loss: 0.1081 - val_loss: 0.5730
# Epoch 73/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3608 - cls_loss: 0.2359 - box_loss: 0.0025 - reg_l2_loss: 0.1081 - loss: 0.4690 - learning_rate: 8.3456e-04 - gradient_norm: 4.7265 - val_det_loss: 0.4961 - val_cls_loss: 0.3118 - val_box_loss: 0.0037 - val_reg_l2_loss: 0.1081 - val_loss: 0.6043
# Epoch 74/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4339 - cls_loss: 0.2895 - box_loss: 0.0029 - reg_l2_loss: 0.1081 - loss: 0.5420 - learning_rate: 7.7625e-04 - gradient_norm: 5.4615 - val_det_loss: 0.4990 - val_cls_loss: 0.3182 - val_box_loss: 0.0036 - val_reg_l2_loss: 0.1081 - val_loss: 0.6072
# Epoch 75/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3548 - cls_loss: 0.2356 - box_loss: 0.0024 - reg_l2_loss: 0.1081 - loss: 0.4630 - learning_rate: 7.1967e-04 - gradient_norm: 4.5138 - val_det_loss: 0.5026 - val_cls_loss: 0.3222 - val_box_loss: 0.0036 - val_reg_l2_loss: 0.1081 - val_loss: 0.6108
# Epoch 76/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3714 - cls_loss: 0.2667 - box_loss: 0.0021 - reg_l2_loss: 0.1081 - loss: 0.4796 - learning_rate: 6.6489e-04 - gradient_norm: 5.4270 - val_det_loss: 0.5311 - val_cls_loss: 0.3285 - val_box_loss: 0.0041 - val_reg_l2_loss: 0.1081 - val_loss: 0.6392
# Epoch 77/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.3788 - cls_loss: 0.2718 - box_loss: 0.0021 - reg_l2_loss: 0.1081 - loss: 0.4869 - learning_rate: 6.1195e-04 - gradient_norm: 5.2226 - val_det_loss: 0.5366 - val_cls_loss: 0.3337 - val_box_loss: 0.0041 - val_reg_l2_loss: 0.1081 - val_loss: 0.6448
# Epoch 78/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.3756 - cls_loss: 0.2501 - box_loss: 0.0025 - reg_l2_loss: 0.1081 - loss: 0.4837 - learning_rate: 5.6091e-04 - gradient_norm: 4.7314 - val_det_loss: 0.5313 - val_cls_loss: 0.3296 - val_box_loss: 0.0040 - val_reg_l2_loss: 0.1081 - val_loss: 0.6394
# Epoch 79/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.5024 - cls_loss: 0.3504 - box_loss: 0.0030 - reg_l2_loss: 0.1081 - loss: 0.6105 - learning_rate: 5.1183e-04 - gradient_norm: 5.9712 - val_det_loss: 0.5382 - val_cls_loss: 0.3394 - val_box_loss: 0.0040 - val_reg_l2_loss: 0.1081 - val_loss: 0.6464
# Epoch 80/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2999 - cls_loss: 0.2093 - box_loss: 0.0018 - reg_l2_loss: 0.1081 - loss: 0.4081 - learning_rate: 4.6475e-04 - gradient_norm: 2.8655 - val_det_loss: 0.5578 - val_cls_loss: 0.3480 - val_box_loss: 0.0042 - val_reg_l2_loss: 0.1081 - val_loss: 0.6659
# Epoch 81/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.3287 - cls_loss: 0.2391 - box_loss: 0.0018 - reg_l2_loss: 0.1081 - loss: 0.4368 - learning_rate: 4.1972e-04 - gradient_norm: 5.9150 - val_det_loss: 0.5595 - val_cls_loss: 0.3497 - val_box_loss: 0.0042 - val_reg_l2_loss: 0.1081 - val_loss: 0.6677
# Epoch 82/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.3645 - cls_loss: 0.2434 - box_loss: 0.0024 - reg_l2_loss: 0.1081 - loss: 0.4727 - learning_rate: 3.7678e-04 - gradient_norm: 6.3888 - val_det_loss: 0.5493 - val_cls_loss: 0.3495 - val_box_loss: 0.0040 - val_reg_l2_loss: 0.1081 - val_loss: 0.6575
# Epoch 83/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2761 - cls_loss: 0.1993 - box_loss: 0.0015 - reg_l2_loss: 0.1081 - loss: 0.3842 - learning_rate: 3.3598e-04 - gradient_norm: 4.2600 - val_det_loss: 0.5380 - val_cls_loss: 0.3411 - val_box_loss: 0.0039 - val_reg_l2_loss: 0.1081 - val_loss: 0.6462
# Epoch 84/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.3616 - cls_loss: 0.2507 - box_loss: 0.0022 - reg_l2_loss: 0.1081 - loss: 0.4698 - learning_rate: 2.9736e-04 - gradient_norm: 6.2681 - val_det_loss: 0.5444 - val_cls_loss: 0.3504 - val_box_loss: 0.0039 - val_reg_l2_loss: 0.1081 - val_loss: 0.6526
# Epoch 85/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3297 - cls_loss: 0.2365 - box_loss: 0.0019 - reg_l2_loss: 0.1081 - loss: 0.4379 - learning_rate: 2.6096e-04 - gradient_norm: 3.8838 - val_det_loss: 0.5447 - val_cls_loss: 0.3520 - val_box_loss: 0.0039 - val_reg_l2_loss: 0.1081 - val_loss: 0.6529
# Epoch 86/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3095 - cls_loss: 0.2407 - box_loss: 0.0014 - reg_l2_loss: 0.1081 - loss: 0.4176 - learning_rate: 2.2681e-04 - gradient_norm: 3.8577 - val_det_loss: 0.5588 - val_cls_loss: 0.3644 - val_box_loss: 0.0039 - val_reg_l2_loss: 0.1081 - val_loss: 0.6670
# Epoch 87/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.3143 - cls_loss: 0.2345 - box_loss: 0.0016 - reg_l2_loss: 0.1081 - loss: 0.4225 - learning_rate: 1.9495e-04 - gradient_norm: 3.7929 - val_det_loss: 0.5649 - val_cls_loss: 0.3700 - val_box_loss: 0.0039 - val_reg_l2_loss: 0.1081 - val_loss: 0.6731
# Epoch 88/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.3874 - cls_loss: 0.2660 - box_loss: 0.0024 - reg_l2_loss: 0.1081 - loss: 0.4956 - learning_rate: 1.6541e-04 - gradient_norm: 4.6596 - val_det_loss: 0.5767 - val_cls_loss: 0.3833 - val_box_loss: 0.0039 - val_reg_l2_loss: 0.1081 - val_loss: 0.6848
# Epoch 89/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.2631 - cls_loss: 0.1881 - box_loss: 0.0015 - reg_l2_loss: 0.1081 - loss: 0.3713 - learning_rate: 1.3822e-04 - gradient_norm: 3.4597 - val_det_loss: 0.5936 - val_cls_loss: 0.4013 - val_box_loss: 0.0038 - val_reg_l2_loss: 0.1081 - val_loss: 0.7018
# Epoch 90/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.4691 - cls_loss: 0.3036 - box_loss: 0.0033 - reg_l2_loss: 0.1081 - loss: 0.5772 - learning_rate: 1.1341e-04 - gradient_norm: 5.5036 - val_det_loss: 0.6067 - val_cls_loss: 0.4181 - val_box_loss: 0.0038 - val_reg_l2_loss: 0.1081 - val_loss: 0.7148
# Epoch 91/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.4061 - cls_loss: 0.2571 - box_loss: 0.0030 - reg_l2_loss: 0.1081 - loss: 0.5142 - learning_rate: 9.1009e-05 - gradient_norm: 4.6234 - val_det_loss: 0.6151 - val_cls_loss: 0.4254 - val_box_loss: 0.0038 - val_reg_l2_loss: 0.1081 - val_loss: 0.7233
# Epoch 92/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2972 - cls_loss: 0.2149 - box_loss: 0.0016 - reg_l2_loss: 0.1081 - loss: 0.4054 - learning_rate: 7.1028e-05 - gradient_norm: 4.2086 - val_det_loss: 0.6122 - val_cls_loss: 0.4260 - val_box_loss: 0.0037 - val_reg_l2_loss: 0.1081 - val_loss: 0.7204
# Epoch 93/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3152 - cls_loss: 0.2138 - box_loss: 0.0020 - reg_l2_loss: 0.1081 - loss: 0.4234 - learning_rate: 5.3493e-05 - gradient_norm: 3.5999 - val_det_loss: 0.6047 - val_cls_loss: 0.4192 - val_box_loss: 0.0037 - val_reg_l2_loss: 0.1081 - val_loss: 0.7128
# Epoch 94/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.3062 - cls_loss: 0.2107 - box_loss: 0.0019 - reg_l2_loss: 0.1081 - loss: 0.4143 - learning_rate: 3.8422e-05 - gradient_norm: 3.5082 - val_det_loss: 0.5884 - val_cls_loss: 0.4060 - val_box_loss: 0.0036 - val_reg_l2_loss: 0.1081 - val_loss: 0.6965
# Epoch 95/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3716 - cls_loss: 0.2503 - box_loss: 0.0024 - reg_l2_loss: 0.1081 - loss: 0.4797 - learning_rate: 2.5829e-05 - gradient_norm: 4.5694 - val_det_loss: 0.5775 - val_cls_loss: 0.3974 - val_box_loss: 0.0036 - val_reg_l2_loss: 0.1081 - val_loss: 0.6857
# Epoch 96/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3531 - cls_loss: 0.2608 - box_loss: 0.0018 - reg_l2_loss: 0.1081 - loss: 0.4613 - learning_rate: 1.5727e-05 - gradient_norm: 6.8418 - val_det_loss: 0.5691 - val_cls_loss: 0.3905 - val_box_loss: 0.0036 - val_reg_l2_loss: 0.1081 - val_loss: 0.6772
# Epoch 97/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.3268 - cls_loss: 0.2410 - box_loss: 0.0017 - reg_l2_loss: 0.1081 - loss: 0.4350 - learning_rate: 8.1273e-06 - gradient_norm: 3.8417 - val_det_loss: 0.5756 - val_cls_loss: 0.3966 - val_box_loss: 0.0036 - val_reg_l2_loss: 0.1081 - val_loss: 0.6838
# Epoch 98/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.2945 - cls_loss: 0.2078 - box_loss: 0.0017 - reg_l2_loss: 0.1081 - loss: 0.4026 - learning_rate: 3.0362e-06 - gradient_norm: 3.5588 - val_det_loss: 0.5675 - val_cls_loss: 0.3889 - val_box_loss: 0.0036 - val_reg_l2_loss: 0.1081 - val_loss: 0.6757
# Epoch 99/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 0.3092 - cls_loss: 0.1989 - box_loss: 0.0022 - reg_l2_loss: 0.1081 - loss: 0.4174 - learning_rate: 4.5955e-07 - gradient_norm: 3.9617 - val_det_loss: 0.5607 - val_cls_loss: 0.3802 - val_box_loss: 0.0036 - val_reg_l2_loss: 0.1081 - val_loss: 0.6689
# Epoch 100/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3337 - cls_loss: 0.2326 - box_loss: 0.0020 - reg_l2_loss: 0.1081 - loss: 0.4418 - learning_rate: 3.9961e-07 - gradient_norm: 3.7226 - val_det_loss: 0.5666 - val_cls_loss: 0.3886 - val_box_loss: 0.0036 - val_reg_l2_loss: 0.1081 - val_loss: 0.6747

# %% [markdown]
# ### Step 4. Evaluate the model with the validation data.
#
# After training the object detection model using the images in the training dataset, use the 10 images in the validation dataset to evaluate how the model performs against new data it has never seen before.
#
# As the default batch size is 64, it will take 1 step to go through the 10 images in the validation dataset.
#
# The evaluation metrics are same as [COCO](https://cocodataset.org/#detection-eval).

# %%
model.evaluate(val_data)
# Out:
# 1/1 [==============================] - 6s 6s/step
# {'AP': 0.29293936,
#  'AP50': 0.47780043,
#  'AP75': 0.26732674,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.29436216,
#  'ARmax1': 0.35,
#  'ARmax10': 0.45416668,
#  'ARmax100': 0.45416668,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.45416668,
#  'AP_/painting': 0.08193777,
#  'AP_/Real_Tunnel': 0.503941}

# %%
# import matplotlib.pyplot as plt
# print(model.history.keys())
# # summarize history for loss
# plt.plot(model.history['loss'])
# plt.plot(model.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %% [markdown]
# ### Step 5: Export as a TensorFlow Lite model.
#
# Export the trained object detection model to the TensorFlow Lite format by specifying which folder you want to export the quantized model to. The default post-training quantization technique is [full integer quantization](https://www.tensorflow.org/lite/performance/post_training_integer_quant). This allows the TensorFlow Lite model to be smaller, run faster on Raspberry Pi CPU and also compatible with the Google Coral EdgeTPU.

# %%
model.export(export_dir='Thesis/', tflite_filename='android.tfliteDIFF640')

# %% [markdown]
# ### Step 6:  Evaluate the TensorFlow Lite model.
#
# Several factors can affect the model accuracy when exporting to TFLite:
# * [Quantization](https://www.tensorflow.org/lite/performance/model_optimization) helps shrinking the model size by 4 times at the expense of some accuracy drop.
# * The original TensorFlow model uses per-class [non-max supression (NMS)](https://www.coursera.org/lecture/convolutional-neural-networks/non-max-suppression-dvrjH) for post-processing, while the TFLite model uses global NMS that's much faster but less accurate.
# Keras outputs maximum 100 detections while tflite outputs maximum 25 detections.
#
# Therefore you'll have to evaluate the exported TFLite model and compare its accuracy with the original TensorFlow model.

# %%
model.evaluate_tflite('Thesis/android.tfliteDIFF640', val_data)
# Out:
# 7/7 [==============================] - 352s 50s/step
# {'AP': 0.29296216,
#  'AP50': 0.5884017,
#  'AP75': 0.2449745,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.2929961,
#  'ARmax1': 0.33333334,
#  'ARmax10': 0.38333333,
#  'ARmax100': 0.43333334,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.43333334,
#  'AP_/painting': 0.08670439,
#  'AP_/Real_Tunnel': 0.49921992}

# %%
# Download the TFLite model to your local computer.
# from google.colab import files
# files.download('android.tflitePP')

# %% [markdown]
# ## Test the Android figurine detection model
#
# After training the model, let's test it with an image that the model hasn't seen before to get a sense of how good the model is.

# %%
#@title Load the trained TFLite model and define some visualization functions

#@markdown This code comes from the TFLite Object Detection [Raspberry Pi sample](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/raspberry_pi).

import platform
from typing import List, NamedTuple
import json

import cv2

Interpreter = tf.lite.Interpreter
load_delegate = tf.lite.experimental.load_delegate

# pylint: enable=g-import-not-at-top


class ObjectDetectorOptions(NamedTuple):
  """A config to initialize an object detector."""

  enable_edgetpu: bool = False
  """Enable the model to run on EdgeTPU."""

  label_allow_list: List[str] = None
  """The optional allow list of labels."""

  label_deny_list: List[str] = None
  """The optional deny list of labels."""

  max_results: int = -1
  """The maximum number of top-scored detection results to return."""

  num_threads: int = 1
  """The number of CPU threads to be used."""

  score_threshold: float = 0.0
  """The score threshold of detection results to return."""


class Rect(NamedTuple):
  """A rectangle in 2D space."""
  left: float
  top: float
  right: float
  bottom: float


class Category(NamedTuple):
  """A result of a classification task."""
  label: str
  score: float
  index: int


class Detection(NamedTuple):
  """A detected object as the result of an ObjectDetector."""
  bounding_box: Rect
  categories: List[Category]


def edgetpu_lib_name():
  """Returns the library name of EdgeTPU in the current platform."""
  return {
      'Darwin': 'libedgetpu.1.dylib',
      'Linux': 'libedgetpu.so.1',
      'Windows': 'edgetpu.dll',
  }.get(platform.system(), None)


class ObjectDetector:
  """A wrapper class for a TFLite object detection model."""

  _OUTPUT_LOCATION_NAME = 'location'
  _OUTPUT_CATEGORY_NAME = 'category'
  _OUTPUT_SCORE_NAME = 'score'
  _OUTPUT_NUMBER_NAME = 'number of detections'

  def __init__(
      self,
      model_path: str,
      options: ObjectDetectorOptions = ObjectDetectorOptions()
  ) -> None:
    """Initialize a TFLite object detection model.
    Args:
        model_path: Path to the TFLite model.
        options: The config to initialize an object detector. (Optional)
    Raises:
        ValueError: If the TFLite model is invalid.
        OSError: If the current OS isn't supported by EdgeTPU.
    """

    # Load metadata from model.
    displayer = metadata.MetadataDisplayer.with_model_file(model_path)

    # Save model metadata for preprocessing later.
    model_metadata = json.loads(displayer.get_metadata_json())
    process_units = model_metadata['subgraph_metadata'][0]['input_tensor_metadata'][0]['process_units']
    mean = 0.0
    std = 1.0
    for option in process_units:
      if option['options_type'] == 'NormalizationOptions':
        mean = option['options']['mean'][0]
        std = option['options']['std'][0]
    self._mean = mean
    self._std = std

    # Load label list from metadata.
    file_name = displayer.get_packed_associated_file_list()[0]
    label_map_file = displayer.get_associated_file_buffer(file_name).decode()
    label_list = list(filter(lambda x: len(x) > 0, label_map_file.splitlines()))
    self._label_list = label_list

    # Initialize TFLite model.
    if options.enable_edgetpu:
      if edgetpu_lib_name() is None:
        raise OSError("The current OS isn't supported by Coral EdgeTPU.")
      interpreter = Interpreter(
          model_path=model_path,
          experimental_delegates=[load_delegate(edgetpu_lib_name())],
          num_threads=options.num_threads)
    else:
      interpreter = Interpreter(
          model_path=model_path, num_threads=options.num_threads)

    interpreter.allocate_tensors()
    input_detail = interpreter.get_input_details()[0]

    # From TensorFlow 2.6, the order of the outputs become undefined.
    # Therefore we need to sort the tensor indices of TFLite outputs and to know
    # exactly the meaning of each output tensor. For example, if
    # output indices are [601, 599, 598, 600], tensor names and indices aligned
    # are:
    #   - location: 598
    #   - category: 599
    #   - score: 600
    #   - detection_count: 601
    # because of the op's ports of TFLITE_DETECTION_POST_PROCESS
    # (https://github.com/tensorflow/tensorflow/blob/a4fe268ea084e7d323133ed7b986e0ae259a2bc7/tensorflow/lite/kernels/detection_postprocess.cc#L47-L50).
    sorted_output_indices = sorted(
        [output['index'] for output in interpreter.get_output_details()])
    self._output_indices = {
        self._OUTPUT_LOCATION_NAME: sorted_output_indices[0],
        self._OUTPUT_CATEGORY_NAME: sorted_output_indices[1],
        self._OUTPUT_SCORE_NAME: sorted_output_indices[2],
        self._OUTPUT_NUMBER_NAME: sorted_output_indices[3],
    }

    self._input_size = input_detail['shape'][2], input_detail['shape'][1]
    self._is_quantized_input = input_detail['dtype'] == np.uint8
    self._interpreter = interpreter
    self._options = options

  def detect(self, input_image: np.ndarray) -> List[Detection]:
    """Run detection on an input image.
    Args:
        input_image: A [height, width, 3] RGB image. Note that height and width
          can be anything since the image will be immediately resized according
          to the needs of the model within this function.
    Returns:
        A Person instance.
    """
    image_height, image_width, _ = input_image.shape

    input_tensor = self._preprocess(input_image)

    self._set_input_tensor(input_tensor)
    self._interpreter.invoke()

    # Get all output details
    boxes = self._get_output_tensor(self._OUTPUT_LOCATION_NAME)
    classes = self._get_output_tensor(self._OUTPUT_CATEGORY_NAME)
    scores = self._get_output_tensor(self._OUTPUT_SCORE_NAME)
    count = int(self._get_output_tensor(self._OUTPUT_NUMBER_NAME))

    return self._postprocess(boxes, classes, scores, count, image_width,
                             image_height)

  def _preprocess(self, input_image: np.ndarray) -> np.ndarray:
    """Preprocess the input image as required by the TFLite model."""

    # Resize the input
    input_tensor = cv2.resize(input_image, self._input_size)

    # Normalize the input if it's a float model (aka. not quantized)
    if not self._is_quantized_input:
      input_tensor = (np.float32(input_tensor) - self._mean) / self._std

    # Add batch dimension
    input_tensor = np.expand_dims(input_tensor, axis=0)

    return input_tensor

  def _set_input_tensor(self, image):
    """Sets the input tensor."""
    tensor_index = self._interpreter.get_input_details()[0]['index']
    input_tensor = self._interpreter.tensor(tensor_index)()[0]
    input_tensor[:, :] = image

  def _get_output_tensor(self, name):
    """Returns the output tensor at the given index."""
    output_index = self._output_indices[name]
    tensor = np.squeeze(self._interpreter.get_tensor(output_index))
    return tensor

  def _postprocess(self, boxes: np.ndarray, classes: np.ndarray,
                   scores: np.ndarray, count: int, image_width: int,
                   image_height: int) -> List[Detection]:
    """Post-process the output of TFLite model into a list of Detection objects.
    Args:
        boxes: Bounding boxes of detected objects from the TFLite model.
        classes: Class index of the detected objects from the TFLite model.
        scores: Confidence scores of the detected objects from the TFLite model.
        count: Number of detected objects from the TFLite model.
        image_width: Width of the input image.
        image_height: Height of the input image.
    Returns:
        A list of Detection objects detected by the TFLite model.
    """
    results = []

    # Parse the model output into a list of Detection entities.
    for i in range(count):
      if scores[i] >= self._options.score_threshold:
        y_min, x_min, y_max, x_max = boxes[i]
        bounding_box = Rect(
            top=int(y_min * image_height),
            left=int(x_min * image_width),
            bottom=int(y_max * image_height),
            right=int(x_max * image_width))
        class_id = int(classes[i])
        category = Category(
            score=scores[i],
            label=self._label_list[class_id],  # 0 is reserved for background
            index=class_id)
        result = Detection(bounding_box=bounding_box, categories=[category])
        results.append(result)

    # Sort detection results by score ascending
    sorted_results = sorted(
        results,
        key=lambda detection: detection.categories[0].score,
        reverse=True)

    # Filter out detections in deny list
    filtered_results = sorted_results
    if self._options.label_deny_list is not None:
      filtered_results = list(
          filter(
              lambda detection: detection.categories[0].label not in self.
              _options.label_deny_list, filtered_results))

    # Keep only detections in allow list
    if self._options.label_allow_list is not None:
      filtered_results = list(
          filter(
              lambda detection: detection.categories[0].label in self._options.
              label_allow_list, filtered_results))

    # Only return maximum of max_results detection.
    if self._options.max_results > 0:
      result_count = min(len(filtered_results), self._options.max_results)
      filtered_results = filtered_results[:result_count]

    return filtered_results


_MARGIN = 10  # pixels
_ROW_SIZE = 10  # pixels
_FONT_SIZE = 1
_FONT_THICKNESS = 1
_TEXT_COLOR = (0, 0, 255)  # red


def visualize(
    image: np.ndarray,
    detections: List[Detection],
) -> np.ndarray:
  """Draws bounding boxes on the input image and return it.
  Args:
    image: The input RGB image.
    detections: The list of all "Detection" entities to be visualize.
  Returns:
    Image with bounding boxes.
  """
  for detection in detections:
    # Draw bounding_box
    start_point = detection.bounding_box.left, detection.bounding_box.top
    end_point = detection.bounding_box.right, detection.bounding_box.bottom
    cv2.rectangle(image, start_point, end_point, _TEXT_COLOR, 3)

    # Draw label and score
    category = detection.categories[0]
    class_name = category.label
    probability = round(category.score, 2)
    result_text = class_name + ' (' + str(probability) + ')'
    text_location = (_MARGIN + detection.bounding_box.left,
                     _MARGIN + _ROW_SIZE + detection.bounding_box.top)
    cv2.putText(image, result_text, text_location, cv2.FONT_HERSHEY_PLAIN,
                _FONT_SIZE, _TEXT_COLOR, _FONT_THICKNESS)

  return image

# %%
from PIL import Image
INPUT_IMAGE_ONE = 'Thesis/All_Photos/640_DIFFNet/640_TEST/0_disp.jpeg' #@param {type:"string"}
DETECTION_THRESHOLD = 0.5 #@param {type:"number"}
TFLITE_MODEL_PATH = "Thesis/android.tfliteDIFF640" #@param {type:"string"}

TEMP_FILE = '/tmp/image.png'

# !wget -q -O $TEMP_FILE $INPUT_IMAGE_ONE

#image = Image.open(TEMP_FILE).convert('RGB')
image_one = Image.open(INPUT_IMAGE_ONE).convert('RGB')
image_one.thumbnail((512, 512), Image.ANTIALIAS)
image_np_one = np.asarray(image_one)

# Load the TFLite model
options = ObjectDetectorOptions(
      num_threads=4,
      score_threshold=DETECTION_THRESHOLD,
)
detector = ObjectDetector(model_path=TFLITE_MODEL_PATH, options=options)

# Run object detection estimation using the model.
detections = detector.detect(image_np_one)

# Draw keypoints and edges on input image
image_np_one = visualize(image_np_one, detections)

# Show the detection result
Image.fromarray(image_np_one)
# Out:
# <PIL.Image.Image image mode=RGB size=512x341 at 0x7EFBDB4B23A0>

# %%
#INPUT_IMAGE_URL = 'JPEG/Validate/2_33226e67-1692-4472-88be-acdbace303f5_1024x1024.jpg'
INPUT_IMAGE_URL = 'Thesis/All_Photos/640_DIFFNet/640_TEST/6_disp.jpeg'
DISP_IMAGE_OVERLAY = 'Thesis/All_Photos/640_DIFFNet/640_TEST/6_disp.jpeg'

# %%
#@title Run object detection and show the detection results

# from PIL import Image

# INPUT_IMAGE_URL = 'Depth_Map_Image/2_disp.jpeg'
# INPUT_IMAGE_URL = "http://download.tensorflow.org/example_images/android_figurine.jpg" #@param {type:"string"}
INPUT_IMAGE_URL = INPUT_IMAGE_URL #@param {type:"string"}
DETECTION_THRESHOLD = 0.5 #@param {type:"number"}
TFLITE_MODEL_PATH = "Thesis/android.tfliteDIFF640" #@param {type:"string"}

TEMP_FILE = '/tmp/image.png'

# !wget -q -O $TEMP_FILE $INPUT_IMAGE_URL

#image = Image.open(TEMP_FILE).convert('RGB')
image = Image.open(INPUT_IMAGE_URL).convert('RGB')
image.thumbnail((512, 512), Image.ANTIALIAS)
image_np = np.asarray(image)

# Load the TFLite model
options = ObjectDetectorOptions(
      num_threads=4,
      score_threshold=DETECTION_THRESHOLD,
)
detector = ObjectDetector(model_path=TFLITE_MODEL_PATH, options=options)

# Run object detection estimation using the model.
detections = detector.detect(image_np)

# Draw keypoints and edges on input image
image_np = visualize(image_np, detections)

# Show the detection result
Image.fromarray(image_np)



# #image = Image.open(TEMP_FILE).convert('RGB')
# image_two = Image.open(DISP_IMAGE_OVERLAY).convert('RGB')
# image_two.thumbnail((512, 512), Image.ANTIALIAS)
# image_np_two = np.asarray(image_two)

# image_np_two = visualize(image_np_two, detections)
# Image.fromarray(image_np_two)
# Out:
# <PIL.Image.Image image mode=RGB size=512x288 at 0x7EFBDAF45280>

# %%
# image_two = Image.open(DISP_IMAGE_OVERLAY).convert('RGB')
# image_two.thumbnail((512, 512), Image.ANTIALIAS)
# image_np_two = np.asarray(image_two)

# image_np_two = visualize(image_np_two, detections)
# Image.fromarray(image_np_two)

# %%
t2 = time.perf_counter()
print('time taken to run:',t2-t1)
# Out:
# time taken to run: 1843.940111803

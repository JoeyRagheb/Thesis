# %% [markdown]
# ## Preparation
#
# ### Install the required packages
# Start by installing the required packages, including the Model Maker package from the [GitHub repo](https://github.com/tensorflow/examples/tree/master/tensorflow_examples/lite/model_maker) and the pycocotools library you'll use for evaluation.

# %%
# !pip install -q tflite-model-maker
# !pip install -q tflite-support
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.3/577.3 KB 23.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 KB 26.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 45.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.6 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/tensorflowjs/
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 KB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.6/128.6 KB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 57.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 39.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 KB 29.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 MB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 56.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.0/498.0 MB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 KB 37.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 29.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 58.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 KB 35.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 KB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.4/222.4 KB 27.7 MB/s eta 0:00:00
#   Building wheel for fire (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 2022.12.0 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.

# %% [markdown]
# Import the required packages.

# %%
import numpy as np
import os

from tflite_model_maker.config import ExportFormat, QuantizationConfig
from tflite_model_maker import model_spec
from tflite_model_maker import object_detector

from tflite_support import metadata

import tensorflow as tf
assert tf.__version__.startswith('2')

tf.get_logger().setLevel('ERROR')
from absl import logging
logging.set_verbosity(logging.ERROR)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.4 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %% [markdown]
# ### Prepare the dataset

# %%
#!wget https://storage.googleapis.com/download.tensorflow.org/data/android_figurine.zip
#!unzip -q android_figurine.zip
from google.colab import drive
drive.mount('/content/drive/', force_remount=True) #, force_remount=True
# Out:
# Mounted at /content/drive/

# %%
# Run this if need to force remount
import os
path = "/content" # /content is pretty much the root. you can choose other path in your colab workspace
os.chdir(path)

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/My Drive/
# Out:
# /content/drive/My Drive

# %%
# !unzip -q JPEG.zip # This should be on when running first time

# %% [markdown]
# ## Train the object detection model
#
# ### Step 1: Load the dataset
#
# * Images in `train_data` is used to train the custom object detection model.
# * Images in `val_data` is used to check if the model can generalize well to new images that it hasn't seen before.

# %%
# !pwd
# Out:
# /content/drive/My Drive

# %%
train_data = object_detector.DataLoader.from_pascal_voc(
    'Thesis/All_Photos/Original/Original_TRAIN',
    'Thesis/All_Photos/Original/Original_TRAIN',
    ['painting','Real_Tunnel']
)

val_data = object_detector.DataLoader.from_pascal_voc(
    'Thesis/All_Photos/Original/Original_TEST',
    'Thesis/All_Photos/Original/Original_TEST',
    ['painting','Real_Tunnel']
)

# %%
print(train_data.size)
# Out:
# 25

# %% [markdown]
# ### Step 2: Select a model architecture
#
# EfficientDet-Lite[0-4] are a family of mobile/IoT-friendly object detection models derived from the [EfficientDet](https://arxiv.org/abs/1911.09070) architecture.
#
# Here is the performance of each EfficientDet-Lite models compared to each others.
#
# | Model architecture | Size(MB)* | Latency(ms)** | Average Precision*** |
# |--------------------|-----------|---------------|----------------------|
# | EfficientDet-Lite0 | 4.4       | 146           | 25.69%               |
# | EfficientDet-Lite1 | 5.8       | 259           | 30.55%               |
# | EfficientDet-Lite2 | 7.2       | 396           | 33.97%               |
# | EfficientDet-Lite3 | 11.4      | 716           | 37.70%               |
# | EfficientDet-Lite4 | 19.9      | 1886          | 41.96%               |
#
# <i> * Size of the integer quantized models. <br/>
# ** Latency measured on Raspberry Pi 4 using 4 threads on CPU. <br/>
# *** Average Precision is the mAP (mean Average Precision) on the COCO 2017 validation dataset.
# </i>
#
# In this notebook, we use EfficientDet-Lite0 to train our model. You can choose other model architectures depending on whether speed or accuracy is more important to you.

# %%
spec = model_spec.get('efficientdet_lite4')

# %% [markdown]
# ### Step 3: Train the TensorFlow model with the training data.
#
# * Set `epochs = 20`, which means it will go through the training dataset 20 times. You can look at the validation accuracy during training and stop when you see validation loss (`val_loss`) stop decreasing to avoid overfitting.
# * Set `batch_size = 4` here so you will see that it takes 15 steps to go through the 62 images in the training dataset.
# * Set `train_whole_model=True` to fine-tune the whole model instead of just training the head layer to improve accuracy. The trade-off is that it may take longer to train the model.

# %%
import time
t1 = time.perf_counter()

# %%
model = object_detector.create(train_data, model_spec=spec, batch_size=4, train_whole_model=True, epochs=100, validation_data=val_data)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 76s 3s/step - det_loss: 1.7606 - cls_loss: 1.1614 - box_loss: 0.0120 - reg_l2_loss: 0.1078 - loss: 1.8684 - learning_rate: 0.0066 - gradient_norm: 1.5575 - val_det_loss: 1.6694 - val_cls_loss: 1.1552 - val_box_loss: 0.0103 - val_reg_l2_loss: 0.1078 - val_loss: 1.7772
# Epoch 2/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.7035 - cls_loss: 1.1524 - box_loss: 0.0110 - reg_l2_loss: 0.1078 - loss: 1.8113 - learning_rate: 0.0050 - gradient_norm: 1.5982 - val_det_loss: 1.5762 - val_cls_loss: 1.1450 - val_box_loss: 0.0086 - val_reg_l2_loss: 0.1078 - val_loss: 1.6840
# Epoch 3/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 1.6995 - cls_loss: 1.1465 - box_loss: 0.0111 - reg_l2_loss: 0.1078 - loss: 1.8073 - learning_rate: 0.0050 - gradient_norm: 1.8278 - val_det_loss: 1.5228 - val_cls_loss: 1.1347 - val_box_loss: 0.0078 - val_reg_l2_loss: 0.1078 - val_loss: 1.6306
# Epoch 4/100
# 6/6 [==============================] - 8s 1s/step - det_loss: 1.5870 - cls_loss: 1.1257 - box_loss: 0.0092 - reg_l2_loss: 0.1078 - loss: 1.6948 - learning_rate: 0.0050 - gradient_norm: 1.9415 - val_det_loss: 1.4934 - val_cls_loss: 1.1196 - val_box_loss: 0.0075 - val_reg_l2_loss: 0.1078 - val_loss: 1.6012
# Epoch 5/100
# 6/6 [==============================] - 15s 3s/step - det_loss: 1.5415 - cls_loss: 1.1109 - box_loss: 0.0086 - reg_l2_loss: 0.1078 - loss: 1.6493 - learning_rate: 0.0050 - gradient_norm: 1.9566 - val_det_loss: 1.4380 - val_cls_loss: 1.0949 - val_box_loss: 0.0069 - val_reg_l2_loss: 0.1078 - val_loss: 1.5458
# Epoch 6/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 1.4655 - cls_loss: 1.0746 - box_loss: 0.0078 - reg_l2_loss: 0.1078 - loss: 1.5733 - learning_rate: 0.0050 - gradient_norm: 2.5803 - val_det_loss: 1.3509 - val_cls_loss: 1.0555 - val_box_loss: 0.0059 - val_reg_l2_loss: 0.1078 - val_loss: 1.4587
# Epoch 7/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.4214 - cls_loss: 1.0467 - box_loss: 0.0075 - reg_l2_loss: 0.1078 - loss: 1.5292 - learning_rate: 0.0049 - gradient_norm: 3.4075 - val_det_loss: 1.2347 - val_cls_loss: 0.9722 - val_box_loss: 0.0053 - val_reg_l2_loss: 0.1078 - val_loss: 1.3425
# Epoch 8/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.3554 - cls_loss: 0.9867 - box_loss: 0.0074 - reg_l2_loss: 0.1078 - loss: 1.4632 - learning_rate: 0.0049 - gradient_norm: 3.7189 - val_det_loss: 1.0963 - val_cls_loss: 0.8472 - val_box_loss: 0.0050 - val_reg_l2_loss: 0.1078 - val_loss: 1.2041
# Epoch 9/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.3018 - cls_loss: 0.9501 - box_loss: 0.0070 - reg_l2_loss: 0.1078 - loss: 1.4096 - learning_rate: 0.0049 - gradient_norm: 3.9882 - val_det_loss: 0.9429 - val_cls_loss: 0.7213 - val_box_loss: 0.0044 - val_reg_l2_loss: 0.1078 - val_loss: 1.0507
# Epoch 10/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.0642 - cls_loss: 0.7849 - box_loss: 0.0056 - reg_l2_loss: 0.1078 - loss: 1.1720 - learning_rate: 0.0049 - gradient_norm: 3.7020 - val_det_loss: 0.8728 - val_cls_loss: 0.6760 - val_box_loss: 0.0039 - val_reg_l2_loss: 0.1078 - val_loss: 0.9806
# Epoch 11/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 1.0164 - cls_loss: 0.7516 - box_loss: 0.0053 - reg_l2_loss: 0.1078 - loss: 1.1242 - learning_rate: 0.0049 - gradient_norm: 4.8653 - val_det_loss: 0.9338 - val_cls_loss: 0.7299 - val_box_loss: 0.0041 - val_reg_l2_loss: 0.1078 - val_loss: 1.0417
# Epoch 12/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.8602 - cls_loss: 0.6370 - box_loss: 0.0045 - reg_l2_loss: 0.1078 - loss: 0.9680 - learning_rate: 0.0048 - gradient_norm: 3.6323 - val_det_loss: 0.7088 - val_cls_loss: 0.5112 - val_box_loss: 0.0040 - val_reg_l2_loss: 0.1078 - val_loss: 0.8167
# Epoch 13/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.9246 - cls_loss: 0.6625 - box_loss: 0.0052 - reg_l2_loss: 0.1078 - loss: 1.0324 - learning_rate: 0.0048 - gradient_norm: 3.2534 - val_det_loss: 0.6872 - val_cls_loss: 0.4641 - val_box_loss: 0.0045 - val_reg_l2_loss: 0.1078 - val_loss: 0.7950
# Epoch 14/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.8331 - cls_loss: 0.6175 - box_loss: 0.0043 - reg_l2_loss: 0.1079 - loss: 0.9409 - learning_rate: 0.0048 - gradient_norm: 5.2371 - val_det_loss: 0.6900 - val_cls_loss: 0.4637 - val_box_loss: 0.0045 - val_reg_l2_loss: 0.1079 - val_loss: 0.7979
# Epoch 15/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.7448 - cls_loss: 0.5415 - box_loss: 0.0041 - reg_l2_loss: 0.1079 - loss: 0.8527 - learning_rate: 0.0047 - gradient_norm: 5.2082 - val_det_loss: 0.5388 - val_cls_loss: 0.4092 - val_box_loss: 0.0026 - val_reg_l2_loss: 0.1079 - val_loss: 0.6466
# Epoch 16/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.7403 - cls_loss: 0.5403 - box_loss: 0.0040 - reg_l2_loss: 0.1079 - loss: 0.8482 - learning_rate: 0.0047 - gradient_norm: 5.4856 - val_det_loss: 0.4968 - val_cls_loss: 0.3843 - val_box_loss: 0.0023 - val_reg_l2_loss: 0.1079 - val_loss: 0.6046
# Epoch 17/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.7713 - cls_loss: 0.5652 - box_loss: 0.0041 - reg_l2_loss: 0.1079 - loss: 0.8792 - learning_rate: 0.0047 - gradient_norm: 4.1155 - val_det_loss: 0.5664 - val_cls_loss: 0.4240 - val_box_loss: 0.0028 - val_reg_l2_loss: 0.1079 - val_loss: 0.6743
# Epoch 18/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.6415 - cls_loss: 0.4520 - box_loss: 0.0038 - reg_l2_loss: 0.1079 - loss: 0.7494 - learning_rate: 0.0046 - gradient_norm: 2.8824 - val_det_loss: 0.5031 - val_cls_loss: 0.4033 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1079 - val_loss: 0.6110
# Epoch 19/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.6282 - cls_loss: 0.4432 - box_loss: 0.0037 - reg_l2_loss: 0.1079 - loss: 0.7361 - learning_rate: 0.0046 - gradient_norm: 4.3248 - val_det_loss: 0.5449 - val_cls_loss: 0.4123 - val_box_loss: 0.0027 - val_reg_l2_loss: 0.1079 - val_loss: 0.6528
# Epoch 20/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.6248 - cls_loss: 0.4631 - box_loss: 0.0032 - reg_l2_loss: 0.1079 - loss: 0.7327 - learning_rate: 0.0045 - gradient_norm: 3.4591 - val_det_loss: 0.5957 - val_cls_loss: 0.4375 - val_box_loss: 0.0032 - val_reg_l2_loss: 0.1079 - val_loss: 0.7036
# Epoch 21/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.4804 - cls_loss: 0.3552 - box_loss: 0.0025 - reg_l2_loss: 0.1079 - loss: 0.5883 - learning_rate: 0.0045 - gradient_norm: 3.2412 - val_det_loss: 0.4996 - val_cls_loss: 0.4178 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.1079 - val_loss: 0.6075
# Epoch 22/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4701 - cls_loss: 0.3446 - box_loss: 0.0025 - reg_l2_loss: 0.1079 - loss: 0.5780 - learning_rate: 0.0044 - gradient_norm: 4.0534 - val_det_loss: 0.4768 - val_cls_loss: 0.3864 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.5847
# Epoch 23/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.5234 - cls_loss: 0.3722 - box_loss: 0.0030 - reg_l2_loss: 0.1079 - loss: 0.6313 - learning_rate: 0.0044 - gradient_norm: 3.6669 - val_det_loss: 0.4290 - val_cls_loss: 0.3385 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1079 - val_loss: 0.5369
# Epoch 24/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4690 - cls_loss: 0.3530 - box_loss: 0.0023 - reg_l2_loss: 0.1079 - loss: 0.5769 - learning_rate: 0.0043 - gradient_norm: 3.2012 - val_det_loss: 0.4355 - val_cls_loss: 0.3354 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1079 - val_loss: 0.5434
# Epoch 25/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.4715 - cls_loss: 0.3364 - box_loss: 0.0027 - reg_l2_loss: 0.1079 - loss: 0.5794 - learning_rate: 0.0043 - gradient_norm: 3.3933 - val_det_loss: 0.4901 - val_cls_loss: 0.3684 - val_box_loss: 0.0024 - val_reg_l2_loss: 0.1079 - val_loss: 0.5980
# Epoch 26/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4480 - cls_loss: 0.3271 - box_loss: 0.0024 - reg_l2_loss: 0.1079 - loss: 0.5559 - learning_rate: 0.0042 - gradient_norm: 3.6565 - val_det_loss: 0.5068 - val_cls_loss: 0.4043 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1079 - val_loss: 0.6147
# Epoch 27/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.5004 - cls_loss: 0.3534 - box_loss: 0.0029 - reg_l2_loss: 0.1079 - loss: 0.6083 - learning_rate: 0.0042 - gradient_norm: 3.8945 - val_det_loss: 0.5115 - val_cls_loss: 0.4188 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1079 - val_loss: 0.6194
# Epoch 28/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4039 - cls_loss: 0.2917 - box_loss: 0.0022 - reg_l2_loss: 0.1079 - loss: 0.5119 - learning_rate: 0.0041 - gradient_norm: 3.0117 - val_det_loss: 0.4534 - val_cls_loss: 0.3790 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1079 - val_loss: 0.5613
# Epoch 29/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4116 - cls_loss: 0.2876 - box_loss: 0.0025 - reg_l2_loss: 0.1079 - loss: 0.5195 - learning_rate: 0.0040 - gradient_norm: 3.7215 - val_det_loss: 0.3779 - val_cls_loss: 0.3089 - val_box_loss: 0.0014 - val_reg_l2_loss: 0.1079 - val_loss: 0.4858
# Epoch 30/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3776 - cls_loss: 0.2794 - box_loss: 0.0020 - reg_l2_loss: 0.1079 - loss: 0.4855 - learning_rate: 0.0040 - gradient_norm: 4.0668 - val_det_loss: 0.4034 - val_cls_loss: 0.3182 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1079 - val_loss: 0.5113
# Epoch 31/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3756 - cls_loss: 0.2774 - box_loss: 0.0020 - reg_l2_loss: 0.1079 - loss: 0.4836 - learning_rate: 0.0039 - gradient_norm: 2.6831 - val_det_loss: 0.4050 - val_cls_loss: 0.3066 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1079 - val_loss: 0.5129
# Epoch 32/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.4033 - cls_loss: 0.2969 - box_loss: 0.0021 - reg_l2_loss: 0.1079 - loss: 0.5112 - learning_rate: 0.0039 - gradient_norm: 3.3560 - val_det_loss: 0.3993 - val_cls_loss: 0.3059 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1079 - val_loss: 0.5072
# Epoch 33/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.4937 - cls_loss: 0.3714 - box_loss: 0.0024 - reg_l2_loss: 0.1079 - loss: 0.6016 - learning_rate: 0.0038 - gradient_norm: 6.0854 - val_det_loss: 0.4564 - val_cls_loss: 0.3473 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1079 - val_loss: 0.5643
# Epoch 34/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3340 - cls_loss: 0.2453 - box_loss: 0.0018 - reg_l2_loss: 0.1079 - loss: 0.4419 - learning_rate: 0.0037 - gradient_norm: 3.4169 - val_det_loss: 0.4572 - val_cls_loss: 0.3470 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1080 - val_loss: 0.5651
# Epoch 35/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3860 - cls_loss: 0.2775 - box_loss: 0.0022 - reg_l2_loss: 0.1080 - loss: 0.4940 - learning_rate: 0.0036 - gradient_norm: 4.0737 - val_det_loss: 0.4771 - val_cls_loss: 0.3665 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1080 - val_loss: 0.5850
# Epoch 36/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3259 - cls_loss: 0.2520 - box_loss: 0.0015 - reg_l2_loss: 0.1080 - loss: 0.4338 - learning_rate: 0.0036 - gradient_norm: 2.6952 - val_det_loss: 0.5137 - val_cls_loss: 0.4045 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1080 - val_loss: 0.6217
# Epoch 37/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3334 - cls_loss: 0.2571 - box_loss: 0.0015 - reg_l2_loss: 0.1080 - loss: 0.4414 - learning_rate: 0.0035 - gradient_norm: 5.4609 - val_det_loss: 0.5523 - val_cls_loss: 0.4443 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1080 - val_loss: 0.6603
# Epoch 38/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2994 - cls_loss: 0.2124 - box_loss: 0.0017 - reg_l2_loss: 0.1080 - loss: 0.4074 - learning_rate: 0.0034 - gradient_norm: 3.6458 - val_det_loss: 0.5382 - val_cls_loss: 0.4176 - val_box_loss: 0.0024 - val_reg_l2_loss: 0.1080 - val_loss: 0.6461
# Epoch 39/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3128 - cls_loss: 0.2140 - box_loss: 0.0020 - reg_l2_loss: 0.1080 - loss: 0.4208 - learning_rate: 0.0034 - gradient_norm: 3.4297 - val_det_loss: 0.5156 - val_cls_loss: 0.3923 - val_box_loss: 0.0025 - val_reg_l2_loss: 0.1080 - val_loss: 0.6236
# Epoch 40/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3546 - cls_loss: 0.2616 - box_loss: 0.0019 - reg_l2_loss: 0.1080 - loss: 0.4626 - learning_rate: 0.0033 - gradient_norm: 4.1754 - val_det_loss: 0.5434 - val_cls_loss: 0.3959 - val_box_loss: 0.0030 - val_reg_l2_loss: 0.1080 - val_loss: 0.6514
# Epoch 41/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3521 - cls_loss: 0.2646 - box_loss: 0.0018 - reg_l2_loss: 0.1080 - loss: 0.4601 - learning_rate: 0.0032 - gradient_norm: 4.9389 - val_det_loss: 0.5044 - val_cls_loss: 0.3914 - val_box_loss: 0.0023 - val_reg_l2_loss: 0.1080 - val_loss: 0.6123
# Epoch 42/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2787 - cls_loss: 0.2018 - box_loss: 0.0015 - reg_l2_loss: 0.1080 - loss: 0.3867 - learning_rate: 0.0031 - gradient_norm: 2.9941 - val_det_loss: 0.4744 - val_cls_loss: 0.3603 - val_box_loss: 0.0023 - val_reg_l2_loss: 0.1080 - val_loss: 0.5824
# Epoch 43/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2982 - cls_loss: 0.2266 - box_loss: 0.0014 - reg_l2_loss: 0.1080 - loss: 0.4062 - learning_rate: 0.0031 - gradient_norm: 4.3976 - val_det_loss: 0.4596 - val_cls_loss: 0.3498 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1080 - val_loss: 0.5676
# Epoch 44/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3316 - cls_loss: 0.2491 - box_loss: 0.0016 - reg_l2_loss: 0.1080 - loss: 0.4396 - learning_rate: 0.0030 - gradient_norm: 4.5376 - val_det_loss: 0.4301 - val_cls_loss: 0.3277 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.5381
# Epoch 45/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3131 - cls_loss: 0.2118 - box_loss: 0.0020 - reg_l2_loss: 0.1080 - loss: 0.4211 - learning_rate: 0.0029 - gradient_norm: 5.0044 - val_det_loss: 0.4336 - val_cls_loss: 0.3238 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1080 - val_loss: 0.5416
# Epoch 46/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2615 - cls_loss: 0.1887 - box_loss: 0.0015 - reg_l2_loss: 0.1080 - loss: 0.3694 - learning_rate: 0.0028 - gradient_norm: 2.5670 - val_det_loss: 0.4632 - val_cls_loss: 0.3490 - val_box_loss: 0.0023 - val_reg_l2_loss: 0.1080 - val_loss: 0.5712
# Epoch 47/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.3166 - cls_loss: 0.2274 - box_loss: 0.0018 - reg_l2_loss: 0.1080 - loss: 0.4246 - learning_rate: 0.0027 - gradient_norm: 3.1970 - val_det_loss: 0.4843 - val_cls_loss: 0.3627 - val_box_loss: 0.0024 - val_reg_l2_loss: 0.1080 - val_loss: 0.5923
# Epoch 48/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3015 - cls_loss: 0.2259 - box_loss: 0.0015 - reg_l2_loss: 0.1080 - loss: 0.4094 - learning_rate: 0.0027 - gradient_norm: 3.1210 - val_det_loss: 0.4841 - val_cls_loss: 0.3621 - val_box_loss: 0.0024 - val_reg_l2_loss: 0.1080 - val_loss: 0.5920
# Epoch 49/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2538 - cls_loss: 0.1844 - box_loss: 0.0014 - reg_l2_loss: 0.1080 - loss: 0.3618 - learning_rate: 0.0026 - gradient_norm: 2.8154 - val_det_loss: 0.4754 - val_cls_loss: 0.3651 - val_box_loss: 0.0022 - val_reg_l2_loss: 0.1080 - val_loss: 0.5834
# Epoch 50/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2512 - cls_loss: 0.1936 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3592 - learning_rate: 0.0025 - gradient_norm: 2.6793 - val_det_loss: 0.4540 - val_cls_loss: 0.3564 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.5620
# Epoch 51/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2088 - cls_loss: 0.1526 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3168 - learning_rate: 0.0024 - gradient_norm: 2.4309 - val_det_loss: 0.4550 - val_cls_loss: 0.3708 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1080 - val_loss: 0.5629
# Epoch 52/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3621 - cls_loss: 0.2651 - box_loss: 0.0019 - reg_l2_loss: 0.1080 - loss: 0.4701 - learning_rate: 0.0023 - gradient_norm: 5.8317 - val_det_loss: 0.4744 - val_cls_loss: 0.3810 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.5824
# Epoch 53/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3225 - cls_loss: 0.2057 - box_loss: 0.0023 - reg_l2_loss: 0.1080 - loss: 0.4305 - learning_rate: 0.0023 - gradient_norm: 4.2660 - val_det_loss: 0.5088 - val_cls_loss: 0.3934 - val_box_loss: 0.0023 - val_reg_l2_loss: 0.1080 - val_loss: 0.6168
# Epoch 54/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2051 - cls_loss: 0.1568 - box_loss: 9.6422e-04 - reg_l2_loss: 0.1080 - loss: 0.3130 - learning_rate: 0.0022 - gradient_norm: 2.0752 - val_det_loss: 0.4699 - val_cls_loss: 0.3833 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1080 - val_loss: 0.5779
# Epoch 55/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2267 - cls_loss: 0.1701 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3347 - learning_rate: 0.0021 - gradient_norm: 3.2280 - val_det_loss: 0.5017 - val_cls_loss: 0.4116 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1080 - val_loss: 0.6097
# Epoch 56/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2464 - cls_loss: 0.1979 - box_loss: 9.6922e-04 - reg_l2_loss: 0.1080 - loss: 0.3544 - learning_rate: 0.0020 - gradient_norm: 2.7763 - val_det_loss: 0.5072 - val_cls_loss: 0.4104 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.6152
# Epoch 57/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2283 - cls_loss: 0.1652 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3363 - learning_rate: 0.0020 - gradient_norm: 3.2007 - val_det_loss: 0.5306 - val_cls_loss: 0.4128 - val_box_loss: 0.0024 - val_reg_l2_loss: 0.1080 - val_loss: 0.6386
# Epoch 58/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2573 - cls_loss: 0.1794 - box_loss: 0.0016 - reg_l2_loss: 0.1080 - loss: 0.3653 - learning_rate: 0.0019 - gradient_norm: 3.2416 - val_det_loss: 0.5219 - val_cls_loss: 0.4188 - val_box_loss: 0.0021 - val_reg_l2_loss: 0.1080 - val_loss: 0.6299
# Epoch 59/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2816 - cls_loss: 0.2202 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3896 - learning_rate: 0.0018 - gradient_norm: 3.1623 - val_det_loss: 0.5148 - val_cls_loss: 0.4190 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.6228
# Epoch 60/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2834 - cls_loss: 0.2077 - box_loss: 0.0015 - reg_l2_loss: 0.1080 - loss: 0.3914 - learning_rate: 0.0017 - gradient_norm: 2.8908 - val_det_loss: 0.5064 - val_cls_loss: 0.4086 - val_box_loss: 0.0020 - val_reg_l2_loss: 0.1080 - val_loss: 0.6144
# Epoch 61/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2512 - cls_loss: 0.1852 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3592 - learning_rate: 0.0016 - gradient_norm: 2.3483 - val_det_loss: 0.5033 - val_cls_loss: 0.3978 - val_box_loss: 0.0021 - val_reg_l2_loss: 0.1080 - val_loss: 0.6113
# Epoch 62/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2250 - cls_loss: 0.1627 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3330 - learning_rate: 0.0016 - gradient_norm: 3.0841 - val_det_loss: 0.4822 - val_cls_loss: 0.3859 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.5902
# Epoch 63/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2135 - cls_loss: 0.1626 - box_loss: 0.0010 - reg_l2_loss: 0.1080 - loss: 0.3215 - learning_rate: 0.0015 - gradient_norm: 2.1948 - val_det_loss: 0.4610 - val_cls_loss: 0.3693 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.1080 - val_loss: 0.5690
# Epoch 64/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2435 - cls_loss: 0.1758 - box_loss: 0.0014 - reg_l2_loss: 0.1080 - loss: 0.3515 - learning_rate: 0.0014 - gradient_norm: 3.4960 - val_det_loss: 0.4513 - val_cls_loss: 0.3584 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.5593
# Epoch 65/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2073 - cls_loss: 0.1631 - box_loss: 8.8349e-04 - reg_l2_loss: 0.1080 - loss: 0.3153 - learning_rate: 0.0014 - gradient_norm: 2.4858 - val_det_loss: 0.4426 - val_cls_loss: 0.3497 - val_box_loss: 0.0019 - val_reg_l2_loss: 0.1080 - val_loss: 0.5506
# Epoch 66/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2014 - cls_loss: 0.1510 - box_loss: 0.0010 - reg_l2_loss: 0.1080 - loss: 0.3094 - learning_rate: 0.0013 - gradient_norm: 1.7446 - val_det_loss: 0.4227 - val_cls_loss: 0.3355 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1080 - val_loss: 0.5307
# Epoch 67/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1894 - cls_loss: 0.1398 - box_loss: 9.9261e-04 - reg_l2_loss: 0.1080 - loss: 0.2974 - learning_rate: 0.0012 - gradient_norm: 2.0521 - val_det_loss: 0.4021 - val_cls_loss: 0.3166 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1080 - val_loss: 0.5101
# Epoch 68/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1923 - cls_loss: 0.1505 - box_loss: 8.3530e-04 - reg_l2_loss: 0.1080 - loss: 0.3003 - learning_rate: 0.0012 - gradient_norm: 1.8907 - val_det_loss: 0.3908 - val_cls_loss: 0.3036 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1080 - val_loss: 0.4988
# Epoch 69/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2344 - cls_loss: 0.1695 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3424 - learning_rate: 0.0011 - gradient_norm: 3.2673 - val_det_loss: 0.3833 - val_cls_loss: 0.3002 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1080 - val_loss: 0.4913
# Epoch 70/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2915 - cls_loss: 0.2182 - box_loss: 0.0015 - reg_l2_loss: 0.1080 - loss: 0.3995 - learning_rate: 0.0010 - gradient_norm: 3.4275 - val_det_loss: 0.3729 - val_cls_loss: 0.2903 - val_box_loss: 0.0017 - val_reg_l2_loss: 0.1080 - val_loss: 0.4809
# Epoch 71/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.3042 - cls_loss: 0.2178 - box_loss: 0.0017 - reg_l2_loss: 0.1080 - loss: 0.4122 - learning_rate: 9.5616e-04 - gradient_norm: 4.1085 - val_det_loss: 0.3705 - val_cls_loss: 0.2955 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4785
# Epoch 72/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2451 - cls_loss: 0.1845 - box_loss: 0.0012 - reg_l2_loss: 0.1080 - loss: 0.3531 - learning_rate: 8.9455e-04 - gradient_norm: 4.5649 - val_det_loss: 0.3580 - val_cls_loss: 0.2859 - val_box_loss: 0.0014 - val_reg_l2_loss: 0.1080 - val_loss: 0.4660
# Epoch 73/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2450 - cls_loss: 0.1724 - box_loss: 0.0015 - reg_l2_loss: 0.1080 - loss: 0.3530 - learning_rate: 8.3456e-04 - gradient_norm: 4.0668 - val_det_loss: 0.3414 - val_cls_loss: 0.2726 - val_box_loss: 0.0014 - val_reg_l2_loss: 0.1080 - val_loss: 0.4494
# Epoch 74/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2372 - cls_loss: 0.1730 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3452 - learning_rate: 7.7625e-04 - gradient_norm: 3.3005 - val_det_loss: 0.3273 - val_cls_loss: 0.2569 - val_box_loss: 0.0014 - val_reg_l2_loss: 0.1080 - val_loss: 0.4353
# Epoch 75/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1909 - cls_loss: 0.1412 - box_loss: 9.9380e-04 - reg_l2_loss: 0.1080 - loss: 0.2989 - learning_rate: 7.1967e-04 - gradient_norm: 1.8962 - val_det_loss: 0.3291 - val_cls_loss: 0.2548 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4371
# Epoch 76/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1808 - cls_loss: 0.1416 - box_loss: 7.8406e-04 - reg_l2_loss: 0.1080 - loss: 0.2888 - learning_rate: 6.6489e-04 - gradient_norm: 2.0680 - val_det_loss: 0.3355 - val_cls_loss: 0.2595 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4435
# Epoch 77/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2230 - cls_loss: 0.1743 - box_loss: 9.7457e-04 - reg_l2_loss: 0.1080 - loss: 0.3310 - learning_rate: 6.1195e-04 - gradient_norm: 4.1066 - val_det_loss: 0.3463 - val_cls_loss: 0.2686 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.1080 - val_loss: 0.4543
# Epoch 78/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2121 - cls_loss: 0.1662 - box_loss: 9.1884e-04 - reg_l2_loss: 0.1080 - loss: 0.3201 - learning_rate: 5.6091e-04 - gradient_norm: 2.8600 - val_det_loss: 0.3692 - val_cls_loss: 0.2892 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.1080 - val_loss: 0.4772
# Epoch 79/100
# 6/6 [==============================] - 11s 2s/step - det_loss: 0.2841 - cls_loss: 0.2288 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3921 - learning_rate: 5.1183e-04 - gradient_norm: 3.6404 - val_det_loss: 0.3690 - val_cls_loss: 0.2898 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.1080 - val_loss: 0.4770
# Epoch 80/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2142 - cls_loss: 0.1735 - box_loss: 8.1415e-04 - reg_l2_loss: 0.1080 - loss: 0.3222 - learning_rate: 4.6475e-04 - gradient_norm: 2.2957 - val_det_loss: 0.3654 - val_cls_loss: 0.2882 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4734
# Epoch 81/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2015 - cls_loss: 0.1469 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3095 - learning_rate: 4.1972e-04 - gradient_norm: 2.0982 - val_det_loss: 0.3570 - val_cls_loss: 0.2815 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4650
# Epoch 82/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.2529 - cls_loss: 0.1865 - box_loss: 0.0013 - reg_l2_loss: 0.1080 - loss: 0.3609 - learning_rate: 3.7678e-04 - gradient_norm: 3.1931 - val_det_loss: 0.3508 - val_cls_loss: 0.2753 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4588
# Epoch 83/100
# 6/6 [==============================] - 8s 2s/step - det_loss: 0.1989 - cls_loss: 0.1540 - box_loss: 8.9687e-04 - reg_l2_loss: 0.1080 - loss: 0.3069 - learning_rate: 3.3598e-04 - gradient_norm: 2.1679 - val_det_loss: 0.3486 - val_cls_loss: 0.2719 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4566
# Epoch 84/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.1690 - cls_loss: 0.1404 - box_loss: 5.7219e-04 - reg_l2_loss: 0.1080 - loss: 0.2770 - learning_rate: 2.9736e-04 - gradient_norm: 1.5963 - val_det_loss: 0.3449 - val_cls_loss: 0.2681 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4529
# Epoch 85/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1833 - cls_loss: 0.1437 - box_loss: 7.9237e-04 - reg_l2_loss: 0.1080 - loss: 0.2913 - learning_rate: 2.6096e-04 - gradient_norm: 1.8310 - val_det_loss: 0.3421 - val_cls_loss: 0.2649 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4501
# Epoch 86/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2556 - cls_loss: 0.1852 - box_loss: 0.0014 - reg_l2_loss: 0.1080 - loss: 0.3636 - learning_rate: 2.2681e-04 - gradient_norm: 2.7767 - val_det_loss: 0.3414 - val_cls_loss: 0.2635 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.1080 - val_loss: 0.4494
# Epoch 87/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1859 - cls_loss: 0.1492 - box_loss: 7.3280e-04 - reg_l2_loss: 0.1080 - loss: 0.2939 - learning_rate: 1.9495e-04 - gradient_norm: 1.7314 - val_det_loss: 0.3410 - val_cls_loss: 0.2623 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.1080 - val_loss: 0.4490
# Epoch 88/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1989 - cls_loss: 0.1482 - box_loss: 0.0010 - reg_l2_loss: 0.1080 - loss: 0.3069 - learning_rate: 1.6541e-04 - gradient_norm: 2.5891 - val_det_loss: 0.3363 - val_cls_loss: 0.2580 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.1080 - val_loss: 0.4443
# Epoch 89/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2112 - cls_loss: 0.1686 - box_loss: 8.5210e-04 - reg_l2_loss: 0.1080 - loss: 0.3192 - learning_rate: 1.3822e-04 - gradient_norm: 1.9592 - val_det_loss: 0.3281 - val_cls_loss: 0.2510 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4361
# Epoch 90/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.1852 - cls_loss: 0.1442 - box_loss: 8.2013e-04 - reg_l2_loss: 0.1080 - loss: 0.2932 - learning_rate: 1.1341e-04 - gradient_norm: 1.5137 - val_det_loss: 0.3251 - val_cls_loss: 0.2480 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4331
# Epoch 91/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2156 - cls_loss: 0.1610 - box_loss: 0.0011 - reg_l2_loss: 0.1080 - loss: 0.3236 - learning_rate: 9.1009e-05 - gradient_norm: 3.4613 - val_det_loss: 0.3251 - val_cls_loss: 0.2483 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4331
# Epoch 92/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2120 - cls_loss: 0.1666 - box_loss: 9.0654e-04 - reg_l2_loss: 0.1080 - loss: 0.3200 - learning_rate: 7.1028e-05 - gradient_norm: 2.2611 - val_det_loss: 0.3241 - val_cls_loss: 0.2481 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4321
# Epoch 93/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1852 - cls_loss: 0.1496 - box_loss: 7.1177e-04 - reg_l2_loss: 0.1080 - loss: 0.2932 - learning_rate: 5.3493e-05 - gradient_norm: 2.0245 - val_det_loss: 0.3231 - val_cls_loss: 0.2475 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4311
# Epoch 94/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1961 - cls_loss: 0.1502 - box_loss: 9.1787e-04 - reg_l2_loss: 0.1080 - loss: 0.3041 - learning_rate: 3.8422e-05 - gradient_norm: 1.9022 - val_det_loss: 0.3227 - val_cls_loss: 0.2469 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4307
# Epoch 95/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.1835 - cls_loss: 0.1422 - box_loss: 8.2670e-04 - reg_l2_loss: 0.1080 - loss: 0.2915 - learning_rate: 2.5829e-05 - gradient_norm: 1.8528 - val_det_loss: 0.3221 - val_cls_loss: 0.2458 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4301
# Epoch 96/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.1894 - cls_loss: 0.1459 - box_loss: 8.6982e-04 - reg_l2_loss: 0.1080 - loss: 0.2974 - learning_rate: 1.5727e-05 - gradient_norm: 2.7287 - val_det_loss: 0.3222 - val_cls_loss: 0.2460 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4302
# Epoch 97/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.2168 - cls_loss: 0.1701 - box_loss: 9.3439e-04 - reg_l2_loss: 0.1080 - loss: 0.3248 - learning_rate: 8.1273e-06 - gradient_norm: 2.7798 - val_det_loss: 0.3200 - val_cls_loss: 0.2431 - val_box_loss: 0.0015 - val_reg_l2_loss: 0.1080 - val_loss: 0.4280
# Epoch 98/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.1751 - cls_loss: 0.1381 - box_loss: 7.3912e-04 - reg_l2_loss: 0.1080 - loss: 0.2831 - learning_rate: 3.0362e-06 - gradient_norm: 1.7508 - val_det_loss: 0.3196 - val_cls_loss: 0.2419 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.1080 - val_loss: 0.4276
# Epoch 99/100
# 6/6 [==============================] - 9s 2s/step - det_loss: 0.2878 - cls_loss: 0.2176 - box_loss: 0.0014 - reg_l2_loss: 0.1080 - loss: 0.3958 - learning_rate: 4.5955e-07 - gradient_norm: 4.0017 - val_det_loss: 0.3173 - val_cls_loss: 0.2392 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.1080 - val_loss: 0.4253
# Epoch 100/100
# 6/6 [==============================] - 10s 2s/step - det_loss: 0.1811 - cls_loss: 0.1375 - box_loss: 8.7279e-04 - reg_l2_loss: 0.1080 - loss: 0.2891 - learning_rate: 3.9961e-07 - gradient_norm: 2.4587 - val_det_loss: 0.3161 - val_cls_loss: 0.2383 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.1080 - val_loss: 0.4241

# %% [markdown]
# ### Step 4. Evaluate the model with the validation data.
#
# After training the object detection model using the images in the training dataset, use the 10 images in the validation dataset to evaluate how the model performs against new data it has never seen before.
#
# As the default batch size is 64, it will take 1 step to go through the 10 images in the validation dataset.
#
# The evaluation metrics are same as [COCO](https://cocodataset.org/#detection-eval).

# %%
model.evaluate(val_data)
# Out:
# 1/1 [==============================] - 7s 7s/step
# {'AP': 0.67145216,
#  'AP50': 0.91749173,
#  'AP75': 0.91749173,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.67145216,
#  'ARmax1': 0.75416666,
#  'ARmax10': 0.75416666,
#  'ARmax100': 0.75416666,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.75416666,
#  'AP_/painting': 0.7227723,
#  'AP_/Real_Tunnel': 0.620132}

# %%
# import matplotlib.pyplot as plt
# print(model.history.keys())
# # summarize history for loss
# plt.plot(model.history['loss'])
# plt.plot(model.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %% [markdown]
# ### Step 5: Export as a TensorFlow Lite model.
#
# Export the trained object detection model to the TensorFlow Lite format by specifying which folder you want to export the quantized model to. The default post-training quantization technique is [full integer quantization](https://www.tensorflow.org/lite/performance/post_training_integer_quant). This allows the TensorFlow Lite model to be smaller, run faster on Raspberry Pi CPU and also compatible with the Google Coral EdgeTPU.

# %%
model.export(export_dir='Thesis/', tflite_filename='android.tflite')

# %% [markdown]
# ### Step 6:  Evaluate the TensorFlow Lite model.
#
# Several factors can affect the model accuracy when exporting to TFLite:
# * [Quantization](https://www.tensorflow.org/lite/performance/model_optimization) helps shrinking the model size by 4 times at the expense of some accuracy drop.
# * The original TensorFlow model uses per-class [non-max supression (NMS)](https://www.coursera.org/lecture/convolutional-neural-networks/non-max-suppression-dvrjH) for post-processing, while the TFLite model uses global NMS that's much faster but less accurate.
# Keras outputs maximum 100 detections while tflite outputs maximum 25 detections.
#
# Therefore you'll have to evaluate the exported TFLite model and compare its accuracy with the original TensorFlow model.

# %%
model.evaluate_tflite('Thesis/android.tflite', val_data)
# Out:
# 7/7 [==============================] - 364s 52s/step
# {'AP': 0.6632249,
#  'AP50': 0.897454,
#  'AP75': 0.897454,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.6632249,
#  'ARmax1': 0.7416667,
#  'ARmax10': 0.7416667,
#  'ARmax100': 0.7416667,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.7416667,
#  'AP_/painting': 0.7227723,
#  'AP_/Real_Tunnel': 0.6036775}

# %%
# Download the TFLite model to your local computer.
# from google.colab import files
# files.download('android.tflite')

# %% [markdown]
# ## Test the Android figurine detection model
#
# After training the model, let's test it with an image that the model hasn't seen before to get a sense of how good the model is.

# %%
#@title Load the trained TFLite model and define some visualization functions

#@markdown This code comes from the TFLite Object Detection [Raspberry Pi sample](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/raspberry_pi).

import platform
from typing import List, NamedTuple
import json

import tensorflow as tf
import numpy as np

import cv2

Interpreter = tf.lite.Interpreter
load_delegate = tf.lite.experimental.load_delegate

# pylint: enable=g-import-not-at-top


class ObjectDetectorOptions(NamedTuple):
  """A config to initialize an object detector."""

  enable_edgetpu: bool = False
  """Enable the model to run on EdgeTPU."""

  label_allow_list: List[str] = None
  """The optional allow list of labels."""

  label_deny_list: List[str] = None
  """The optional deny list of labels."""

  max_results: int = -1
  """The maximum number of top-scored detection results to return."""

  num_threads: int = 1
  """The number of CPU threads to be used."""

  score_threshold: float = 0.0
  """The score threshold of detection results to return."""


class Rect(NamedTuple):
  """A rectangle in 2D space."""
  left: float
  top: float
  right: float
  bottom: float


class Category(NamedTuple):
  """A result of a classification task."""
  label: str
  score: float
  index: int


class Detection(NamedTuple):
  """A detected object as the result of an ObjectDetector."""
  bounding_box: Rect
  categories: List[Category]


def edgetpu_lib_name():
  """Returns the library name of EdgeTPU in the current platform."""
  return {
      'Darwin': 'libedgetpu.1.dylib',
      'Linux': 'libedgetpu.so.1',
      'Windows': 'edgetpu.dll',
  }.get(platform.system(), None)


class ObjectDetector:
  """A wrapper class for a TFLite object detection model."""

  _OUTPUT_LOCATION_NAME = 'location'
  _OUTPUT_CATEGORY_NAME = 'category'
  _OUTPUT_SCORE_NAME = 'score'
  _OUTPUT_NUMBER_NAME = 'number of detections'

  def __init__(
      self,
      model_path: str,
      options: ObjectDetectorOptions = ObjectDetectorOptions()
  ) -> None:
    """Initialize a TFLite object detection model.
    Args:
        model_path: Path to the TFLite model.
        options: The config to initialize an object detector. (Optional)
    Raises:
        ValueError: If the TFLite model is invalid.
        OSError: If the current OS isn't supported by EdgeTPU.
    """

    # Load metadata from model.
    displayer = metadata.MetadataDisplayer.with_model_file(model_path)

    # Save model metadata for preprocessing later.
    model_metadata = json.loads(displayer.get_metadata_json())
    process_units = model_metadata['subgraph_metadata'][0]['input_tensor_metadata'][0]['process_units']
    mean = 0.0
    std = 1.0
    for option in process_units:
      if option['options_type'] == 'NormalizationOptions':
        mean = option['options']['mean'][0]
        std = option['options']['std'][0]
    self._mean = mean
    self._std = std

    # Load label list from metadata.
    file_name = displayer.get_packed_associated_file_list()[0]
    label_map_file = displayer.get_associated_file_buffer(file_name).decode()
    label_list = list(filter(lambda x: len(x) > 0, label_map_file.splitlines()))
    self._label_list = label_list

    # Initialize TFLite model.
    if options.enable_edgetpu:
      if edgetpu_lib_name() is None:
        raise OSError("The current OS isn't supported by Coral EdgeTPU.")
      interpreter = Interpreter(
          model_path=model_path,
          experimental_delegates=[load_delegate(edgetpu_lib_name())],
          num_threads=options.num_threads)
    else:
      interpreter = Interpreter(
          model_path=model_path, num_threads=options.num_threads)

    interpreter.allocate_tensors()
    input_detail = interpreter.get_input_details()[0]

    # From TensorFlow 2.6, the order of the outputs become undefined.
    # Therefore we need to sort the tensor indices of TFLite outputs and to know
    # exactly the meaning of each output tensor. For example, if
    # output indices are [601, 599, 598, 600], tensor names and indices aligned
    # are:
    #   - location: 598
    #   - category: 599
    #   - score: 600
    #   - detection_count: 601
    # because of the op's ports of TFLITE_DETECTION_POST_PROCESS
    # (https://github.com/tensorflow/tensorflow/blob/a4fe268ea084e7d323133ed7b986e0ae259a2bc7/tensorflow/lite/kernels/detection_postprocess.cc#L47-L50).
    sorted_output_indices = sorted(
        [output['index'] for output in interpreter.get_output_details()])
    self._output_indices = {
        self._OUTPUT_LOCATION_NAME: sorted_output_indices[0],
        self._OUTPUT_CATEGORY_NAME: sorted_output_indices[1],
        self._OUTPUT_SCORE_NAME: sorted_output_indices[2],
        self._OUTPUT_NUMBER_NAME: sorted_output_indices[3],
    }

    self._input_size = input_detail['shape'][2], input_detail['shape'][1]
    self._is_quantized_input = input_detail['dtype'] == np.uint8
    self._interpreter = interpreter
    self._options = options

  def detect(self, input_image: np.ndarray) -> List[Detection]:
    """Run detection on an input image.
    Args:
        input_image: A [height, width, 3] RGB image. Note that height and width
          can be anything since the image will be immediately resized according
          to the needs of the model within this function.
    Returns:
        A Person instance.
    """
    image_height, image_width, _ = input_image.shape

    input_tensor = self._preprocess(input_image)

    self._set_input_tensor(input_tensor)
    self._interpreter.invoke()

    # Get all output details
    boxes = self._get_output_tensor(self._OUTPUT_LOCATION_NAME)
    classes = self._get_output_tensor(self._OUTPUT_CATEGORY_NAME)
    scores = self._get_output_tensor(self._OUTPUT_SCORE_NAME)
    count = int(self._get_output_tensor(self._OUTPUT_NUMBER_NAME))

    return self._postprocess(boxes, classes, scores, count, image_width,
                             image_height)

  def _preprocess(self, input_image: np.ndarray) -> np.ndarray:
    """Preprocess the input image as required by the TFLite model."""

    # Resize the input
    input_tensor = cv2.resize(input_image, self._input_size)

    # Normalize the input if it's a float model (aka. not quantized)
    if not self._is_quantized_input:
      input_tensor = (np.float32(input_tensor) - self._mean) / self._std

    # Add batch dimension
    input_tensor = np.expand_dims(input_tensor, axis=0)

    return input_tensor

  def _set_input_tensor(self, image):
    """Sets the input tensor."""
    tensor_index = self._interpreter.get_input_details()[0]['index']
    input_tensor = self._interpreter.tensor(tensor_index)()[0]
    input_tensor[:, :] = image

  def _get_output_tensor(self, name):
    """Returns the output tensor at the given index."""
    output_index = self._output_indices[name]
    tensor = np.squeeze(self._interpreter.get_tensor(output_index))
    return tensor

  def _postprocess(self, boxes: np.ndarray, classes: np.ndarray,
                   scores: np.ndarray, count: int, image_width: int,
                   image_height: int) -> List[Detection]:
    """Post-process the output of TFLite model into a list of Detection objects.
    Args:
        boxes: Bounding boxes of detected objects from the TFLite model.
        classes: Class index of the detected objects from the TFLite model.
        scores: Confidence scores of the detected objects from the TFLite model.
        count: Number of detected objects from the TFLite model.
        image_width: Width of the input image.
        image_height: Height of the input image.
    Returns:
        A list of Detection objects detected by the TFLite model.
    """
    results = []

    # Parse the model output into a list of Detection entities.
    for i in range(count):
      if scores[i] >= self._options.score_threshold:
        y_min, x_min, y_max, x_max = boxes[i]
        bounding_box = Rect(
            top=int(y_min * image_height),
            left=int(x_min * image_width),
            bottom=int(y_max * image_height),
            right=int(x_max * image_width))
        class_id = int(classes[i])
        category = Category(
            score=scores[i],
            label=self._label_list[class_id],  # 0 is reserved for background
            index=class_id)
        result = Detection(bounding_box=bounding_box, categories=[category])
        results.append(result)

    # Sort detection results by score ascending
    sorted_results = sorted(
        results,
        key=lambda detection: detection.categories[0].score,
        reverse=True)

    # Filter out detections in deny list
    filtered_results = sorted_results
    if self._options.label_deny_list is not None:
      filtered_results = list(
          filter(
              lambda detection: detection.categories[0].label not in self.
              _options.label_deny_list, filtered_results))

    # Keep only detections in allow list
    if self._options.label_allow_list is not None:
      filtered_results = list(
          filter(
              lambda detection: detection.categories[0].label in self._options.
              label_allow_list, filtered_results))

    # Only return maximum of max_results detection.
    if self._options.max_results > 0:
      result_count = min(len(filtered_results), self._options.max_results)
      filtered_results = filtered_results[:result_count]

    return filtered_results


_MARGIN = 10  # pixels
_ROW_SIZE = 10  # pixels
_FONT_SIZE = 1
_FONT_THICKNESS = 1
_TEXT_COLOR = (0, 0, 255)  # red


def visualize(
    image: np.ndarray,
    detections: List[Detection],
) -> np.ndarray:
  """Draws bounding boxes on the input image and return it.
  Args:
    image: The input RGB image.
    detections: The list of all "Detection" entities to be visualize.
  Returns:
    Image with bounding boxes.
  """
  for detection in detections:
    # Draw bounding_box
    start_point = detection.bounding_box.left, detection.bounding_box.top
    end_point = detection.bounding_box.right, detection.bounding_box.bottom
    cv2.rectangle(image, start_point, end_point, _TEXT_COLOR, 3)

    # Draw label and score
    category = detection.categories[0]
    class_name = category.label
    probability = round(category.score, 2)
    result_text = class_name + ' (' + str(probability) + ')'
    text_location = (_MARGIN + detection.bounding_box.left,
                     _MARGIN + _ROW_SIZE + detection.bounding_box.top)
    cv2.putText(image, result_text, text_location, cv2.FONT_HERSHEY_PLAIN,
                _FONT_SIZE, _TEXT_COLOR, _FONT_THICKNESS)

  return image

# %%
from PIL import Image
INPUT_IMAGE_ONE = 'Thesis/All_Photos/Original/Original_TEST/0_disp.jpg' #@param {type:"string"}
DETECTION_THRESHOLD = 0.1 #@param {type:"number"}
TFLITE_MODEL_PATH = "Thesis/android.tflite" #@param {type:"string"}

TEMP_FILE = '/tmp/image.png'

# !wget -q -O $TEMP_FILE $INPUT_IMAGE_ONE

#image = Image.open(TEMP_FILE).convert('RGB')
image_one = Image.open(INPUT_IMAGE_ONE).convert('RGB')
image_one.thumbnail((512, 512), Image.ANTIALIAS)
image_np_one = np.asarray(image_one)

# Load the TFLite model
options = ObjectDetectorOptions(
      num_threads=4,
      score_threshold=DETECTION_THRESHOLD,
)
detector = ObjectDetector(model_path=TFLITE_MODEL_PATH, options=options)

# Run object detection estimation using the model.
detections = detector.detect(image_np_one)

# Draw keypoints and edges on input image
image_np_one = visualize(image_np_one, detections)

# Show the detection result
Image.fromarray(image_np_one)
# Out:
# <PIL.Image.Image image mode=RGB size=512x341 at 0x7F84E9181400>

# %%
#INPUT_IMAGE_URL = 'JPEG/Validate/2_33226e67-1692-4472-88be-acdbace303f5_1024x1024.jpg'
INPUT_IMAGE_URL = 'Thesis/All_Photos/Original/Original_TEST/6_disp.jpg'
DISP_IMAGE_OVERLAY = 'Thesis/All_Photos/1024_DIFFNet/TEST_1024/6_disp.jpeg'

# %%
#@title Run object detection and show the detection results

# from PIL import Image

# INPUT_IMAGE_URL = 'Depth_Map_Image/2_disp.jpeg'
# INPUT_IMAGE_URL = "http://download.tensorflow.org/example_images/android_figurine.jpg" #@param {type:"string"}
INPUT_IMAGE_URL = INPUT_IMAGE_URL #@param {type:"string"}
DETECTION_THRESHOLD = 0.5 #@param {type:"number"}
TFLITE_MODEL_PATH = "Thesis/android.tflite" #@param {type:"string"}

TEMP_FILE = '/tmp/image.png'

# !wget -q -O $TEMP_FILE $INPUT_IMAGE_URL

#image = Image.open(TEMP_FILE).convert('RGB')
image = Image.open(INPUT_IMAGE_URL).convert('RGB')
image.thumbnail((512, 512), Image.ANTIALIAS)
image_np = np.asarray(image)

# Load the TFLite model
options = ObjectDetectorOptions(
      num_threads=4,
      score_threshold=DETECTION_THRESHOLD,
)
detector = ObjectDetector(model_path=TFLITE_MODEL_PATH, options=options)

# Run object detection estimation using the model.
detections = detector.detect(image_np)

# Draw keypoints and edges on input image
image_np = visualize(image_np, detections)

# Show the detection result
Image.fromarray(image_np)



# #image = Image.open(TEMP_FILE).convert('RGB')
# image_two = Image.open(DISP_IMAGE_OVERLAY).convert('RGB')
# image_two.thumbnail((512, 512), Image.ANTIALIAS)
# image_np_two = np.asarray(image_two)

# image_np_two = visualize(image_np_two, detections)
# Image.fromarray(image_np_two)
# Out:
# <PIL.Image.Image image mode=RGB size=512x288 at 0x7F84E9122400>

# %%
image_two = Image.open(DISP_IMAGE_OVERLAY).convert('RGB')
image_two.thumbnail((512, 512), Image.ANTIALIAS)
image_np_two = np.asarray(image_two)

image_np_two = visualize(image_np_two, detections)
Image.fromarray(image_np_two)
# Out:
# <PIL.Image.Image image mode=RGB size=512x288 at 0x7F84E9122F10>

# %%
t2 = time.perf_counter()
print('time taken to run:',t2-t1)
# Out:
# time taken to run: 1696.1136866610004
